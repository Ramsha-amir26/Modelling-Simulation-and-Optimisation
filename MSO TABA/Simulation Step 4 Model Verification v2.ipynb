# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import simpy
# Out:
# C:\Users\ramsh\AppData\Local\Temp\ipykernel_12228\4025722026.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def label(i):
    return (label(i//26-1)+chr(65+i%26)) if i>25 else chr(65+i)

# %%
def plotMap(G, T=[], P=[], w=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=3,
            styleP='b-o', lwP=2, msP=3,
            stylePT='go', msPT=7,
            styleW='ro', msW=9,
            text=None, grid=False, labels=False, scale=False):

    V, E = G

    def round_down(x, level): return (x//level)*level
    def round_up(x, level): return (x//level+1)*level
    
    xmin = round_down(min([ x for (x, _) in V ]), 100)
    xmax = round_up(max([ x for (x, _) in V ]), 100)
    ymin = round_down(min([ y for (_, y) in V ]), 100)
    ymax = round_up(max([ y for (_, y) in V ]), 100)
    dx = xmax-xmin
    dy = ymax-ymin
    yoffset = (ymax-ymin)//10
    
    fig = plt.gcf()
    fig.set_size_inches(4, 4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin-yoffset, ymax)
    
    if not grid:
        plt.axis('off')

    for e in E:
        p1, p2 = e
        plt.plot( [ p1[0], p2[0] ],
                  [ p1[1], p2[1] ], 
                  style, lw=lw, ms=ms)
    if scale:
        # plot 1000m scale
        ybar = ymin-0.9*yoffset
        D = [ (xmin, ybar+50), (xmin, ybar), (xmin+1000, ybar), (xmin+1000, ybar+50) ]
        plt.plot( [ d[0] for d in D ], [ d[1] for d in D ], 'k-', lw=0.5)
        plt.text(xmin+500, ymin-0.7*yoffset, '1000m' , horizontalalignment='center', size=8)
    
    if labels:
        for i in range(len(V)):
            x, y = V[i]
            plt.text(x+0.0150*dx, y-0.0350*dy, label(i), size=8)
        
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
        
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if w is not None:
        plt.plot( [ w[0] ], [ w[1] ], 
                      styleW, ms=msW)
    if text is not None:
        plt.text(xmax, ymin-0.7*yoffset, text, horizontalalignment='right', size=8)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Central Warehouse Location

# %%
from statistics import median

def generateWarehouseLocation(M):
    V, _ = M
    xc = median([ x for (x, y) in V ])
    yc = median([ y for (x, y) in V ])
    cloc = (xc, yc)
    minloc = V[0]
    mindist = dist(minloc, cloc)
    for i in range(1, len(V)):
        d = dist(V[i], cloc)
        if d<mindist:
            minloc = V[i]
            mindist = dist(V[i], cloc)
    return minloc

# %% [markdown]
# ## Time Handling (NEW)

# %% [markdown]
# **Convention:** In this project we measure simulation time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    t = round(t, 1)
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(t)
    t = int(round((t-secs)*10,1)) 
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.1'

# %%
timestamp(24*3600*12+3*3600+122.96)
# Out:
# '[12] 03:02:03.0'

# %%
def day(now):
    return int(now//(24*3600))

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Short Delivery Route (as before)

# %% [markdown]
# ## Greedy Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopG(M, T, timing=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
        
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
        
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
            
    if timing:
        print(f"createLoopH:    {time.time()-start_time:6.2f}s")

    return makeLoop(L)

# %% [markdown]
# # Finding Optimal Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
                
    def cycles(k, n):
        if k==1:
            return [ [i] for i in range(0,n) ]
        else:
            sc=cycles(k-1, n)
            all=[]
            for c in sc:
                for i in range(0,n):
                    if c.count(i)==0:
                        all.append(c+[i])
            return all

    for k in range(3, 4):   
        cycs=cycles(k,n)
        for c in cycs:
            c.append(c[0])
            prob+=pulp.lpSum([ x[c[i]][c[i+1]] for i in range(0,k)]) <= k-1
            constraints += 1    
            
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0, timeLimit=2)
    res = prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()
        
    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
                
        res = prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
    trip = trips[0]
    # print(trip)
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
import time

class Recorder:
    
    def __init__(self, env, M, W, C, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    def __init__(self, rec, id, location):
        self.rec = rec
        self.id = id
        self.location = location
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer {self.id:d} at {str(self.location):s}"
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            answerTime = random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR)
            if answerTime < WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR:                            
                yield self.rec.env.timeout(answerTime)
                self.rec.trace(str(self)+" answers door")
                self.answersDoor = True
            else:
                yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
                self.rec.trace(str(self)+" to slow to answer the door")
                self.answersDoor = False
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec.trace(str(self)+" not at home")
            self.answersDoot = False
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            returnTime = 22 if random.random()<CUSTOMER_NOT_AT_HOME else 18
            yield self.rec.env.timeout(nextHour(self.rec.env, returnTime))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    def __init__(self, rec, i, day, cust):
        self.rec = rec
        self.i = i  
        self.arrival = day
        self.cust = cust
        self.status = [  ] # status record and
        self.timing = [  ] # timing

    def __str__(self):
        return f"Parcel {self.i:d} for cust {self.cust.id:d}"

    def index(self):
        return self.i
    
    def destination(self):
        return self.cust.location
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.trace("Driver arrives for work")

    def goesHome(self):
        self.location = None
        self.parcels = None
        self.returns = None
        self.tour = None
        self.rec.trace("Driver goes home")
        
    def leaveForDelivery(self, tour, parcels, addresses):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " 
                       f"of {len(parcels):d} parcels "
                       f"to {len(addresses):d} customers")
        self.rec.trace(f"Length of delivery tour: {pathLength(tour):,d}m")
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, w=tour[0], 
                    text=f"Day {day(self.rec.env.now):d}:, {pathLength(tour):,d}m")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels, addresses = self.DC.sendForDelivery()
            if len(parcels)==0: 
                self.rec.trace("Nothing to do today")
            else:
                yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
                self.leaveForDelivery(tour, parcels, addresses)        
                while len(self.parcels)>0:
                    # drive to customer
                    custLocation = self.parcels[0].destination()
                    cust = self.parcels[0].cust
                    self.rec.trace("Driver drives to "+str(cust))
                    yield from self.__drive(custLocation)
                    self.rec.trace("Driver arrived at "+str(cust))
                    # call at customer
                    yield from cust.answerDoor()
                    
                    if cust.answersDoor:
                        while len(self.parcels)>0 and \
                                custLocation == self.parcels[0].destination():
                            cust.acceptParcel(self.parcels[0])
                            yield self.rec.env.timeout(random.expovariate(1/10))
                            self.parcels = self.parcels[1:]
                        cust.signOff()
                        yield self.rec.env.timeout(random.expovariate(1/10))
                    else:
                        while len(self.parcels)>0 and  \
                                custLocation == self.parcels[0].destination():
                            self.returns += [self.parcels[0]]
                            self.parcels = self.parcels[1:]

                # return to delivery centre
                self.rec.trace("Driver returns to delivery centre")
                yield from self.__drive(self.DC.W)
                self.rec.trace("Driver arrived at delivery centre")
            
                for parcel in self.returns:
                    self.DC.returnFromDelivery(parcel)
                    yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)

                leftOver = len(self.DC.parcels)+len(self.DC.leftOver)
                self.rec.trace(f"{leftOver:d} parcels left for next day")
            
            yield self.rec.env.timeout(600)
        
            self.goesHome()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = BIKE_RANGE
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = [self.W]  # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.destination()
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            SH = createLoopG(MT, [self.W] + self.dest + [custLoc])
            if pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
                self.tour = SH
            else: 
                self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        tour = self.tour
        addresses = []
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.destination() == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
                    if dest not in addresses:
                        addresses += [dest]
         
        # arrange the left overs for next day
        L = self.leftOver
        self.tour = [self.W]
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        return tour, parcels, addresses
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The proportion of customers that for whatever are not at home or return home late

# %%
CUSTOMER_NOT_AT_HOME = 0.9  # 10%

# %% [markdown]
# The maximum bike range. This is passed as parameter to the Delivery Centre
# and taken into account for the daily tour planning

# %%
BIKE_RANGE = 40000

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveries(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    random.seed(seed)
    deliveries = [ [ ] for _ in range(days) ]
    for c in range(C):
        arr = 0
        while True:
            arr += random.expovariate(p)
            day = int(arr)
            if day>=days:
                break
            deliveries[day].append(c)
    return deliveries

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, 
               log=False, plot=False, timing=False):

    random.seed(seed)
    D = generateDeliveries(p, len(C), days, seed)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, 
                   log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {sum([len(d) for d in D]):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    CUSTOMERS = []
    for i in range(len(C)):
        CUSTOMERS.append(Customer(rec, i, C[i]))

    DC = DeliveryCentre(rec, M, W)
    Z = Driver(rec, DC)
    PARCELS = []

    def parcelGeneratorProcess(env, rec, D, C):
        for day in range(len(D)):
            yield env.timeout(nextHour(env, 17.00))
            for c in D[day]:
                cust = CUSTOMERS[c]
                parcel = Parcel(rec, len(PARCELS), day, cust)
                PARCELS.append(parcel)
                DC.acceptParcel(parcel)

    env.process(parcelGeneratorProcess(env, rec, D, C))
    env.run()

    rec.finish()

    if DC.getInventory()>0:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Model Verification

# %%
import pickle
with open('simpleData.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, w=W, scale=True)

# %%
rec1 = simulation(M, W, C, p=0.15, days=4, log=True)
# Out:
# Simulating delivery of 48 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 27 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 30 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 40 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 54 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 77 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 80 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 89 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 92 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 96 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 96 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 27 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 0] 18:12:30.0 Driver leaves for delivery of 15 parcels to 13 customers
# [ 0] 18:12:30.0 Length of delivery tour: 39,296m
# [ 0] 18:12:30.0 Driver drives to Customer 79 at (5736, 1320)
# [ 0] 18:27:40.8 Driver arrived at Customer 79 at (5736, 1320)
# [ 0] 18:28:40.8 Customer 79 at (5736, 1320) not at home
# [ 0] 18:28:40.8 Driver drives to Customer 84 at (6012, 1320)
# [ 0] 18:29:47.0 Driver arrived at Customer 84 at (6012, 1320)
# [ 0] 18:30:47.0 Customer 84 at (6012, 1320) not at home
# [ 0] 18:30:47.0 Driver drives to Customer 96 at (8035, 2380)
# [ 0] 18:43:07.0 Driver arrived at Customer 96 at (8035, 2380)
# [ 0] 18:44:07.0 Customer 96 at (8035, 2380) not at home
# [ 0] 18:44:07.0 Driver drives to Customer 40 at (3440, 804)
# [ 0] 19:10:40.1 Driver arrived at Customer 40 at (3440, 804)
# [ 0] 19:11:40.1 Customer 40 at (3440, 804) not at home
# [ 0] 19:11:40.1 Driver drives to Customer 19 at (2380, 2717)
# [ 0] 19:23:33.6 Driver arrived at Customer 19 at (2380, 2717)
# [ 0] 19:24:33.6 Customer 19 at (2380, 2717) not at home
# [ 0] 19:24:33.6 Driver drives to Customer 27 at (2653, 8466)
# [ 0] 19:56:11.5 Driver arrived at Customer 27 at (2653, 8466)
# [ 0] 19:56:12.3 Customer 27 at (2653, 8466) answers door
# [ 0] 19:56:12.3 Customer 27 at (2653, 8466) accepts Parcel 1 for cust 27
# [ 0] 19:56:12.7 Customer 27 at (2653, 8466) signs off
# [ 0] 19:56:24.1 Driver drives to Customer 30 at (2771, 8347)
# [ 0] 19:57:04.2 Driver arrived at Customer 30 at (2771, 8347)
# [ 0] 19:58:04.2 Customer 30 at (2771, 8347) not at home
# [ 0] 19:58:04.2 Driver drives to Customer 54 at (3974, 7680)
# [ 0] 20:03:58.9 Driver arrived at Customer 54 at (3974, 7680)
# [ 0] 20:04:58.9 Customer 54 at (3974, 7680) not at home
# [ 0] 20:04:58.9 Driver drives to Customer 72 at (4630, 8740)
# [ 0] 20:11:50.8 Driver arrived at Customer 72 at (4630, 8740)
# [ 0] 20:12:50.8 Customer 72 at (4630, 8740) not at home
# [ 0] 20:12:50.8 Driver drives to Customer 77 at (5326, 8740)
# [ 0] 20:15:37.8 Driver arrived at Customer 77 at (5326, 8740)
# [ 0] 20:16:37.8 Customer 77 at (5326, 8740) not at home
# [ 0] 20:16:37.8 Driver drives to Customer 80 at (5832, 5560)
# [ 0] 20:37:58.9 Driver arrived at Customer 80 at (5832, 5560)
# [ 0] 20:38:58.9 Customer 80 at (5832, 5560) not at home
# [ 0] 20:38:58.9 Driver drives to Customer 89 at (6620, 5719)
# [ 0] 20:42:46.2 Driver arrived at Customer 89 at (6620, 5719)
# [ 0] 20:43:46.2 Customer 89 at (6620, 5719) not at home
# [ 0] 20:43:46.2 Driver drives to Customer 92 at (6620, 6190)
# [ 0] 20:45:39.2 Driver arrived at Customer 92 at (6620, 6190)
# [ 0] 20:46:39.2 Customer 92 at (6620, 6190) not at home
# [ 0] 20:46:39.2 Driver returns to delivery centre
# [ 0] 21:01:53.6 Driver arrived at delivery centre
# [ 0] 21:01:53.6 Parcel 7 for cust 79 return from delivery
# [ 0] 21:02:23.6 Parcel 9 for cust 84 return from delivery
# [ 0] 21:02:53.6 Parcel 13 for cust 96 return from delivery
# [ 0] 21:03:23.6 Parcel 14 for cust 96 return from delivery
# [ 0] 21:03:53.6 Parcel 3 for cust 40 return from delivery
# [ 0] 21:04:23.6 Parcel 0 for cust 19 return from delivery
# [ 0] 21:04:53.6 Parcel 2 for cust 30 return from delivery
# [ 0] 21:05:23.6 Parcel 4 for cust 54 return from delivery
# [ 0] 21:05:53.6 Parcel 5 for cust 72 return from delivery
# [ 0] 21:06:23.6 Parcel 6 for cust 77 return from delivery
# [ 0] 21:06:53.6 Parcel 8 for cust 80 return from delivery
# [ 0] 21:07:23.6 Parcel 10 for cust 89 return from delivery
# [ 0] 21:07:53.6 Parcel 11 for cust 89 return from delivery
# [ 0] 21:08:23.6 Parcel 12 for cust 92 return from delivery
# [ 0] 21:08:53.6 14 parcels left for next day
# [ 0] 21:18:53.6 Driver goes home
# [ 1] 17:00:00.0 Parcel 15 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 16 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 34 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 35 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 97 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 1] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 34 out for delivery
# [ 1] 18:00:00.0 Parcel 0 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 1] 18:12:30.0 Driver leaves for delivery of 15 parcels to 13 customers
# [ 1] 18:12:30.0 Length of delivery tour: 39,698m
# [ 1] 18:12:30.0 Driver drives to Customer 72 at (4630, 8740)
# [ 1] 18:29:58.8 Driver arrived at Customer 72 at (4630, 8740)
# [ 1] 18:30:58.8 Customer 72 at (4630, 8740) not at home
# [ 1] 18:30:58.8 Driver drives to Customer 77 at (5326, 8740)
# [ 1] 18:33:45.8 Driver arrived at Customer 77 at (5326, 8740)
# [ 1] 18:34:45.8 Customer 77 at (5326, 8740) not at home
# [ 1] 18:34:45.8 Driver drives to Customer 54 at (3974, 7680)
# [ 1] 18:44:24.7 Driver arrived at Customer 54 at (3974, 7680)
# [ 1] 18:45:24.7 Customer 54 at (3974, 7680) not at home
# [ 1] 18:45:24.7 Driver drives to Customer 32 at (2925, 8194)
# [ 1] 18:50:27.4 Driver arrived at Customer 32 at (2925, 8194)
# [ 1] 18:51:27.4 Customer 32 at (2925, 8194) not at home
# [ 1] 18:51:27.4 Driver drives to Customer 30 at (2771, 8347)
# [ 1] 18:52:19.4 Driver arrived at Customer 30 at (2771, 8347)
# [ 1] 18:53:19.4 Customer 30 at (2771, 8347) not at home
# [ 1] 18:53:19.4 Driver drives to Customer 11 at (2223, 8583)
# [ 1] 18:56:25.7 Driver arrived at Customer 11 at (2223, 8583)
# [ 1] 18:57:25.7 Customer 11 at (2223, 8583) not at home
# [ 1] 18:57:25.7 Driver drives to Customer 80 at (5832, 5560)
# [ 1] 19:22:21.4 Driver arrived at Customer 80 at (5832, 5560)
# [ 1] 19:23:21.4 Customer 80 at (5832, 5560) not at home
# [ 1] 19:23:21.4 Driver drives to Customer 34 at (3063, 2380)
# [ 1] 19:47:09.1 Driver arrived at Customer 34 at (3063, 2380)
# [ 1] 19:48:09.1 Customer 34 at (3063, 2380) not at home
# [ 1] 19:48:09.1 Driver drives to Customer 19 at (2380, 2717)
# [ 1] 19:52:13.9 Driver arrived at Customer 19 at (2380, 2717)
# [ 1] 19:52:41.5 Customer 19 at (2380, 2717) answers door
# [ 1] 19:52:41.5 Customer 19 at (2380, 2717) accepts Parcel 0 for cust 19
# [ 1] 19:52:52.6 Customer 19 at (2380, 2717) signs off
# [ 1] 19:52:54.9 Driver drives to Customer 40 at (3440, 804)
# [ 1] 20:04:48.4 Driver arrived at Customer 40 at (3440, 804)
# [ 1] 20:05:48.4 Customer 40 at (3440, 804) not at home
# [ 1] 20:05:48.4 Driver drives to Customer 79 at (5736, 1320)
# [ 1] 20:18:55.4 Driver arrived at Customer 79 at (5736, 1320)
# [ 1] 20:19:55.4 Customer 79 at (5736, 1320) not at home
# [ 1] 20:19:55.4 Driver drives to Customer 84 at (6012, 1320)
# [ 1] 20:21:01.6 Driver arrived at Customer 84 at (6012, 1320)
# [ 1] 20:22:01.6 Customer 84 at (6012, 1320) not at home
# [ 1] 20:22:01.6 Driver drives to Customer 96 at (8035, 2380)
# [ 1] 20:34:21.5 Driver arrived at Customer 96 at (8035, 2380)
# [ 1] 20:35:21.5 Customer 96 at (8035, 2380) not at home
# [ 1] 20:35:21.5 Driver returns to delivery centre
# [ 1] 21:03:58.5 Driver arrived at delivery centre
# [ 1] 21:03:58.5 Parcel 5 for cust 72 return from delivery
# [ 1] 21:04:28.5 Parcel 6 for cust 77 return from delivery
# [ 1] 21:04:58.5 Parcel 4 for cust 54 return from delivery
# [ 1] 21:05:28.5 Parcel 16 for cust 32 return from delivery
# [ 1] 21:05:58.5 Parcel 2 for cust 30 return from delivery
# [ 1] 21:06:28.5 Parcel 15 for cust 11 return from delivery
# [ 1] 21:06:58.5 Parcel 8 for cust 80 return from delivery
# [ 1] 21:07:28.5 Parcel 17 for cust 34 return from delivery
# [ 1] 21:07:58.5 Parcel 3 for cust 40 return from delivery
# [ 1] 21:08:28.5 Parcel 7 for cust 79 return from delivery
# [ 1] 21:08:58.5 Parcel 20 for cust 79 return from delivery
# [ 1] 21:09:28.5 Parcel 9 for cust 84 return from delivery
# [ 1] 21:09:58.5 Parcel 13 for cust 96 return from delivery
# [ 1] 21:10:28.5 Parcel 14 for cust 96 return from delivery
# [ 1] 21:10:58.5 21 parcels left for next day
# [ 1] 21:20:58.5 Driver goes home
# [ 2] 17:00:00.0 Parcel 23 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 24 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 25 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 26 for cust 25 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 27 for cust 38 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 28 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 29 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 30 for cust 77 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 31 for cust 78 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 32 for cust 90 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 33 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 34 for cust 94 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 29 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 18 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 2] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 13 for cust 96 out for delivery
# [ 2] 18:00:00.0 Parcel 14 for cust 96 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 5 for cust 72 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 77 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 93 out for delivery
# [ 2] 18:21:40.0 Driver leaves for delivery of 26 parcels to 21 customers
# [ 2] 18:21:40.0 Length of delivery tour: 39,743m
# [ 2] 18:21:40.0 Driver drives to Customer 62 at (4500, 4006)
# [ 2] 18:23:38.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 2] 18:24:38.6 Customer 62 at (4500, 4006) to slow to answer the door
# [ 2] 18:24:38.6 Driver drives to Customer 40 at (3440, 804)
# [ 2] 18:41:41.4 Driver arrived at Customer 40 at (3440, 804)
# [ 2] 18:42:41.4 Customer 40 at (3440, 804) not at home
# [ 2] 18:42:41.4 Driver drives to Customer 38 at (3440, 440)
# [ 2] 18:44:08.8 Driver arrived at Customer 38 at (3440, 440)
# [ 2] 18:45:08.8 Customer 38 at (3440, 440) not at home
# [ 2] 18:45:08.8 Driver drives to Customer 35 at (3192, 260)
# [ 2] 18:46:51.5 Driver arrived at Customer 35 at (3192, 260)
# [ 2] 18:47:51.5 Customer 35 at (3192, 260) not at home
# [ 2] 18:47:51.5 Driver drives to Customer 79 at (5736, 1320)
# [ 2] 18:59:47.4 Driver arrived at Customer 79 at (5736, 1320)
# [ 2] 19:00:47.4 Customer 79 at (5736, 1320) not at home
# [ 2] 19:00:47.4 Driver drives to Customer 84 at (6012, 1320)
# [ 2] 19:01:53.7 Driver arrived at Customer 84 at (6012, 1320)
# [ 2] 19:02:53.7 Customer 84 at (6012, 1320) not at home
# [ 2] 19:02:53.7 Driver drives to Customer 96 at (8035, 2380)
# [ 2] 19:15:13.6 Driver arrived at Customer 96 at (8035, 2380)
# [ 2] 19:15:59.3 Customer 96 at (8035, 2380) answers door
# [ 2] 19:15:59.3 Customer 96 at (8035, 2380) accepts Parcel 13 for cust 96
# [ 2] 19:16:15.9 Customer 96 at (8035, 2380) accepts Parcel 14 for cust 96
# [ 2] 19:16:23.2 Customer 96 at (8035, 2380) signs off
# [ 2] 19:16:38.6 Driver drives to Customer 97 at (8360, 2380)
# [ 2] 19:17:56.6 Driver arrived at Customer 97 at (8360, 2380)
# [ 2] 19:18:56.6 Customer 97 at (8360, 2380) not at home
# [ 2] 19:18:56.6 Driver drives to Customer 76 at (5226, 1653)
# [ 2] 19:36:16.1 Driver arrived at Customer 76 at (5226, 1653)
# [ 2] 19:37:16.1 Customer 76 at (5226, 1653) not at home
# [ 2] 19:37:16.1 Driver drives to Customer 72 at (4630, 8740)
# [ 2] 20:07:20.2 Driver arrived at Customer 72 at (4630, 8740)
# [ 2] 20:08:20.2 Customer 72 at (4630, 8740) not at home
# [ 2] 20:08:20.2 Driver drives to Customer 77 at (5326, 8740)
# [ 2] 20:11:07.2 Driver arrived at Customer 77 at (5326, 8740)
# [ 2] 20:12:07.2 Customer 77 at (5326, 8740) not at home
# [ 2] 20:12:07.2 Driver drives to Customer 78 at (5419, 8740)
# [ 2] 20:12:29.5 Driver arrived at Customer 78 at (5419, 8740)
# [ 2] 20:13:29.5 Customer 78 at (5419, 8740) not at home
# [ 2] 20:13:29.5 Driver drives to Customer 54 at (3974, 7680)
# [ 2] 20:23:30.7 Driver arrived at Customer 54 at (3974, 7680)
# [ 2] 20:24:30.7 Customer 54 at (3974, 7680) not at home
# [ 2] 20:24:30.7 Driver drives to Customer 50 at (3623, 7680)
# [ 2] 20:25:55.0 Driver arrived at Customer 50 at (3623, 7680)
# [ 2] 20:26:55.0 Customer 50 at (3623, 7680) not at home
# [ 2] 20:26:55.0 Driver drives to Customer 32 at (2925, 8194)
# [ 2] 20:30:33.4 Driver arrived at Customer 32 at (2925, 8194)
# [ 2] 20:31:33.4 Customer 32 at (2925, 8194) not at home
# [ 2] 20:31:33.4 Driver drives to Customer 30 at (2771, 8347)
# [ 2] 20:32:25.4 Driver arrived at Customer 30 at (2771, 8347)
# [ 2] 20:33:25.4 Customer 30 at (2771, 8347) not at home
# [ 2] 20:33:25.4 Driver drives to Customer 80 at (5832, 5560)
# [ 2] 20:55:14.9 Driver arrived at Customer 80 at (5832, 5560)
# [ 2] 20:56:14.9 Customer 80 at (5832, 5560) not at home
# [ 2] 20:56:14.9 Driver drives to Customer 89 at (6620, 5719)
# [ 2] 21:00:02.2 Driver arrived at Customer 89 at (6620, 5719)
# [ 2] 21:01:02.2 Customer 89 at (6620, 5719) not at home
# [ 2] 21:01:02.2 Driver drives to Customer 90 at (6620, 5883)
# [ 2] 21:01:41.5 Driver arrived at Customer 90 at (6620, 5883)
# [ 2] 21:02:41.5 Customer 90 at (6620, 5883) not at home
# [ 2] 21:02:41.5 Driver drives to Customer 92 at (6620, 6190)
# [ 2] 21:03:55.2 Driver arrived at Customer 92 at (6620, 6190)
# [ 2] 21:04:55.2 Customer 92 at (6620, 6190) not at home
# [ 2] 21:04:55.2 Driver drives to Customer 93 at (6620, 6302)
# [ 2] 21:05:22.1 Driver arrived at Customer 93 at (6620, 6302)
# [ 2] 21:06:22.1 Customer 93 at (6620, 6302) not at home
# [ 2] 21:06:22.1 Driver returns to delivery centre
# [ 2] 21:22:03.4 Driver arrived at delivery centre
# [ 2] 21:22:03.4 Parcel 29 for cust 62 return from delivery
# [ 2] 21:22:33.4 Parcel 3 for cust 40 return from delivery
# [ 2] 21:23:03.4 Parcel 27 for cust 38 return from delivery
# [ 2] 21:23:33.4 Parcel 18 for cust 35 return from delivery
# [ 2] 21:24:03.4 Parcel 7 for cust 79 return from delivery
# [ 2] 21:24:33.4 Parcel 20 for cust 79 return from delivery
# [ 2] 21:25:03.4 Parcel 9 for cust 84 return from delivery
# [ 2] 21:25:33.4 Parcel 22 for cust 97 return from delivery
# [ 2] 21:26:03.4 Parcel 19 for cust 76 return from delivery
# [ 2] 21:26:33.4 Parcel 5 for cust 72 return from delivery
# [ 2] 21:27:03.4 Parcel 6 for cust 77 return from delivery
# [ 2] 21:27:33.4 Parcel 30 for cust 77 return from delivery
# [ 2] 21:28:03.4 Parcel 31 for cust 78 return from delivery
# [ 2] 21:28:33.4 Parcel 4 for cust 54 return from delivery
# [ 2] 21:29:03.4 Parcel 28 for cust 50 return from delivery
# [ 2] 21:29:33.4 Parcel 16 for cust 32 return from delivery
# [ 2] 21:30:03.4 Parcel 2 for cust 30 return from delivery
# [ 2] 21:30:33.4 Parcel 8 for cust 80 return from delivery
# [ 2] 21:31:03.4 Parcel 10 for cust 89 return from delivery
# [ 2] 21:31:33.4 Parcel 11 for cust 89 return from delivery
# [ 2] 21:32:03.4 Parcel 21 for cust 90 return from delivery
# [ 2] 21:32:33.4 Parcel 32 for cust 90 return from delivery
# [ 2] 21:33:03.4 Parcel 12 for cust 92 return from delivery
# [ 2] 21:33:33.4 Parcel 33 for cust 93 return from delivery
# [ 2] 21:34:03.4 31 parcels left for next day
# [ 2] 21:44:03.4 Driver goes home
# [ 3] 17:00:00.0 Parcel 35 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 36 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 37 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 38 for cust 37 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 39 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 40 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 41 for cust 50 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 42 for cust 61 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 43 for cust 68 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 44 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 45 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 46 for cust 92 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 47 for cust 93 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 8 for cust 80 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 89 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 32 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 45 for cust 90 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 92 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 92 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 93 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 94 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 54 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 16 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 30 out for delivery
# [ 3] 18:00:00.0 Parcel 15 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 24 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 23 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 35 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 18 for cust 35 out for delivery
# [ 3] 18:00:00.0 Parcel 27 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 48 out for delivery
# [ 3] 18:00:00.0 Parcel 38 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 17 for cust 34 out for delivery
# [ 3] 18:00:00.0 Parcel 19 for cust 76 out for delivery
# [ 3] 18:00:00.0 Parcel 7 for cust 79 out for delivery
# [ 3] 18:00:00.0 Parcel 20 for cust 79 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 84 out for delivery
# [ 3] 18:00:00.0 Parcel 22 for cust 97 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 29 for cust 62 out for delivery
# [ 3] 18:31:40.0 Driver leaves for delivery of 38 parcels to 31 customers
# [ 3] 18:31:40.0 Length of delivery tour: 39,934m
# [ 3] 18:31:40.0 Driver drives to Customer 80 at (5832, 5560)
# [ 3] 18:41:14.1 Driver arrived at Customer 80 at (5832, 5560)
# [ 3] 18:42:14.1 Customer 80 at (5832, 5560) not at home
# [ 3] 18:42:14.1 Driver drives to Customer 89 at (6620, 5719)
# [ 3] 18:46:01.4 Driver arrived at Customer 89 at (6620, 5719)
# [ 3] 18:47:01.4 Customer 89 at (6620, 5719) not at home
# [ 3] 18:47:01.4 Driver drives to Customer 90 at (6620, 5883)
# [ 3] 18:47:40.7 Driver arrived at Customer 90 at (6620, 5883)
# [ 3] 18:48:40.7 Customer 90 at (6620, 5883) not at home
# [ 3] 18:48:40.7 Driver drives to Customer 92 at (6620, 6190)
# [ 3] 18:49:54.4 Driver arrived at Customer 92 at (6620, 6190)
# [ 3] 18:50:54.4 Customer 92 at (6620, 6190) not at home
# [ 3] 18:50:54.4 Driver drives to Customer 93 at (6620, 6302)
# [ 3] 18:51:21.3 Driver arrived at Customer 93 at (6620, 6302)
# [ 3] 18:52:21.3 Customer 93 at (6620, 6302) not at home
# [ 3] 18:52:21.3 Driver drives to Customer 94 at (6620, 6483)
# [ 3] 18:53:04.7 Driver arrived at Customer 94 at (6620, 6483)
# [ 3] 18:53:26.3 Customer 94 at (6620, 6483) answers door
# [ 3] 18:53:26.3 Customer 94 at (6620, 6483) accepts Parcel 34 for cust 94
# [ 3] 18:53:39.3 Customer 94 at (6620, 6483) signs off
# [ 3] 18:53:43.2 Driver drives to Customer 68 at (4500, 6293)
# [ 3] 19:08:49.5 Driver arrived at Customer 68 at (4500, 6293)
# [ 3] 19:09:49.5 Customer 68 at (4500, 6293) not at home
# [ 3] 19:09:49.5 Driver drives to Customer 54 at (3974, 7680)
# [ 3] 19:17:28.6 Driver arrived at Customer 54 at (3974, 7680)
# [ 3] 19:18:28.6 Customer 54 at (3974, 7680) not at home
# [ 3] 19:18:28.6 Driver drives to Customer 50 at (3623, 7680)
# [ 3] 19:19:52.8 Driver arrived at Customer 50 at (3623, 7680)
# [ 3] 19:20:52.8 Customer 50 at (3623, 7680) not at home
# [ 3] 19:20:52.8 Driver drives to Customer 32 at (2925, 8194)
# [ 3] 19:24:31.2 Driver arrived at Customer 32 at (2925, 8194)
# [ 3] 19:25:31.2 Customer 32 at (2925, 8194) not at home
# [ 3] 19:25:31.2 Driver drives to Customer 30 at (2771, 8347)
# [ 3] 19:26:23.3 Driver arrived at Customer 30 at (2771, 8347)
# [ 3] 19:27:23.3 Customer 30 at (2771, 8347) not at home
# [ 3] 19:27:23.3 Driver drives to Customer 11 at (2223, 8583)
# [ 3] 19:30:29.5 Driver arrived at Customer 11 at (2223, 8583)
# [ 3] 19:31:29.5 Customer 11 at (2223, 8583) not at home
# [ 3] 19:31:29.5 Driver drives to Customer 9 at (2051, 8411)
# [ 3] 19:32:27.9 Driver arrived at Customer 9 at (2051, 8411)
# [ 3] 19:33:27.9 Customer 9 at (2051, 8411) not at home
# [ 3] 19:33:27.9 Driver drives to Customer 5 at (1495, 7855)
# [ 3] 19:36:36.5 Driver arrived at Customer 5 at (1495, 7855)
# [ 3] 19:37:36.5 Customer 5 at (1495, 7855) not at home
# [ 3] 19:37:36.5 Driver drives to Customer 4 at (1320, 7483)
# [ 3] 19:39:23.1 Driver arrived at Customer 4 at (1320, 7483)
# [ 3] 19:40:23.1 Customer 4 at (1320, 7483) not at home
# [ 3] 19:40:23.1 Driver drives to Customer 2 at (1320, 6990)
# [ 3] 19:42:21.4 Driver arrived at Customer 2 at (1320, 6990)
# [ 3] 19:43:21.4 Customer 2 at (1320, 6990) not at home
# [ 3] 19:43:21.4 Driver drives to Customer 25 at (2380, 4319)
# [ 3] 19:58:16.8 Driver arrived at Customer 25 at (2380, 4319)
# [ 3] 19:58:25.9 Customer 25 at (2380, 4319) answers door
# [ 3] 19:58:25.9 Customer 25 at (2380, 4319) accepts Parcel 26 for cust 25
# [ 3] 19:58:29.4 Customer 25 at (2380, 4319) signs off
# [ 3] 19:58:35.8 Driver drives to Customer 15 at (2380, 1445)
# [ 3] 20:10:05.5 Driver arrived at Customer 15 at (2380, 1445)
# [ 3] 20:11:05.5 Customer 15 at (2380, 1445) not at home
# [ 3] 20:11:05.5 Driver drives to Customer 28 at (2727, 260)
# [ 3] 20:17:13.2 Driver arrived at Customer 28 at (2727, 260)
# [ 3] 20:18:13.2 Customer 28 at (2727, 260) not at home
# [ 3] 20:18:13.2 Driver drives to Customer 35 at (3192, 260)
# [ 3] 20:20:04.8 Driver arrived at Customer 35 at (3192, 260)
# [ 3] 20:21:04.8 Customer 35 at (3192, 260) not at home
# [ 3] 20:21:04.8 Driver drives to Customer 38 at (3440, 440)
# [ 3] 20:22:47.5 Driver arrived at Customer 38 at (3440, 440)
# [ 3] 20:23:47.5 Customer 38 at (3440, 440) not at home
# [ 3] 20:23:47.5 Driver drives to Customer 40 at (3440, 804)
# [ 3] 20:25:14.9 Driver arrived at Customer 40 at (3440, 804)
# [ 3] 20:26:14.9 Customer 40 at (3440, 804) not at home
# [ 3] 20:26:14.9 Driver drives to Customer 48 at (3440, 2229)
# [ 3] 20:31:56.9 Driver arrived at Customer 48 at (3440, 2229)
# [ 3] 20:32:56.9 Customer 48 at (3440, 2229) to slow to answer the door
# [ 3] 20:32:56.9 Driver drives to Customer 37 at (3305, 2380)
# [ 3] 20:34:05.5 Driver arrived at Customer 37 at (3305, 2380)
# [ 3] 20:35:05.5 Customer 37 at (3305, 2380) not at home
# [ 3] 20:35:05.5 Driver drives to Customer 34 at (3063, 2380)
# [ 3] 20:36:03.6 Driver arrived at Customer 34 at (3063, 2380)
# [ 3] 20:37:03.6 Customer 34 at (3063, 2380) to slow to answer the door
# [ 3] 20:37:03.6 Driver drives to Customer 76 at (5226, 1653)
# [ 3] 20:48:07.5 Driver arrived at Customer 76 at (5226, 1653)
# [ 3] 20:49:07.5 Customer 76 at (5226, 1653) not at home
# [ 3] 20:49:07.5 Driver drives to Customer 79 at (5736, 1320)
# [ 3] 20:51:42.7 Driver arrived at Customer 79 at (5736, 1320)
# [ 3] 20:52:42.7 Customer 79 at (5736, 1320) not at home
# [ 3] 20:52:42.7 Driver drives to Customer 84 at (6012, 1320)
# [ 3] 20:53:49.0 Driver arrived at Customer 84 at (6012, 1320)
# [ 3] 20:54:49.0 Customer 84 at (6012, 1320) not at home
# [ 3] 20:54:49.0 Driver drives to Customer 97 at (8360, 2380)
# [ 3] 21:08:26.9 Driver arrived at Customer 97 at (8360, 2380)
# [ 3] 21:09:26.9 Customer 97 at (8360, 2380) not at home
# [ 3] 21:09:26.9 Driver drives to Customer 61 at (4500, 3324)
# [ 3] 21:34:39.4 Driver arrived at Customer 61 at (4500, 3324)
# [ 3] 21:35:39.4 Customer 61 at (4500, 3324) not at home
# [ 3] 21:35:39.4 Driver drives to Customer 62 at (4500, 4006)
# [ 3] 21:38:23.1 Driver arrived at Customer 62 at (4500, 4006)
# [ 3] 21:39:23.1 Customer 62 at (4500, 4006) not at home
# [ 3] 21:39:23.1 Driver returns to delivery centre
# [ 3] 21:41:21.6 Driver arrived at delivery centre
# [ 3] 21:41:21.6 Parcel 8 for cust 80 return from delivery
# [ 3] 21:41:51.6 Parcel 10 for cust 89 return from delivery
# [ 3] 21:42:21.6 Parcel 11 for cust 89 return from delivery
# [ 3] 21:42:51.6 Parcel 21 for cust 90 return from delivery
# [ 3] 21:43:21.6 Parcel 32 for cust 90 return from delivery
# [ 3] 21:43:51.6 Parcel 45 for cust 90 return from delivery
# [ 3] 21:44:21.6 Parcel 12 for cust 92 return from delivery
# [ 3] 21:44:51.6 Parcel 46 for cust 92 return from delivery
# [ 3] 21:45:21.6 Parcel 33 for cust 93 return from delivery
# [ 3] 21:45:51.6 Parcel 47 for cust 93 return from delivery
# [ 3] 21:46:21.6 Parcel 43 for cust 68 return from delivery
# [ 3] 21:46:51.6 Parcel 4 for cust 54 return from delivery
# [ 3] 21:47:21.6 Parcel 28 for cust 50 return from delivery
# [ 3] 21:47:51.6 Parcel 41 for cust 50 return from delivery
# [ 3] 21:48:21.6 Parcel 16 for cust 32 return from delivery
# [ 3] 21:48:51.6 Parcel 2 for cust 30 return from delivery
# [ 3] 21:49:21.6 Parcel 15 for cust 11 return from delivery
# [ 3] 21:49:51.6 Parcel 24 for cust 9 return from delivery
# [ 3] 21:50:21.6 Parcel 23 for cust 5 return from delivery
# [ 3] 21:50:51.6 Parcel 36 for cust 4 return from delivery
# [ 3] 21:51:21.6 Parcel 35 for cust 2 return from delivery
# [ 3] 21:51:51.6 Parcel 25 for cust 15 return from delivery
# [ 3] 21:52:21.6 Parcel 37 for cust 28 return from delivery
# [ 3] 21:52:51.6 Parcel 18 for cust 35 return from delivery
# [ 3] 21:53:21.6 Parcel 27 for cust 38 return from delivery
# [ 3] 21:53:51.6 Parcel 3 for cust 40 return from delivery
# [ 3] 21:54:21.6 Parcel 39 for cust 48 return from delivery
# [ 3] 21:54:51.6 Parcel 38 for cust 37 return from delivery
# [ 3] 21:55:21.6 Parcel 17 for cust 34 return from delivery
# [ 3] 21:55:51.6 Parcel 19 for cust 76 return from delivery
# [ 3] 21:56:21.6 Parcel 7 for cust 79 return from delivery
# [ 3] 21:56:51.6 Parcel 20 for cust 79 return from delivery
# [ 3] 21:57:21.6 Parcel 9 for cust 84 return from delivery
# [ 3] 21:57:51.6 Parcel 22 for cust 97 return from delivery
# [ 3] 21:58:21.6 Parcel 42 for cust 61 return from delivery
# [ 3] 21:58:51.6 Parcel 29 for cust 62 return from delivery
# [ 3] 21:59:21.6 42 parcels left for next day
# [ 3] 22:09:21.6 Driver goes home
# Delivery Centre Inventory: 42 parcels

# %%
rec2 = simulation(M, W, C, p=0.3, days=4, seed=1, log=True, plot=True)
# Out:
# Simulating delivery of 117 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 0 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 2 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 4 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 4 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 9 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 9 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 11 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 11 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 12 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 25 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 35 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 41 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 57 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 60 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 24 for cust 64 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 25 for cust 65 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 26 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 27 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 28 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 29 for cust 69 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 30 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 31 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 32 for cust 82 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 33 for cust 88 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 34 for cust 93 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 35 for cust 93 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 23 for cust 62 out for delivery
# [ 0] 18:00:00.0 Parcel 22 for cust 60 out for delivery
# [ 0] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 19 for cust 57 out for delivery
# [ 0] 18:00:00.0 Parcel 31 for cust 76 out for delivery
# [ 0] 18:00:00.0 Parcel 33 for cust 88 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 52 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 52 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 35 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 25 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 0 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 4 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 4 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 9 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 9 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 12 out for delivery
# [ 0] 18:00:00.0 Parcel 30 for cust 71 out for delivery
# [ 0] 18:00:00.0 Parcel 32 for cust 82 out for delivery
# [ 0] 18:00:00.0 Parcel 29 for cust 69 out for delivery
# [ 0] 18:00:00.0 Parcel 26 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 27 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 28 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 25 for cust 65 out for delivery
# [ 0] 18:00:00.0 Parcel 34 for cust 93 out for delivery
# [ 0] 18:00:00.0 Parcel 35 for cust 93 out for delivery
# [ 0] 18:00:00.0 Parcel 24 for cust 64 out for delivery
# [ 0] 18:30:00.0 Driver leaves for delivery of 36 parcels to 28 customers
# [ 0] 18:30:00.0 Length of delivery tour: 37,451m
# [ 0] 18:30:00.0 Driver drives to Customer 62 at (4500, 4006)
# [ 0] 18:31:58.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 0] 18:32:58.6 Customer 62 at (4500, 4006) not at home
# [ 0] 18:32:58.6 Driver drives to Customer 60 at (4500, 3173)
# [ 0] 18:36:18.5 Driver arrived at Customer 60 at (4500, 3173)
# [ 0] 18:37:18.5 Customer 60 at (4500, 3173) not at home
# [ 0] 18:37:18.5 Driver drives to Customer 59 at (4500, 3088)
# [ 0] 18:37:38.9 Driver arrived at Customer 59 at (4500, 3088)
# [ 0] 18:38:38.9 Customer 59 at (4500, 3088) not at home
# [ 0] 18:38:38.9 Driver drives to Customer 57 at (4500, 2596)
# [ 0] 18:40:37.0 Driver arrived at Customer 57 at (4500, 2596)
# [ 0] 18:41:08.4 Customer 57 at (4500, 2596) answers door
# [ 0] 18:41:08.4 Customer 57 at (4500, 2596) accepts Parcel 19 for cust 57
# [ 0] 18:41:17.0 Customer 57 at (4500, 2596) signs off
# [ 0] 18:41:26.1 Driver drives to Customer 76 at (5226, 1653)
# [ 0] 18:46:24.4 Driver arrived at Customer 76 at (5226, 1653)
# [ 0] 18:47:24.4 Customer 76 at (5226, 1653) not at home
# [ 0] 18:47:24.4 Driver drives to Customer 88 at (6370, 1320)
# [ 0] 18:52:31.9 Driver arrived at Customer 88 at (6370, 1320)
# [ 0] 18:53:31.9 Customer 88 at (6370, 1320) not at home
# [ 0] 18:53:31.9 Driver drives to Customer 52 at (3769, 260)
# [ 0] 19:05:41.5 Driver arrived at Customer 52 at (3769, 260)
# [ 0] 19:06:41.5 Customer 52 at (3769, 260) not at home
# [ 0] 19:06:41.5 Driver drives to Customer 35 at (3192, 260)
# [ 0] 19:08:59.9 Driver arrived at Customer 35 at (3192, 260)
# [ 0] 19:09:11.2 Customer 35 at (3192, 260) answers door
# [ 0] 19:09:11.2 Customer 35 at (3192, 260) accepts Parcel 14 for cust 35
# [ 0] 19:09:11.4 Customer 35 at (3192, 260) signs off
# [ 0] 19:09:14.2 Driver drives to Customer 38 at (3440, 440)
# [ 0] 19:10:56.9 Driver arrived at Customer 38 at (3440, 440)
# [ 0] 19:11:56.9 Customer 38 at (3440, 440) not at home
# [ 0] 19:11:56.9 Driver drives to Customer 41 at (3440, 960)
# [ 0] 19:14:01.7 Driver arrived at Customer 41 at (3440, 960)
# [ 0] 19:15:01.7 Customer 41 at (3440, 960) not at home
# [ 0] 19:15:01.7 Driver drives to Customer 15 at (2380, 1445)
# [ 0] 19:21:12.5 Driver arrived at Customer 15 at (2380, 1445)
# [ 0] 19:21:15.5 Customer 15 at (2380, 1445) answers door
# [ 0] 19:21:15.5 Customer 15 at (2380, 1445) accepts Parcel 11 for cust 15
# [ 0] 19:21:23.5 Customer 15 at (2380, 1445) signs off
# [ 0] 19:21:24.3 Driver drives to Customer 17 at (2380, 1652)
# [ 0] 19:22:13.9 Driver arrived at Customer 17 at (2380, 1652)
# [ 0] 19:23:13.9 Customer 17 at (2380, 1652) not at home
# [ 0] 19:23:13.9 Driver drives to Customer 6 at (1542, 3440)
# [ 0] 19:33:44.2 Driver arrived at Customer 6 at (1542, 3440)
# [ 0] 19:34:44.2 Customer 6 at (1542, 3440) not at home
# [ 0] 19:34:44.2 Driver drives to Customer 25 at (2380, 4319)
# [ 0] 19:41:36.3 Driver arrived at Customer 25 at (2380, 4319)
# [ 0] 19:42:36.3 Customer 25 at (2380, 4319) not at home
# [ 0] 19:42:36.3 Driver drives to Customer 0 at (1320, 5886)
# [ 0] 19:53:06.7 Driver arrived at Customer 0 at (1320, 5886)
# [ 0] 19:53:09.9 Customer 0 at (1320, 5886) answers door
# [ 0] 19:53:09.9 Customer 0 at (1320, 5886) accepts Parcel 0 for cust 0
# [ 0] 19:53:20.0 Customer 0 at (1320, 5886) signs off
# [ 0] 19:53:23.4 Driver drives to Customer 2 at (1320, 6990)
# [ 0] 19:57:48.4 Driver arrived at Customer 2 at (1320, 6990)
# [ 0] 19:58:48.4 Customer 2 at (1320, 6990) not at home
# [ 0] 19:58:48.4 Driver drives to Customer 4 at (1320, 7483)
# [ 0] 20:00:46.7 Driver arrived at Customer 4 at (1320, 7483)
# [ 0] 20:01:46.7 Customer 4 at (1320, 7483) not at home
# [ 0] 20:01:46.7 Driver drives to Customer 7 at (1577, 7937)
# [ 0] 20:04:01.1 Driver arrived at Customer 7 at (1577, 7937)
# [ 0] 20:05:01.1 Customer 7 at (1577, 7937) not at home
# [ 0] 20:05:01.1 Driver drives to Customer 9 at (2051, 8411)
# [ 0] 20:07:41.9 Driver arrived at Customer 9 at (2051, 8411)
# [ 0] 20:08:41.9 Customer 9 at (2051, 8411) not at home
# [ 0] 20:08:41.9 Driver drives to Customer 11 at (2223, 8583)
# [ 0] 20:09:40.2 Driver arrived at Customer 11 at (2223, 8583)
# [ 0] 20:10:40.2 Customer 11 at (2223, 8583) not at home
# [ 0] 20:10:40.2 Driver drives to Customer 12 at (2294, 8654)
# [ 0] 20:11:04.2 Driver arrived at Customer 12 at (2294, 8654)
# [ 0] 20:12:04.2 Customer 12 at (2294, 8654) not at home
# [ 0] 20:12:04.2 Driver drives to Customer 71 at (4500, 8018)
# [ 0] 20:24:08.5 Driver arrived at Customer 71 at (4500, 8018)
# [ 0] 20:25:08.5 Customer 71 at (4500, 8018) to slow to answer the door
# [ 0] 20:25:08.5 Driver drives to Customer 82 at (5931, 8740)
# [ 0] 20:33:45.2 Driver arrived at Customer 82 at (5931, 8740)
# [ 0] 20:34:45.2 Customer 82 at (5931, 8740) not at home
# [ 0] 20:34:45.2 Driver drives to Customer 69 at (4500, 7022)
# [ 0] 20:47:21.0 Driver arrived at Customer 69 at (4500, 7022)
# [ 0] 20:48:21.0 Customer 69 at (4500, 7022) not at home
# [ 0] 20:48:21.0 Driver drives to Customer 68 at (4500, 6293)
# [ 0] 20:51:16.0 Driver arrived at Customer 68 at (4500, 6293)
# [ 0] 20:52:16.0 Customer 68 at (4500, 6293) not at home
# [ 0] 20:52:16.0 Driver drives to Customer 65 at (4500, 5794)
# [ 0] 20:54:15.7 Driver arrived at Customer 65 at (4500, 5794)
# [ 0] 20:54:42.9 Customer 65 at (4500, 5794) answers door
# [ 0] 20:54:42.9 Customer 65 at (4500, 5794) accepts Parcel 25 for cust 65
# [ 0] 20:55:02.8 Customer 65 at (4500, 5794) signs off
# [ 0] 20:55:04.4 Driver drives to Customer 93 at (6620, 6302)
# [ 0] 21:07:27.5 Driver arrived at Customer 93 at (6620, 6302)
# [ 0] 21:08:27.5 Customer 93 at (6620, 6302) not at home
# [ 0] 21:08:27.5 Driver drives to Customer 64 at (4500, 4955)
# [ 0] 21:22:19.5 Driver arrived at Customer 64 at (4500, 4955)
# [ 0] 21:23:19.5 Customer 64 at (4500, 4955) not at home
# [ 0] 21:23:19.5 Driver returns to delivery centre
# [ 0] 21:25:08.7 Driver arrived at delivery centre
# [ 0] 21:25:08.7 Parcel 23 for cust 62 return from delivery
# [ 0] 21:25:38.7 Parcel 22 for cust 60 return from delivery
# [ 0] 21:26:08.7 Parcel 20 for cust 59 return from delivery
# [ 0] 21:26:38.7 Parcel 21 for cust 59 return from delivery
# [ 0] 21:27:08.7 Parcel 31 for cust 76 return from delivery
# [ 0] 21:27:38.7 Parcel 33 for cust 88 return from delivery
# [ 0] 21:28:08.7 Parcel 17 for cust 52 return from delivery
# [ 0] 21:28:38.7 Parcel 18 for cust 52 return from delivery
# [ 0] 21:29:08.7 Parcel 15 for cust 38 return from delivery
# [ 0] 21:29:38.7 Parcel 16 for cust 41 return from delivery
# [ 0] 21:30:08.7 Parcel 12 for cust 17 return from delivery
# [ 0] 21:30:38.7 Parcel 4 for cust 6 return from delivery
# [ 0] 21:31:08.7 Parcel 13 for cust 25 return from delivery
# [ 0] 21:31:38.7 Parcel 1 for cust 2 return from delivery
# [ 0] 21:32:08.7 Parcel 2 for cust 4 return from delivery
# [ 0] 21:32:38.7 Parcel 3 for cust 4 return from delivery
# [ 0] 21:33:08.7 Parcel 5 for cust 7 return from delivery
# [ 0] 21:33:38.7 Parcel 6 for cust 9 return from delivery
# [ 0] 21:34:08.7 Parcel 7 for cust 9 return from delivery
# [ 0] 21:34:38.7 Parcel 8 for cust 11 return from delivery
# [ 0] 21:35:08.7 Parcel 9 for cust 11 return from delivery
# [ 0] 21:35:38.7 Parcel 10 for cust 12 return from delivery
# [ 0] 21:36:08.7 Parcel 30 for cust 71 return from delivery
# [ 0] 21:36:38.7 Parcel 32 for cust 82 return from delivery
# [ 0] 21:37:08.7 Parcel 29 for cust 69 return from delivery
# [ 0] 21:37:38.7 Parcel 26 for cust 68 return from delivery
# [ 0] 21:38:08.7 Parcel 27 for cust 68 return from delivery
# [ 0] 21:38:38.7 Parcel 28 for cust 68 return from delivery
# [ 0] 21:39:08.7 Parcel 34 for cust 93 return from delivery
# [ 0] 21:39:38.7 Parcel 35 for cust 93 return from delivery
# [ 0] 21:40:08.7 Parcel 24 for cust 64 return from delivery
# [ 0] 21:40:38.7 31 parcels left for next day
# [ 0] 21:50:38.7 Driver goes home
# [ 1] 17:00:00.0 Parcel 36 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 6 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 38 for cust 10 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 39 for cust 12 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 40 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 41 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 42 for cust 17 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 43 for cust 20 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 44 for cust 25 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 45 for cust 26 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 46 for cust 29 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 47 for cust 40 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 48 for cust 47 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 49 for cust 52 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 50 for cust 60 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 51 for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 52 for cust 61 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 53 for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 54 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 55 for cust 74 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 56 for cust 75 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 57 for cust 76 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 58 for cust 78 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 59 for cust 79 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 60 for cust 81 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 61 for cust 89 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 62 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 63 for cust 95 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 64 for cust 98 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 23 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 53 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 61 for cust 89 out for delivery
# [ 1] 18:00:00.0 Parcel 62 for cust 90 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 93 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 93 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 71 out for delivery
# [ 1] 18:00:00.0 Parcel 55 for cust 74 out for delivery
# [ 1] 18:00:00.0 Parcel 56 for cust 75 out for delivery
# [ 1] 18:00:00.0 Parcel 58 for cust 78 out for delivery
# [ 1] 18:00:00.0 Parcel 32 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 10 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 9 out for delivery
# [ 1] 18:00:00.0 Parcel 5 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 4 out for delivery
# [ 1] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 1] 18:00:00.0 Parcel 45 for cust 26 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 25 out for delivery
# [ 1] 18:00:00.0 Parcel 44 for cust 25 out for delivery
# [ 1] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 29 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 40 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 52 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 52 out for delivery
# [ 1] 18:00:00.0 Parcel 49 for cust 52 out for delivery
# [ 1] 18:00:00.0 Parcel 59 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 60 for cust 81 out for delivery
# [ 1] 18:00:00.0 Parcel 33 for cust 88 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 57 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 60 out for delivery
# [ 1] 18:40:50.0 Driver leaves for delivery of 49 parcels to 34 customers
# [ 1] 18:40:50.0 Length of delivery tour: 39,460m
# [ 1] 18:40:50.0 Driver drives to Customer 62 at (4500, 4006)
# [ 1] 18:42:48.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 1] 18:43:48.6 Customer 62 at (4500, 4006) not at home
# [ 1] 18:43:48.6 Driver drives to Customer 89 at (6620, 5719)
# [ 1] 18:59:08.5 Driver arrived at Customer 89 at (6620, 5719)
# [ 1] 19:00:08.5 Customer 89 at (6620, 5719) not at home
# [ 1] 19:00:08.5 Driver drives to Customer 90 at (6620, 5883)
# [ 1] 19:00:47.8 Driver arrived at Customer 90 at (6620, 5883)
# [ 1] 19:01:47.8 Customer 90 at (6620, 5883) not at home
# [ 1] 19:01:47.8 Driver drives to Customer 93 at (6620, 6302)
# [ 1] 19:03:28.4 Driver arrived at Customer 93 at (6620, 6302)
# [ 1] 19:04:28.4 Customer 93 at (6620, 6302) not at home
# [ 1] 19:04:28.4 Driver drives to Customer 71 at (4500, 8018)
# [ 1] 19:25:45.2 Driver arrived at Customer 71 at (4500, 8018)
# [ 1] 19:26:45.2 Customer 71 at (4500, 8018) not at home
# [ 1] 19:26:45.2 Driver drives to Customer 74 at (5079, 8740)
# [ 1] 19:31:57.4 Driver arrived at Customer 74 at (5079, 8740)
# [ 1] 19:32:57.4 Customer 74 at (5079, 8740) not at home
# [ 1] 19:32:57.4 Driver drives to Customer 75 at (5211, 8740)
# [ 1] 19:33:29.1 Driver arrived at Customer 75 at (5211, 8740)
# [ 1] 19:34:29.1 Customer 75 at (5211, 8740) not at home
# [ 1] 19:34:29.1 Driver drives to Customer 78 at (5419, 8740)
# [ 1] 19:35:19.0 Driver arrived at Customer 78 at (5419, 8740)
# [ 1] 19:36:19.0 Customer 78 at (5419, 8740) not at home
# [ 1] 19:36:19.0 Driver drives to Customer 82 at (5931, 8740)
# [ 1] 19:38:21.9 Driver arrived at Customer 82 at (5931, 8740)
# [ 1] 19:39:21.9 Customer 82 at (5931, 8740) not at home
# [ 1] 19:39:21.9 Driver drives to Customer 12 at (2294, 8654)
# [ 1] 20:00:03.0 Driver arrived at Customer 12 at (2294, 8654)
# [ 1] 20:01:03.0 Customer 12 at (2294, 8654) not at home
# [ 1] 20:01:03.0 Driver drives to Customer 11 at (2223, 8583)
# [ 1] 20:01:27.0 Driver arrived at Customer 11 at (2223, 8583)
# [ 1] 20:02:27.0 Customer 11 at (2223, 8583) not at home
# [ 1] 20:02:27.0 Driver drives to Customer 10 at (2155, 8515)
# [ 1] 20:02:50.0 Driver arrived at Customer 10 at (2155, 8515)
# [ 1] 20:03:50.0 Customer 10 at (2155, 8515) not at home
# [ 1] 20:03:50.0 Driver drives to Customer 9 at (2051, 8411)
# [ 1] 20:04:25.3 Driver arrived at Customer 9 at (2051, 8411)
# [ 1] 20:05:25.3 Customer 9 at (2051, 8411) not at home
# [ 1] 20:05:25.3 Driver drives to Customer 7 at (1577, 7937)
# [ 1] 20:08:06.1 Driver arrived at Customer 7 at (1577, 7937)
# [ 1] 20:08:58.4 Customer 7 at (1577, 7937) answers door
# [ 1] 20:08:58.4 Customer 7 at (1577, 7937) accepts Parcel 5 for cust 7
# [ 1] 20:08:58.9 Customer 7 at (1577, 7937) signs off
# [ 1] 20:09:38.6 Driver drives to Customer 5 at (1495, 7855)
# [ 1] 20:10:06.2 Driver arrived at Customer 5 at (1495, 7855)
# [ 1] 20:11:06.2 Customer 5 at (1495, 7855) not at home
# [ 1] 20:11:06.2 Driver drives to Customer 4 at (1320, 7483)
# [ 1] 20:12:52.8 Driver arrived at Customer 4 at (1320, 7483)
# [ 1] 20:13:52.8 Customer 4 at (1320, 7483) to slow to answer the door
# [ 1] 20:13:52.8 Driver drives to Customer 2 at (1320, 6990)
# [ 1] 20:15:51.1 Driver arrived at Customer 2 at (1320, 6990)
# [ 1] 20:16:51.1 Customer 2 at (1320, 6990) not at home
# [ 1] 20:16:51.1 Driver drives to Customer 26 at (2380, 5019)
# [ 1] 20:28:58.5 Driver arrived at Customer 26 at (2380, 5019)
# [ 1] 20:29:58.5 Customer 26 at (2380, 5019) not at home
# [ 1] 20:29:58.5 Driver drives to Customer 25 at (2380, 4319)
# [ 1] 20:32:46.5 Driver arrived at Customer 25 at (2380, 4319)
# [ 1] 20:33:46.5 Customer 25 at (2380, 4319) not at home
# [ 1] 20:33:46.5 Driver drives to Customer 6 at (1542, 3440)
# [ 1] 20:40:38.6 Driver arrived at Customer 6 at (1542, 3440)
# [ 1] 20:41:38.6 Customer 6 at (1542, 3440) not at home
# [ 1] 20:41:38.6 Driver drives to Customer 20 at (2380, 3216)
# [ 1] 20:45:53.5 Driver arrived at Customer 20 at (2380, 3216)
# [ 1] 20:46:53.5 Customer 20 at (2380, 3216) not at home
# [ 1] 20:46:53.5 Driver drives to Customer 17 at (2380, 1652)
# [ 1] 20:53:08.8 Driver arrived at Customer 17 at (2380, 1652)
# [ 1] 20:54:08.8 Customer 17 at (2380, 1652) not at home
# [ 1] 20:54:08.8 Driver drives to Customer 13 at (2380, 561)
# [ 1] 20:58:30.7 Driver arrived at Customer 13 at (2380, 561)
# [ 1] 20:59:30.7 Customer 13 at (2380, 561) not at home
# [ 1] 20:59:30.7 Driver drives to Customer 29 at (2758, 1320)
# [ 1] 21:04:03.6 Driver arrived at Customer 29 at (2758, 1320)
# [ 1] 21:05:03.6 Customer 29 at (2758, 1320) not at home
# [ 1] 21:05:03.6 Driver drives to Customer 41 at (3440, 960)
# [ 1] 21:09:13.6 Driver arrived at Customer 41 at (3440, 960)
# [ 1] 21:10:13.6 Customer 41 at (3440, 960) not at home
# [ 1] 21:10:13.6 Driver drives to Customer 40 at (3440, 804)
# [ 1] 21:10:51.1 Driver arrived at Customer 40 at (3440, 804)
# [ 1] 21:11:51.1 Customer 40 at (3440, 804) not at home
# [ 1] 21:11:51.1 Driver drives to Customer 38 at (3440, 440)
# [ 1] 21:13:18.4 Driver arrived at Customer 38 at (3440, 440)
# [ 1] 21:14:18.4 Customer 38 at (3440, 440) not at home
# [ 1] 21:14:18.4 Driver drives to Customer 52 at (3769, 260)
# [ 1] 21:16:20.6 Driver arrived at Customer 52 at (3769, 260)
# [ 1] 21:17:20.6 Customer 52 at (3769, 260) not at home
# [ 1] 21:17:20.6 Driver drives to Customer 79 at (5736, 1320)
# [ 1] 21:26:58.0 Driver arrived at Customer 79 at (5736, 1320)
# [ 1] 21:27:58.0 Customer 79 at (5736, 1320) not at home
# [ 1] 21:27:58.0 Driver drives to Customer 81 at (5915, 1320)
# [ 1] 21:28:41.0 Driver arrived at Customer 81 at (5915, 1320)
# [ 1] 21:29:41.0 Customer 81 at (5915, 1320) not at home
# [ 1] 21:29:41.0 Driver drives to Customer 88 at (6370, 1320)
# [ 1] 21:31:30.2 Driver arrived at Customer 88 at (6370, 1320)
# [ 1] 21:32:30.2 Customer 88 at (6370, 1320) not at home
# [ 1] 21:32:30.2 Driver drives to Customer 76 at (5226, 1653)
# [ 1] 21:37:37.6 Driver arrived at Customer 76 at (5226, 1653)
# [ 1] 21:38:37.6 Customer 76 at (5226, 1653) not at home
# [ 1] 21:38:37.6 Driver drives to Customer 59 at (4500, 3088)
# [ 1] 21:45:34.0 Driver arrived at Customer 59 at (4500, 3088)
# [ 1] 21:46:34.0 Customer 59 at (4500, 3088) not at home
# [ 1] 21:46:34.0 Driver drives to Customer 60 at (4500, 3173)
# [ 1] 21:46:54.4 Driver arrived at Customer 60 at (4500, 3173)
# [ 1] 21:47:34.0 Customer 60 at (4500, 3173) answers door
# [ 1] 21:47:34.0 Customer 60 at (4500, 3173) accepts Parcel 22 for cust 60
# [ 1] 21:47:37.2 Customer 60 at (4500, 3173) accepts Parcel 50 for cust 60
# [ 1] 21:48:01.6 Customer 60 at (4500, 3173) signs off
# [ 1] 21:48:33.6 Driver returns to delivery centre
# [ 1] 21:53:52.1 Driver arrived at delivery centre
# [ 1] 21:53:52.1 Parcel 23 for cust 62 return from delivery
# [ 1] 21:54:22.1 Parcel 53 for cust 62 return from delivery
# [ 1] 21:54:52.1 Parcel 61 for cust 89 return from delivery
# [ 1] 21:55:22.1 Parcel 62 for cust 90 return from delivery
# [ 1] 21:55:52.1 Parcel 34 for cust 93 return from delivery
# [ 1] 21:56:22.1 Parcel 35 for cust 93 return from delivery
# [ 1] 21:56:52.1 Parcel 30 for cust 71 return from delivery
# [ 1] 21:57:22.1 Parcel 55 for cust 74 return from delivery
# [ 1] 21:57:52.1 Parcel 56 for cust 75 return from delivery
# [ 1] 21:58:22.1 Parcel 58 for cust 78 return from delivery
# [ 1] 21:58:52.1 Parcel 32 for cust 82 return from delivery
# [ 1] 21:59:22.1 Parcel 10 for cust 12 return from delivery
# [ 1] 21:59:52.1 Parcel 39 for cust 12 return from delivery
# [ 1] 22:00:22.1 Parcel 8 for cust 11 return from delivery
# [ 1] 22:00:52.1 Parcel 9 for cust 11 return from delivery
# [ 1] 22:01:22.1 Parcel 38 for cust 10 return from delivery
# [ 1] 22:01:52.1 Parcel 6 for cust 9 return from delivery
# [ 1] 22:02:22.1 Parcel 7 for cust 9 return from delivery
# [ 1] 22:02:52.1 Parcel 36 for cust 5 return from delivery
# [ 1] 22:03:22.1 Parcel 2 for cust 4 return from delivery
# [ 1] 22:03:52.1 Parcel 3 for cust 4 return from delivery
# [ 1] 22:04:22.1 Parcel 1 for cust 2 return from delivery
# [ 1] 22:04:52.1 Parcel 45 for cust 26 return from delivery
# [ 1] 22:05:22.1 Parcel 13 for cust 25 return from delivery
# [ 1] 22:05:52.1 Parcel 44 for cust 25 return from delivery
# [ 1] 22:06:22.1 Parcel 4 for cust 6 return from delivery
# [ 1] 22:06:52.1 Parcel 37 for cust 6 return from delivery
# [ 1] 22:07:22.1 Parcel 43 for cust 20 return from delivery
# [ 1] 22:07:52.1 Parcel 12 for cust 17 return from delivery
# [ 1] 22:08:22.1 Parcel 42 for cust 17 return from delivery
# [ 1] 22:08:52.1 Parcel 40 for cust 13 return from delivery
# [ 1] 22:09:22.1 Parcel 41 for cust 13 return from delivery
# [ 1] 22:09:52.1 Parcel 46 for cust 29 return from delivery
# [ 1] 22:10:22.1 Parcel 16 for cust 41 return from delivery
# [ 1] 22:10:52.1 Parcel 47 for cust 40 return from delivery
# [ 1] 22:11:22.1 Parcel 15 for cust 38 return from delivery
# [ 1] 22:11:52.1 Parcel 17 for cust 52 return from delivery
# [ 1] 22:12:22.1 Parcel 18 for cust 52 return from delivery
# [ 1] 22:12:52.1 Parcel 49 for cust 52 return from delivery
# [ 1] 22:13:22.1 Parcel 59 for cust 79 return from delivery
# [ 1] 22:13:52.1 Parcel 60 for cust 81 return from delivery
# [ 1] 22:14:22.1 Parcel 33 for cust 88 return from delivery
# [ 1] 22:14:52.1 Parcel 31 for cust 76 return from delivery
# [ 1] 22:15:22.1 Parcel 57 for cust 76 return from delivery
# [ 1] 22:15:52.1 Parcel 20 for cust 59 return from delivery
# [ 1] 22:16:22.1 Parcel 21 for cust 59 return from delivery
# [ 1] 22:16:52.1 57 parcels left for next day
# [ 1] 22:26:52.1 Driver goes home
# [ 2] 17:00:00.0 Parcel 65 for cust 9 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 66 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 67 for cust 11 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 68 for cust 12 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 69 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 70 for cust 22 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 71 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 72 for cust 26 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 73 for cust 31 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 74 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 75 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 76 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 77 for cust 34 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 78 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 79 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 80 for cust 39 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 81 for cust 46 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 82 for cust 47 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 83 for cust 48 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 84 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 85 for cust 50 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 86 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 87 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 88 for cust 66 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 89 for cust 73 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 90 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 91 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 92 for cust 84 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 93 for cust 87 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 94 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 95 for cust 89 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 96 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 97 for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 23 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 53 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 51 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 52 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 86 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 83 for cust 48 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 82 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 81 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 79 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 77 for cust 34 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 57 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 59 for cust 79 out for delivery
# [ 2] 18:00:00.0 Parcel 60 for cust 81 out for delivery
# [ 2] 18:00:00.0 Parcel 90 for cust 81 out for delivery
# [ 2] 18:00:00.0 Parcel 91 for cust 81 out for delivery
# [ 2] 18:00:00.0 Parcel 92 for cust 84 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 88 out for delivery
# [ 2] 18:00:00.0 Parcel 63 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 97 for cust 95 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 98 out for delivery
# [ 2] 18:00:00.0 Parcel 87 for cust 63 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 54 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 61 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 94 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 95 for cust 89 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 96 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 88 for cust 66 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 69 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 71 out for delivery
# [ 2] 18:00:00.0 Parcel 89 for cust 73 out for delivery
# [ 2] 18:00:00.0 Parcel 55 for cust 74 out for delivery
# [ 2] 18:00:00.0 Parcel 56 for cust 75 out for delivery
# [ 2] 18:00:00.0 Parcel 58 for cust 78 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 82 out for delivery
# [ 2] 18:00:00.0 Parcel 93 for cust 87 out for delivery
# [ 2] 18:39:10.0 Driver leaves for delivery of 47 parcels to 31 customers
# [ 2] 18:39:10.0 Length of delivery tour: 39,696m
# [ 2] 18:39:10.0 Driver drives to Customer 62 at (4500, 4006)
# [ 2] 18:41:08.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 2] 18:42:08.6 Customer 62 at (4500, 4006) not at home
# [ 2] 18:42:08.6 Driver drives to Customer 61 at (4500, 3324)
# [ 2] 18:44:52.2 Driver arrived at Customer 61 at (4500, 3324)
# [ 2] 18:45:52.2 Customer 61 at (4500, 3324) not at home
# [ 2] 18:45:52.2 Driver drives to Customer 59 at (4500, 3088)
# [ 2] 18:46:48.9 Driver arrived at Customer 59 at (4500, 3088)
# [ 2] 18:47:48.9 Customer 59 at (4500, 3088) not at home
# [ 2] 18:47:48.9 Driver drives to Customer 48 at (3440, 2229)
# [ 2] 18:55:29.4 Driver arrived at Customer 48 at (3440, 2229)
# [ 2] 18:56:29.4 Customer 48 at (3440, 2229) not at home
# [ 2] 18:56:29.4 Driver drives to Customer 47 at (3440, 2110)
# [ 2] 18:56:58.0 Driver arrived at Customer 47 at (3440, 2110)
# [ 2] 18:57:58.0 Customer 47 at (3440, 2110) not at home
# [ 2] 18:57:58.0 Driver drives to Customer 46 at (3440, 2013)
# [ 2] 18:58:21.3 Driver arrived at Customer 46 at (3440, 2013)
# [ 2] 18:59:21.3 Customer 46 at (3440, 2013) not at home
# [ 2] 18:59:21.3 Driver drives to Customer 37 at (3305, 2380)
# [ 2] 19:01:21.8 Driver arrived at Customer 37 at (3305, 2380)
# [ 2] 19:02:21.8 Customer 37 at (3305, 2380) not at home
# [ 2] 19:02:21.8 Driver drives to Customer 34 at (3063, 2380)
# [ 2] 19:03:19.8 Driver arrived at Customer 34 at (3063, 2380)
# [ 2] 19:04:19.8 Customer 34 at (3063, 2380) not at home
# [ 2] 19:04:19.8 Driver drives to Customer 20 at (2380, 3216)
# [ 2] 19:10:24.4 Driver arrived at Customer 20 at (2380, 3216)
# [ 2] 19:11:24.4 Customer 20 at (2380, 3216) not at home
# [ 2] 19:11:24.4 Driver drives to Customer 76 at (5226, 1653)
# [ 2] 19:27:20.3 Driver arrived at Customer 76 at (5226, 1653)
# [ 2] 19:28:20.3 Customer 76 at (5226, 1653) not at home
# [ 2] 19:28:20.3 Driver drives to Customer 79 at (5736, 1320)
# [ 2] 19:30:55.6 Driver arrived at Customer 79 at (5736, 1320)
# [ 2] 19:31:55.6 Customer 79 at (5736, 1320) not at home
# [ 2] 19:31:55.6 Driver drives to Customer 81 at (5915, 1320)
# [ 2] 19:32:38.6 Driver arrived at Customer 81 at (5915, 1320)
# [ 2] 19:33:33.3 Customer 81 at (5915, 1320) answers door
# [ 2] 19:33:33.3 Customer 81 at (5915, 1320) accepts Parcel 60 for cust 81
# [ 2] 19:33:43.6 Customer 81 at (5915, 1320) accepts Parcel 90 for cust 81
# [ 2] 19:33:54.0 Customer 81 at (5915, 1320) accepts Parcel 91 for cust 81
# [ 2] 19:34:04.0 Customer 81 at (5915, 1320) signs off
# [ 2] 19:34:09.2 Driver drives to Customer 84 at (6012, 1320)
# [ 2] 19:34:32.5 Driver arrived at Customer 84 at (6012, 1320)
# [ 2] 19:35:32.5 Customer 84 at (6012, 1320) not at home
# [ 2] 19:35:32.5 Driver drives to Customer 88 at (6370, 1320)
# [ 2] 19:36:58.4 Driver arrived at Customer 88 at (6370, 1320)
# [ 2] 19:37:58.4 Customer 88 at (6370, 1320) not at home
# [ 2] 19:37:58.4 Driver drives to Customer 95 at (7141, 2380)
# [ 2] 19:45:17.8 Driver arrived at Customer 95 at (7141, 2380)
# [ 2] 19:46:17.8 Customer 95 at (7141, 2380) not at home
# [ 2] 19:46:17.8 Driver drives to Customer 98 at (8520, 2380)
# [ 2] 19:51:48.8 Driver arrived at Customer 98 at (8520, 2380)
# [ 2] 19:52:48.8 Customer 98 at (8520, 2380) not at home
# [ 2] 19:52:48.8 Driver drives to Customer 63 at (4500, 4714)
# [ 2] 20:24:13.3 Driver arrived at Customer 63 at (4500, 4714)
# [ 2] 20:25:13.3 Customer 63 at (4500, 4714) not at home
# [ 2] 20:25:13.3 Driver drives to Customer 64 at (4500, 4955)
# [ 2] 20:26:11.1 Driver arrived at Customer 64 at (4500, 4955)
# [ 2] 20:27:11.1 Customer 64 at (4500, 4955) not at home
# [ 2] 20:27:11.1 Driver drives to Customer 89 at (6620, 5719)
# [ 2] 20:38:43.3 Driver arrived at Customer 89 at (6620, 5719)
# [ 2] 20:39:43.3 Customer 89 at (6620, 5719) not at home
# [ 2] 20:39:43.3 Driver drives to Customer 90 at (6620, 5883)
# [ 2] 20:40:22.6 Driver arrived at Customer 90 at (6620, 5883)
# [ 2] 20:41:22.6 Customer 90 at (6620, 5883) not at home
# [ 2] 20:41:22.6 Driver drives to Customer 93 at (6620, 6302)
# [ 2] 20:43:03.2 Driver arrived at Customer 93 at (6620, 6302)
# [ 2] 20:44:03.2 Customer 93 at (6620, 6302) not at home
# [ 2] 20:44:03.2 Driver drives to Customer 66 at (4500, 6013)
# [ 2] 20:57:18.8 Driver arrived at Customer 66 at (4500, 6013)
# [ 2] 20:58:18.8 Customer 66 at (4500, 6013) not at home
# [ 2] 20:58:18.8 Driver drives to Customer 68 at (4500, 6293)
# [ 2] 20:59:26.0 Driver arrived at Customer 68 at (4500, 6293)
# [ 2] 21:00:26.0 Customer 68 at (4500, 6293) not at home
# [ 2] 21:00:26.0 Driver drives to Customer 69 at (4500, 7022)
# [ 2] 21:03:20.9 Driver arrived at Customer 69 at (4500, 7022)
# [ 2] 21:04:20.9 Customer 69 at (4500, 7022) not at home
# [ 2] 21:04:20.9 Driver drives to Customer 71 at (4500, 8018)
# [ 2] 21:08:20.0 Driver arrived at Customer 71 at (4500, 8018)
# [ 2] 21:09:20.0 Customer 71 at (4500, 8018) not at home
# [ 2] 21:09:20.0 Driver drives to Customer 73 at (4853, 8740)
# [ 2] 21:13:38.0 Driver arrived at Customer 73 at (4853, 8740)
# [ 2] 21:14:38.0 Customer 73 at (4853, 8740) not at home
# [ 2] 21:14:38.0 Driver drives to Customer 74 at (5079, 8740)
# [ 2] 21:15:32.2 Driver arrived at Customer 74 at (5079, 8740)
# [ 2] 21:16:32.2 Customer 74 at (5079, 8740) not at home
# [ 2] 21:16:32.2 Driver drives to Customer 75 at (5211, 8740)
# [ 2] 21:17:03.9 Driver arrived at Customer 75 at (5211, 8740)
# [ 2] 21:17:43.6 Customer 75 at (5211, 8740) answers door
# [ 2] 21:17:43.6 Customer 75 at (5211, 8740) accepts Parcel 56 for cust 75
# [ 2] 21:17:53.6 Customer 75 at (5211, 8740) signs off
# [ 2] 21:18:21.3 Driver drives to Customer 78 at (5419, 8740)
# [ 2] 21:19:11.2 Driver arrived at Customer 78 at (5419, 8740)
# [ 2] 21:20:11.2 Customer 78 at (5419, 8740) not at home
# [ 2] 21:20:11.2 Driver drives to Customer 82 at (5931, 8740)
# [ 2] 21:22:14.1 Driver arrived at Customer 82 at (5931, 8740)
# [ 2] 21:23:14.1 Customer 82 at (5931, 8740) not at home
# [ 2] 21:23:14.1 Driver drives to Customer 87 at (6285, 8740)
# [ 2] 21:24:39.1 Driver arrived at Customer 87 at (6285, 8740)
# [ 2] 21:25:39.1 Customer 87 at (6285, 8740) not at home
# [ 2] 21:25:39.1 Driver returns to delivery centre
# [ 2] 21:49:45.1 Driver arrived at delivery centre
# [ 2] 21:49:45.1 Parcel 23 for cust 62 return from delivery
# [ 2] 21:50:15.1 Parcel 53 for cust 62 return from delivery
# [ 2] 21:50:45.1 Parcel 51 for cust 61 return from delivery
# [ 2] 21:51:15.1 Parcel 52 for cust 61 return from delivery
# [ 2] 21:51:45.1 Parcel 86 for cust 61 return from delivery
# [ 2] 21:52:15.1 Parcel 20 for cust 59 return from delivery
# [ 2] 21:52:45.1 Parcel 21 for cust 59 return from delivery
# [ 2] 21:53:15.1 Parcel 83 for cust 48 return from delivery
# [ 2] 21:53:45.1 Parcel 48 for cust 47 return from delivery
# [ 2] 21:54:15.1 Parcel 82 for cust 47 return from delivery
# [ 2] 21:54:45.1 Parcel 81 for cust 46 return from delivery
# [ 2] 21:55:15.1 Parcel 79 for cust 37 return from delivery
# [ 2] 21:55:45.1 Parcel 77 for cust 34 return from delivery
# [ 2] 21:56:15.1 Parcel 43 for cust 20 return from delivery
# [ 2] 21:56:45.1 Parcel 31 for cust 76 return from delivery
# [ 2] 21:57:15.1 Parcel 57 for cust 76 return from delivery
# [ 2] 21:57:45.1 Parcel 59 for cust 79 return from delivery
# [ 2] 21:58:15.1 Parcel 92 for cust 84 return from delivery
# [ 2] 21:58:45.1 Parcel 33 for cust 88 return from delivery
# [ 2] 21:59:15.1 Parcel 63 for cust 95 return from delivery
# [ 2] 21:59:45.1 Parcel 97 for cust 95 return from delivery
# [ 2] 22:00:15.1 Parcel 64 for cust 98 return from delivery
# [ 2] 22:00:45.1 Parcel 87 for cust 63 return from delivery
# [ 2] 22:01:15.1 Parcel 24 for cust 64 return from delivery
# [ 2] 22:01:45.1 Parcel 54 for cust 64 return from delivery
# [ 2] 22:02:15.1 Parcel 61 for cust 89 return from delivery
# [ 2] 22:02:45.1 Parcel 94 for cust 89 return from delivery
# [ 2] 22:03:15.1 Parcel 95 for cust 89 return from delivery
# [ 2] 22:03:45.1 Parcel 62 for cust 90 return from delivery
# [ 2] 22:04:15.1 Parcel 34 for cust 93 return from delivery
# [ 2] 22:04:45.1 Parcel 35 for cust 93 return from delivery
# [ 2] 22:05:15.1 Parcel 96 for cust 93 return from delivery
# [ 2] 22:05:45.1 Parcel 88 for cust 66 return from delivery
# [ 2] 22:06:15.1 Parcel 26 for cust 68 return from delivery
# [ 2] 22:06:45.1 Parcel 27 for cust 68 return from delivery
# [ 2] 22:07:15.1 Parcel 28 for cust 68 return from delivery
# [ 2] 22:07:45.1 Parcel 29 for cust 69 return from delivery
# [ 2] 22:08:15.1 Parcel 30 for cust 71 return from delivery
# [ 2] 22:08:45.1 Parcel 89 for cust 73 return from delivery
# [ 2] 22:09:15.1 Parcel 55 for cust 74 return from delivery
# [ 2] 22:09:45.1 Parcel 58 for cust 78 return from delivery
# [ 2] 22:10:15.1 Parcel 32 for cust 82 return from delivery
# [ 2] 22:10:45.1 Parcel 93 for cust 87 return from delivery
# [ 2] 22:11:15.1 86 parcels left for next day
# [ 2] 22:21:15.1 Driver goes home
# [ 3] 17:00:00.0 Parcel 98 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 99 for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 100 for cust 21 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 101 for cust 28 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 102 for cust 38 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 103 for cust 40 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 104 for cust 48 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 105 for cust 49 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 106 for cust 51 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 107 for cust 58 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 108 for cust 63 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 109 for cust 64 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 110 for cust 66 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 111 for cust 70 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 112 for cust 73 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 113 for cust 84 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 114 for cust 87 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 115 for cust 90 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 116 for cust 99 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 23 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 51 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 52 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 86 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 20 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 107 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 79 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 77 for cust 34 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 100 for cust 21 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 37 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 22 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 24 out for delivery
# [ 3] 18:00:00.0 Parcel 13 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 25 out for delivery
# [ 3] 18:00:00.0 Parcel 45 for cust 26 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 26 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 29 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 41 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 101 for cust 28 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 31 out for delivery
# [ 3] 18:00:00.0 Parcel 78 for cust 35 out for delivery
# [ 3] 18:00:00.0 Parcel 84 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 105 for cust 49 out for delivery
# [ 3] 18:00:00.0 Parcel 17 for cust 52 out for delivery
# [ 3] 18:00:00.0 Parcel 18 for cust 52 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 52 out for delivery
# [ 3] 18:00:00.0 Parcel 15 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 102 for cust 38 out for delivery
# [ 3] 18:00:00.0 Parcel 80 for cust 39 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 103 for cust 40 out for delivery
# [ 3] 18:00:00.0 Parcel 16 for cust 41 out for delivery
# [ 3] 18:00:00.0 Parcel 81 for cust 46 out for delivery
# [ 3] 18:00:00.0 Parcel 48 for cust 47 out for delivery
# [ 3] 18:00:00.0 Parcel 82 for cust 47 out for delivery
# [ 3] 18:00:00.0 Parcel 83 for cust 48 out for delivery
# [ 3] 18:00:00.0 Parcel 104 for cust 48 out for delivery
# [ 3] 18:00:00.0 Parcel 87 for cust 63 out for delivery
# [ 3] 18:00:00.0 Parcel 108 for cust 63 out for delivery
# [ 3] 18:00:00.0 Parcel 24 for cust 64 out for delivery
# [ 3] 18:00:00.0 Parcel 54 for cust 64 out for delivery
# [ 3] 18:00:00.0 Parcel 109 for cust 64 out for delivery
# [ 3] 18:00:00.0 Parcel 88 for cust 66 out for delivery
# [ 3] 18:00:00.0 Parcel 110 for cust 66 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 27 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 68 out for delivery
# [ 3] 18:00:00.0 Parcel 29 for cust 69 out for delivery
# [ 3] 18:00:00.0 Parcel 111 for cust 70 out for delivery
# [ 3] 18:00:00.0 Parcel 30 for cust 71 out for delivery
# [ 3] 18:00:00.0 Parcel 106 for cust 51 out for delivery
# [ 3] 18:00:00.0 Parcel 85 for cust 50 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 75 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 76 for cust 32 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 68 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 8 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 38 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 6 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 7 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 36 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 99 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 2 out for delivery
# [ 3] 19:06:40.0 Driver leaves for delivery of 80 parcels to 47 customers
# [ 3] 19:06:40.0 Length of delivery tour: 39,032m
# [ 3] 19:06:40.0 Driver drives to Customer 62 at (4500, 4006)
# [ 3] 19:08:38.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 3] 19:09:38.6 Customer 62 at (4500, 4006) not at home
# [ 3] 19:09:38.6 Driver drives to Customer 61 at (4500, 3324)
# [ 3] 19:12:22.2 Driver arrived at Customer 61 at (4500, 3324)
# [ 3] 19:13:22.2 Customer 61 at (4500, 3324) not at home
# [ 3] 19:13:22.2 Driver drives to Customer 59 at (4500, 3088)
# [ 3] 19:14:18.9 Driver arrived at Customer 59 at (4500, 3088)
# [ 3] 19:15:18.9 Customer 59 at (4500, 3088) not at home
# [ 3] 19:15:18.9 Driver drives to Customer 58 at (4500, 2960)
# [ 3] 19:15:49.6 Driver arrived at Customer 58 at (4500, 2960)
# [ 3] 19:16:49.6 Customer 58 at (4500, 2960) not at home
# [ 3] 19:16:49.6 Driver drives to Customer 37 at (3305, 2380)
# [ 3] 19:23:55.6 Driver arrived at Customer 37 at (3305, 2380)
# [ 3] 19:24:55.6 Customer 37 at (3305, 2380) not at home
# [ 3] 19:24:55.6 Driver drives to Customer 34 at (3063, 2380)
# [ 3] 19:25:53.7 Driver arrived at Customer 34 at (3063, 2380)
# [ 3] 19:26:53.7 Customer 34 at (3063, 2380) not at home
# [ 3] 19:26:53.7 Driver drives to Customer 20 at (2380, 3216)
# [ 3] 19:32:58.2 Driver arrived at Customer 20 at (2380, 3216)
# [ 3] 19:33:58.2 Customer 20 at (2380, 3216) not at home
# [ 3] 19:33:58.2 Driver drives to Customer 21 at (2380, 3334)
# [ 3] 19:34:26.6 Driver arrived at Customer 21 at (2380, 3334)
# [ 3] 19:35:26.6 Customer 21 at (2380, 3334) not at home
# [ 3] 19:35:26.6 Driver drives to Customer 6 at (1542, 3440)
# [ 3] 19:39:13.1 Driver arrived at Customer 6 at (1542, 3440)
# [ 3] 19:40:13.1 Customer 6 at (1542, 3440) not at home
# [ 3] 19:40:13.1 Driver drives to Customer 22 at (2380, 3906)
# [ 3] 19:45:26.1 Driver arrived at Customer 22 at (2380, 3906)
# [ 3] 19:46:26.1 Customer 22 at (2380, 3906) not at home
# [ 3] 19:46:26.1 Driver drives to Customer 24 at (2380, 4124)
# [ 3] 19:47:18.4 Driver arrived at Customer 24 at (2380, 4124)
# [ 3] 19:48:18.4 Customer 24 at (2380, 4124) not at home
# [ 3] 19:48:18.4 Driver drives to Customer 25 at (2380, 4319)
# [ 3] 19:49:05.2 Driver arrived at Customer 25 at (2380, 4319)
# [ 3] 19:50:05.2 Customer 25 at (2380, 4319) not at home
# [ 3] 19:50:05.2 Driver drives to Customer 26 at (2380, 5019)
# [ 3] 19:52:53.2 Driver arrived at Customer 26 at (2380, 5019)
# [ 3] 19:53:53.2 Customer 26 at (2380, 5019) not at home
# [ 3] 19:53:53.2 Driver drives to Customer 17 at (2380, 1652)
# [ 3] 20:07:21.3 Driver arrived at Customer 17 at (2380, 1652)
# [ 3] 20:08:21.3 Customer 17 at (2380, 1652) not at home
# [ 3] 20:08:21.3 Driver drives to Customer 29 at (2758, 1320)
# [ 3] 20:11:11.7 Driver arrived at Customer 29 at (2758, 1320)
# [ 3] 20:12:11.7 Customer 29 at (2758, 1320) not at home
# [ 3] 20:12:11.7 Driver drives to Customer 14 at (2380, 952)
# [ 3] 20:17:50.1 Driver arrived at Customer 14 at (2380, 952)
# [ 3] 20:18:50.1 Customer 14 at (2380, 952) not at home
# [ 3] 20:18:50.1 Driver drives to Customer 13 at (2380, 561)
# [ 3] 20:20:23.9 Driver arrived at Customer 13 at (2380, 561)
# [ 3] 20:21:23.9 Customer 13 at (2380, 561) not at home
# [ 3] 20:21:23.9 Driver drives to Customer 28 at (2727, 260)
# [ 3] 20:23:59.4 Driver arrived at Customer 28 at (2727, 260)
# [ 3] 20:24:59.4 Customer 28 at (2727, 260) not at home
# [ 3] 20:24:59.4 Driver drives to Customer 31 at (2850, 260)
# [ 3] 20:25:29.0 Driver arrived at Customer 31 at (2850, 260)
# [ 3] 20:25:47.9 Customer 31 at (2850, 260) answers door
# [ 3] 20:25:47.9 Customer 31 at (2850, 260) accepts Parcel 73 for cust 31
# [ 3] 20:25:49.8 Customer 31 at (2850, 260) signs off
# [ 3] 20:25:52.4 Driver drives to Customer 35 at (3192, 260)
# [ 3] 20:27:14.5 Driver arrived at Customer 35 at (3192, 260)
# [ 3] 20:28:14.5 Customer 35 at (3192, 260) not at home
# [ 3] 20:28:14.5 Driver drives to Customer 49 at (3545, 260)
# [ 3] 20:29:39.2 Driver arrived at Customer 49 at (3545, 260)
# [ 3] 20:30:39.2 Customer 49 at (3545, 260) not at home
# [ 3] 20:30:39.2 Driver drives to Customer 52 at (3769, 260)
# [ 3] 20:31:33.0 Driver arrived at Customer 52 at (3769, 260)
# [ 3] 20:32:33.0 Customer 52 at (3769, 260) not at home
# [ 3] 20:32:33.0 Driver drives to Customer 38 at (3440, 440)
# [ 3] 20:34:35.1 Driver arrived at Customer 38 at (3440, 440)
# [ 3] 20:35:35.1 Customer 38 at (3440, 440) not at home
# [ 3] 20:35:35.1 Driver drives to Customer 39 at (3440, 641)
# [ 3] 20:36:23.4 Driver arrived at Customer 39 at (3440, 641)
# [ 3] 20:37:23.4 Customer 39 at (3440, 641) not at home
# [ 3] 20:37:23.4 Driver drives to Customer 40 at (3440, 804)
# [ 3] 20:38:02.5 Driver arrived at Customer 40 at (3440, 804)
# [ 3] 20:39:02.5 Customer 40 at (3440, 804) not at home
# [ 3] 20:39:02.5 Driver drives to Customer 41 at (3440, 960)
# [ 3] 20:39:39.9 Driver arrived at Customer 41 at (3440, 960)
# [ 3] 20:40:39.9 Customer 41 at (3440, 960) not at home
# [ 3] 20:40:39.9 Driver drives to Customer 46 at (3440, 2013)
# [ 3] 20:44:52.7 Driver arrived at Customer 46 at (3440, 2013)
# [ 3] 20:45:52.7 Customer 46 at (3440, 2013) not at home
# [ 3] 20:45:52.7 Driver drives to Customer 47 at (3440, 2110)
# [ 3] 20:46:15.9 Driver arrived at Customer 47 at (3440, 2110)
# [ 3] 20:47:15.9 Customer 47 at (3440, 2110) not at home
# [ 3] 20:47:15.9 Driver drives to Customer 48 at (3440, 2229)
# [ 3] 20:47:44.5 Driver arrived at Customer 48 at (3440, 2229)
# [ 3] 20:48:44.5 Customer 48 at (3440, 2229) to slow to answer the door
# [ 3] 20:48:44.5 Driver drives to Customer 63 at (4500, 4714)
# [ 3] 21:05:56.3 Driver arrived at Customer 63 at (4500, 4714)
# [ 3] 21:06:56.3 Customer 63 at (4500, 4714) not at home
# [ 3] 21:06:56.3 Driver drives to Customer 64 at (4500, 4955)
# [ 3] 21:07:54.1 Driver arrived at Customer 64 at (4500, 4955)
# [ 3] 21:08:54.1 Customer 64 at (4500, 4955) not at home
# [ 3] 21:08:54.1 Driver drives to Customer 66 at (4500, 6013)
# [ 3] 21:13:08.0 Driver arrived at Customer 66 at (4500, 6013)
# [ 3] 21:14:08.0 Customer 66 at (4500, 6013) not at home
# [ 3] 21:14:08.0 Driver drives to Customer 68 at (4500, 6293)
# [ 3] 21:15:15.2 Driver arrived at Customer 68 at (4500, 6293)
# [ 3] 21:16:15.2 Customer 68 at (4500, 6293) not at home
# [ 3] 21:16:15.2 Driver drives to Customer 69 at (4500, 7022)
# [ 3] 21:19:10.2 Driver arrived at Customer 69 at (4500, 7022)
# [ 3] 21:20:10.2 Customer 69 at (4500, 7022) not at home
# [ 3] 21:20:10.2 Driver drives to Customer 70 at (4500, 7788)
# [ 3] 21:23:14.0 Driver arrived at Customer 70 at (4500, 7788)
# [ 3] 21:24:14.0 Customer 70 at (4500, 7788) not at home
# [ 3] 21:24:14.0 Driver drives to Customer 71 at (4500, 8018)
# [ 3] 21:25:09.2 Driver arrived at Customer 71 at (4500, 8018)
# [ 3] 21:25:34.1 Customer 71 at (4500, 8018) answers door
# [ 3] 21:25:34.1 Customer 71 at (4500, 8018) accepts Parcel 30 for cust 71
# [ 3] 21:25:42.7 Customer 71 at (4500, 8018) signs off
# [ 3] 21:25:45.1 Driver drives to Customer 51 at (3758, 7680)
# [ 3] 21:30:04.3 Driver arrived at Customer 51 at (3758, 7680)
# [ 3] 21:31:04.3 Customer 51 at (3758, 7680) not at home
# [ 3] 21:31:04.3 Driver drives to Customer 50 at (3623, 7680)
# [ 3] 21:31:36.7 Driver arrived at Customer 50 at (3623, 7680)
# [ 3] 21:32:26.9 Customer 50 at (3623, 7680) answers door
# [ 3] 21:32:26.9 Customer 50 at (3623, 7680) accepts Parcel 85 for cust 50
# [ 3] 21:32:30.9 Customer 50 at (3623, 7680) signs off
# [ 3] 21:32:39.9 Driver drives to Customer 32 at (2925, 8194)
# [ 3] 21:36:18.3 Driver arrived at Customer 32 at (2925, 8194)
# [ 3] 21:37:18.3 Customer 32 at (2925, 8194) not at home
# [ 3] 21:37:18.3 Driver drives to Customer 12 at (2294, 8654)
# [ 3] 21:40:52.4 Driver arrived at Customer 12 at (2294, 8654)
# [ 3] 21:41:52.4 Customer 12 at (2294, 8654) not at home
# [ 3] 21:41:52.4 Driver drives to Customer 11 at (2223, 8583)
# [ 3] 21:42:16.4 Driver arrived at Customer 11 at (2223, 8583)
# [ 3] 21:43:16.4 Customer 11 at (2223, 8583) not at home
# [ 3] 21:43:16.4 Driver drives to Customer 10 at (2155, 8515)
# [ 3] 21:43:39.5 Driver arrived at Customer 10 at (2155, 8515)
# [ 3] 21:44:39.5 Customer 10 at (2155, 8515) not at home
# [ 3] 21:44:39.5 Driver drives to Customer 9 at (2051, 8411)
# [ 3] 21:45:14.7 Driver arrived at Customer 9 at (2051, 8411)
# [ 3] 21:46:14.7 Customer 9 at (2051, 8411) not at home
# [ 3] 21:46:14.7 Driver drives to Customer 5 at (1495, 7855)
# [ 3] 21:49:23.4 Driver arrived at Customer 5 at (1495, 7855)
# [ 3] 21:50:23.4 Customer 5 at (1495, 7855) not at home
# [ 3] 21:50:23.4 Driver drives to Customer 4 at (1320, 7483)
# [ 3] 21:52:09.9 Driver arrived at Customer 4 at (1320, 7483)
# [ 3] 21:53:09.9 Customer 4 at (1320, 7483) not at home
# [ 3] 21:53:09.9 Driver drives to Customer 3 at (1320, 7239)
# [ 3] 21:54:08.5 Driver arrived at Customer 3 at (1320, 7239)
# [ 3] 21:55:08.5 Customer 3 at (1320, 7239) not at home
# [ 3] 21:55:08.5 Driver drives to Customer 2 at (1320, 6990)
# [ 3] 21:56:08.3 Driver arrived at Customer 2 at (1320, 6990)
# [ 3] 21:57:08.3 Customer 2 at (1320, 6990) not at home
# [ 3] 21:57:08.3 Driver returns to delivery centre
# [ 3] 22:28:50.3 Driver arrived at delivery centre
# [ 3] 22:28:50.3 Parcel 23 for cust 62 return from delivery
# [ 3] 22:29:20.3 Parcel 53 for cust 62 return from delivery
# [ 3] 22:29:50.3 Parcel 51 for cust 61 return from delivery
# [ 3] 22:30:20.3 Parcel 52 for cust 61 return from delivery
# [ 3] 22:30:50.3 Parcel 86 for cust 61 return from delivery
# [ 3] 22:31:20.3 Parcel 20 for cust 59 return from delivery
# [ 3] 22:31:50.3 Parcel 21 for cust 59 return from delivery
# [ 3] 22:32:20.3 Parcel 107 for cust 58 return from delivery
# [ 3] 22:32:50.3 Parcel 79 for cust 37 return from delivery
# [ 3] 22:33:20.3 Parcel 77 for cust 34 return from delivery
# [ 3] 22:33:50.3 Parcel 43 for cust 20 return from delivery
# [ 3] 22:34:20.3 Parcel 100 for cust 21 return from delivery
# [ 3] 22:34:50.3 Parcel 4 for cust 6 return from delivery
# [ 3] 22:35:20.3 Parcel 37 for cust 6 return from delivery
# [ 3] 22:35:50.3 Parcel 70 for cust 22 return from delivery
# [ 3] 22:36:20.3 Parcel 71 for cust 24 return from delivery
# [ 3] 22:36:50.3 Parcel 13 for cust 25 return from delivery
# [ 3] 22:37:20.3 Parcel 44 for cust 25 return from delivery
# [ 3] 22:37:50.3 Parcel 45 for cust 26 return from delivery
# [ 3] 22:38:20.3 Parcel 72 for cust 26 return from delivery
# [ 3] 22:38:50.3 Parcel 12 for cust 17 return from delivery
# [ 3] 22:39:20.3 Parcel 42 for cust 17 return from delivery
# [ 3] 22:39:50.3 Parcel 46 for cust 29 return from delivery
# [ 3] 22:40:20.3 Parcel 69 for cust 14 return from delivery
# [ 3] 22:40:50.3 Parcel 40 for cust 13 return from delivery
# [ 3] 22:41:20.3 Parcel 41 for cust 13 return from delivery
# [ 3] 22:41:50.3 Parcel 101 for cust 28 return from delivery
# [ 3] 22:42:20.3 Parcel 78 for cust 35 return from delivery
# [ 3] 22:42:50.3 Parcel 84 for cust 49 return from delivery
# [ 3] 22:43:20.3 Parcel 105 for cust 49 return from delivery
# [ 3] 22:43:50.3 Parcel 17 for cust 52 return from delivery
# [ 3] 22:44:20.3 Parcel 18 for cust 52 return from delivery
# [ 3] 22:44:50.3 Parcel 49 for cust 52 return from delivery
# [ 3] 22:45:20.3 Parcel 15 for cust 38 return from delivery
# [ 3] 22:45:50.3 Parcel 102 for cust 38 return from delivery
# [ 3] 22:46:20.3 Parcel 80 for cust 39 return from delivery
# [ 3] 22:46:50.3 Parcel 47 for cust 40 return from delivery
# [ 3] 22:47:20.3 Parcel 103 for cust 40 return from delivery
# [ 3] 22:47:50.3 Parcel 16 for cust 41 return from delivery
# [ 3] 22:48:20.3 Parcel 81 for cust 46 return from delivery
# [ 3] 22:48:50.3 Parcel 48 for cust 47 return from delivery
# [ 3] 22:49:20.3 Parcel 82 for cust 47 return from delivery
# [ 3] 22:49:50.3 Parcel 83 for cust 48 return from delivery
# [ 3] 22:50:20.3 Parcel 104 for cust 48 return from delivery
# [ 3] 22:50:50.3 Parcel 87 for cust 63 return from delivery
# [ 3] 22:51:20.3 Parcel 108 for cust 63 return from delivery
# [ 3] 22:51:50.3 Parcel 24 for cust 64 return from delivery
# [ 3] 22:52:20.3 Parcel 54 for cust 64 return from delivery
# [ 3] 22:52:50.3 Parcel 109 for cust 64 return from delivery
# [ 3] 22:53:20.3 Parcel 88 for cust 66 return from delivery
# [ 3] 22:53:50.3 Parcel 110 for cust 66 return from delivery
# [ 3] 22:54:20.3 Parcel 26 for cust 68 return from delivery
# [ 3] 22:54:50.3 Parcel 27 for cust 68 return from delivery
# [ 3] 22:55:20.3 Parcel 28 for cust 68 return from delivery
# [ 3] 22:55:50.3 Parcel 29 for cust 69 return from delivery
# [ 3] 22:56:20.3 Parcel 111 for cust 70 return from delivery
# [ 3] 22:56:50.3 Parcel 106 for cust 51 return from delivery
# [ 3] 22:57:20.3 Parcel 74 for cust 32 return from delivery
# [ 3] 22:57:50.3 Parcel 75 for cust 32 return from delivery
# [ 3] 22:58:20.3 Parcel 76 for cust 32 return from delivery
# [ 3] 22:58:50.3 Parcel 10 for cust 12 return from delivery
# [ 3] 22:59:20.3 Parcel 39 for cust 12 return from delivery
# [ 3] 22:59:50.3 Parcel 68 for cust 12 return from delivery
# [ 3] 23:00:20.3 Parcel 8 for cust 11 return from delivery
# [ 3] 23:00:50.3 Parcel 9 for cust 11 return from delivery
# [ 3] 23:01:20.3 Parcel 67 for cust 11 return from delivery
# [ 3] 23:01:50.3 Parcel 38 for cust 10 return from delivery
# [ 3] 23:02:20.3 Parcel 66 for cust 10 return from delivery
# [ 3] 23:02:50.3 Parcel 6 for cust 9 return from delivery
# [ 3] 23:03:20.3 Parcel 7 for cust 9 return from delivery
# [ 3] 23:03:50.3 Parcel 65 for cust 9 return from delivery
# [ 3] 23:04:20.3 Parcel 36 for cust 5 return from delivery
# [ 3] 23:04:50.3 Parcel 2 for cust 4 return from delivery
# [ 3] 23:05:20.3 Parcel 3 for cust 4 return from delivery
# [ 3] 23:05:50.3 Parcel 99 for cust 3 return from delivery
# [ 3] 23:06:20.3 Parcel 1 for cust 2 return from delivery
# [ 3] 23:06:50.3 Parcel 98 for cust 2 return from delivery
# [ 3] 23:07:20.3 102 parcels left for next day
# [ 3] 23:17:20.3 Driver goes home
# Delivery Centre Inventory: 102 parcels

# %%
rec3 = simulation(M, W, C, p=0.6, days=4, log=True)
# Out:
# Simulating delivery of 227 parcels over 4 days to 100 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 1 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 2 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 12 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 19 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 23 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 29 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 37 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 38 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 39 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 43 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 16 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 17 for cust 44 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 18 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 19 for cust 45 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 20 for cust 46 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 21 for cust 47 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 22 for cust 49 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 23 for cust 50 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 24 for cust 51 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 25 for cust 52 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 26 for cust 53 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 27 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 28 for cust 55 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 29 for cust 56 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 30 for cust 58 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 31 for cust 59 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 32 for cust 61 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 33 for cust 62 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 34 for cust 66 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 35 for cust 68 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 36 for cust 69 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 37 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 38 for cust 70 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 39 for cust 71 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 40 for cust 72 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 41 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 42 for cust 73 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 43 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 44 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 45 for cust 76 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 46 for cust 79 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 47 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 48 for cust 84 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 49 for cust 85 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 50 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 51 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 52 for cust 86 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 53 for cust 87 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 54 for cust 90 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 55 for cust 91 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 56 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 57 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 58 for cust 95 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 59 for cust 97 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 60 for cust 98 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 61 for cust 99 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 0] 18:00:00.0 Parcel 32 for cust 61 out for delivery
# [ 0] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 0] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 0] 18:00:00.0 Parcel 49 for cust 85 out for delivery
# [ 0] 18:00:00.0 Parcel 34 for cust 66 out for delivery
# [ 0] 18:00:00.0 Parcel 35 for cust 68 out for delivery
# [ 0] 18:00:00.0 Parcel 36 for cust 69 out for delivery
# [ 0] 18:00:00.0 Parcel 37 for cust 70 out for delivery
# [ 0] 18:00:00.0 Parcel 38 for cust 70 out for delivery
# [ 0] 18:00:00.0 Parcel 39 for cust 71 out for delivery
# [ 0] 18:00:00.0 Parcel 40 for cust 72 out for delivery
# [ 0] 18:00:00.0 Parcel 41 for cust 73 out for delivery
# [ 0] 18:00:00.0 Parcel 42 for cust 73 out for delivery
# [ 0] 18:00:00.0 Parcel 29 for cust 56 out for delivery
# [ 0] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 0] 18:00:00.0 Parcel 23 for cust 50 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 0] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 37 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 29 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 22 for cust 49 out for delivery
# [ 0] 18:00:00.0 Parcel 25 for cust 52 out for delivery
# [ 0] 18:00:00.0 Parcel 26 for cust 53 out for delivery
# [ 0] 18:00:00.0 Parcel 27 for cust 55 out for delivery
# [ 0] 18:00:00.0 Parcel 28 for cust 55 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 43 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 43 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 16 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 17 for cust 44 out for delivery
# [ 0] 18:00:00.0 Parcel 18 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 19 for cust 45 out for delivery
# [ 0] 18:00:00.0 Parcel 20 for cust 46 out for delivery
# [ 0] 18:00:00.0 Parcel 21 for cust 47 out for delivery
# [ 0] 18:00:00.0 Parcel 43 for cust 76 out for delivery
# [ 0] 18:00:00.0 Parcel 44 for cust 76 out for delivery
# [ 0] 18:00:00.0 Parcel 45 for cust 76 out for delivery
# [ 0] 18:00:00.0 Parcel 46 for cust 79 out for delivery
# [ 0] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 48 for cust 84 out for delivery
# [ 0] 18:00:00.0 Parcel 50 for cust 86 out for delivery
# [ 0] 18:00:00.0 Parcel 51 for cust 86 out for delivery
# [ 0] 18:00:00.0 Parcel 52 for cust 86 out for delivery
# [ 0] 18:44:10.0 Driver leaves for delivery of 53 parcels to 41 customers
# [ 0] 18:44:10.0 Length of delivery tour: 39,704m
# [ 0] 18:44:10.0 Driver drives to Customer 62 at (4500, 4006)
# [ 0] 18:46:08.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 0] 18:47:08.6 Customer 62 at (4500, 4006) not at home
# [ 0] 18:47:08.6 Driver drives to Customer 61 at (4500, 3324)
# [ 0] 18:49:52.2 Driver arrived at Customer 61 at (4500, 3324)
# [ 0] 18:50:30.1 Customer 61 at (4500, 3324) answers door
# [ 0] 18:50:30.1 Customer 61 at (4500, 3324) accepts Parcel 32 for cust 61
# [ 0] 18:50:35.0 Customer 61 at (4500, 3324) signs off
# [ 0] 18:50:35.5 Driver drives to Customer 59 at (4500, 3088)
# [ 0] 18:51:32.1 Driver arrived at Customer 59 at (4500, 3088)
# [ 0] 18:52:32.1 Customer 59 at (4500, 3088) not at home
# [ 0] 18:52:32.1 Driver drives to Customer 58 at (4500, 2960)
# [ 0] 18:53:02.8 Driver arrived at Customer 58 at (4500, 2960)
# [ 0] 18:54:02.8 Customer 58 at (4500, 2960) not at home
# [ 0] 18:54:02.8 Driver drives to Customer 85 at (6117, 5560)
# [ 0] 19:10:54.9 Driver arrived at Customer 85 at (6117, 5560)
# [ 0] 19:11:54.9 Customer 85 at (6117, 5560) not at home
# [ 0] 19:11:54.9 Driver drives to Customer 66 at (4500, 6013)
# [ 0] 19:20:11.7 Driver arrived at Customer 66 at (4500, 6013)
# [ 0] 19:21:11.7 Customer 66 at (4500, 6013) not at home
# [ 0] 19:21:11.7 Driver drives to Customer 68 at (4500, 6293)
# [ 0] 19:22:18.9 Driver arrived at Customer 68 at (4500, 6293)
# [ 0] 19:23:18.9 Customer 68 at (4500, 6293) not at home
# [ 0] 19:23:18.9 Driver drives to Customer 69 at (4500, 7022)
# [ 0] 19:26:13.9 Driver arrived at Customer 69 at (4500, 7022)
# [ 0] 19:27:13.9 Customer 69 at (4500, 7022) not at home
# [ 0] 19:27:13.9 Driver drives to Customer 70 at (4500, 7788)
# [ 0] 19:30:17.7 Driver arrived at Customer 70 at (4500, 7788)
# [ 0] 19:31:17.7 Customer 70 at (4500, 7788) not at home
# [ 0] 19:31:17.7 Driver drives to Customer 71 at (4500, 8018)
# [ 0] 19:32:12.9 Driver arrived at Customer 71 at (4500, 8018)
# [ 0] 19:33:12.9 Customer 71 at (4500, 8018) not at home
# [ 0] 19:33:12.9 Driver drives to Customer 72 at (4630, 8740)
# [ 0] 19:36:37.4 Driver arrived at Customer 72 at (4630, 8740)
# [ 0] 19:37:37.4 Customer 72 at (4630, 8740) not at home
# [ 0] 19:37:37.4 Driver drives to Customer 73 at (4853, 8740)
# [ 0] 19:38:30.9 Driver arrived at Customer 73 at (4853, 8740)
# [ 0] 19:39:30.9 Customer 73 at (4853, 8740) not at home
# [ 0] 19:39:30.9 Driver drives to Customer 56 at (4173, 7680)
# [ 0] 19:46:28.5 Driver arrived at Customer 56 at (4173, 7680)
# [ 0] 19:47:28.5 Customer 56 at (4173, 7680) not at home
# [ 0] 19:47:28.5 Driver drives to Customer 51 at (3758, 7680)
# [ 0] 19:49:08.1 Driver arrived at Customer 51 at (3758, 7680)
# [ 0] 19:50:08.1 Customer 51 at (3758, 7680) not at home
# [ 0] 19:50:08.1 Driver drives to Customer 50 at (3623, 7680)
# [ 0] 19:50:40.5 Driver arrived at Customer 50 at (3623, 7680)
# [ 0] 19:51:40.5 Customer 50 at (3623, 7680) not at home
# [ 0] 19:51:40.5 Driver drives to Customer 12 at (2294, 8654)
# [ 0] 19:58:53.2 Driver arrived at Customer 12 at (2294, 8654)
# [ 0] 19:59:53.2 Customer 12 at (2294, 8654) not at home
# [ 0] 19:59:53.2 Driver drives to Customer 7 at (1577, 7937)
# [ 0] 20:03:56.3 Driver arrived at Customer 7 at (1577, 7937)
# [ 0] 20:04:21.8 Customer 7 at (1577, 7937) answers door
# [ 0] 20:04:21.8 Customer 7 at (1577, 7937) accepts Parcel 2 for cust 7
# [ 0] 20:04:23.4 Customer 7 at (1577, 7937) signs off
# [ 0] 20:04:23.8 Driver drives to Customer 2 at (1320, 6990)
# [ 0] 20:08:36.5 Driver arrived at Customer 2 at (1320, 6990)
# [ 0] 20:09:36.5 Customer 2 at (1320, 6990) not at home
# [ 0] 20:09:36.5 Driver drives to Customer 1 at (1320, 6844)
# [ 0] 20:10:11.5 Driver arrived at Customer 1 at (1320, 6844)
# [ 0] 20:11:11.5 Customer 1 at (1320, 6844) not at home
# [ 0] 20:11:11.5 Driver drives to Customer 23 at (2380, 4049)
# [ 0] 20:27:46.8 Driver arrived at Customer 23 at (2380, 4049)
# [ 0] 20:28:46.8 Customer 23 at (2380, 4049) not at home
# [ 0] 20:28:46.8 Driver drives to Customer 19 at (2380, 2717)
# [ 0] 20:34:06.5 Driver arrived at Customer 19 at (2380, 2717)
# [ 0] 20:35:06.5 Customer 19 at (2380, 2717) not at home
# [ 0] 20:35:06.5 Driver drives to Customer 37 at (3305, 2380)
# [ 0] 20:40:09.4 Driver arrived at Customer 37 at (3305, 2380)
# [ 0] 20:41:09.4 Customer 37 at (3305, 2380) not at home
# [ 0] 20:41:09.4 Driver drives to Customer 16 at (2380, 1560)
# [ 0] 20:48:08.2 Driver arrived at Customer 16 at (2380, 1560)
# [ 0] 20:49:08.2 Customer 16 at (2380, 1560) not at home
# [ 0] 20:49:08.2 Driver drives to Customer 15 at (2380, 1445)
# [ 0] 20:49:35.8 Driver arrived at Customer 15 at (2380, 1445)
# [ 0] 20:50:14.2 Customer 15 at (2380, 1445) answers door
# [ 0] 20:50:14.2 Customer 15 at (2380, 1445) accepts Parcel 5 for cust 15
# [ 0] 20:50:24.1 Customer 15 at (2380, 1445) signs off
# [ 0] 20:50:25.3 Driver drives to Customer 29 at (2758, 1320)
# [ 0] 20:52:26.0 Driver arrived at Customer 29 at (2758, 1320)
# [ 0] 20:53:26.0 Customer 29 at (2758, 1320) not at home
# [ 0] 20:53:26.0 Driver drives to Customer 13 at (2380, 561)
# [ 0] 20:57:58.9 Driver arrived at Customer 13 at (2380, 561)
# [ 0] 20:58:58.9 Customer 13 at (2380, 561) not at home
# [ 0] 20:58:58.9 Driver drives to Customer 49 at (3545, 260)
# [ 0] 21:04:50.7 Driver arrived at Customer 49 at (3545, 260)
# [ 0] 21:05:50.7 Customer 49 at (3545, 260) not at home
# [ 0] 21:05:50.7 Driver drives to Customer 52 at (3769, 260)
# [ 0] 21:06:44.5 Driver arrived at Customer 52 at (3769, 260)
# [ 0] 21:07:44.5 Customer 52 at (3769, 260) not at home
# [ 0] 21:07:44.5 Driver drives to Customer 53 at (3917, 260)
# [ 0] 21:08:20.0 Driver arrived at Customer 53 at (3917, 260)
# [ 0] 21:08:51.8 Customer 53 at (3917, 260) answers door
# [ 0] 21:08:51.8 Customer 53 at (3917, 260) accepts Parcel 26 for cust 53
# [ 0] 21:08:56.1 Customer 53 at (3917, 260) signs off
# [ 0] 21:09:00.9 Driver drives to Customer 55 at (4094, 260)
# [ 0] 21:09:43.4 Driver arrived at Customer 55 at (4094, 260)
# [ 0] 21:10:43.3 Customer 55 at (4094, 260) answers door
# [ 0] 21:10:43.3 Customer 55 at (4094, 260) accepts Parcel 27 for cust 55
# [ 0] 21:10:50.1 Customer 55 at (4094, 260) accepts Parcel 28 for cust 55
# [ 0] 21:11:11.4 Customer 55 at (4094, 260) signs off
# [ 0] 21:11:20.8 Driver drives to Customer 38 at (3440, 440)
# [ 0] 21:14:41.0 Driver arrived at Customer 38 at (3440, 440)
# [ 0] 21:15:41.0 Customer 38 at (3440, 440) not at home
# [ 0] 21:15:41.0 Driver drives to Customer 39 at (3440, 641)
# [ 0] 21:16:29.2 Driver arrived at Customer 39 at (3440, 641)
# [ 0] 21:17:29.2 Customer 39 at (3440, 641) not at home
# [ 0] 21:17:29.2 Driver drives to Customer 43 at (3440, 1165)
# [ 0] 21:19:35.0 Driver arrived at Customer 43 at (3440, 1165)
# [ 0] 21:20:35.0 Customer 43 at (3440, 1165) not at home
# [ 0] 21:20:35.0 Driver drives to Customer 44 at (3440, 1751)
# [ 0] 21:22:55.6 Driver arrived at Customer 44 at (3440, 1751)
# [ 0] 21:23:55.6 Customer 44 at (3440, 1751) not at home
# [ 0] 21:23:55.6 Driver drives to Customer 45 at (3440, 1869)
# [ 0] 21:24:23.9 Driver arrived at Customer 45 at (3440, 1869)
# [ 0] 21:25:23.9 Customer 45 at (3440, 1869) not at home
# [ 0] 21:25:23.9 Driver drives to Customer 46 at (3440, 2013)
# [ 0] 21:25:58.5 Driver arrived at Customer 46 at (3440, 2013)
# [ 0] 21:26:58.5 Customer 46 at (3440, 2013) not at home
# [ 0] 21:26:58.5 Driver drives to Customer 47 at (3440, 2110)
# [ 0] 21:27:21.8 Driver arrived at Customer 47 at (3440, 2110)
# [ 0] 21:28:21.8 Customer 47 at (3440, 2110) not at home
# [ 0] 21:28:21.8 Driver drives to Customer 76 at (5226, 1653)
# [ 0] 21:37:47.4 Driver arrived at Customer 76 at (5226, 1653)
# [ 0] 21:38:47.4 Customer 76 at (5226, 1653) not at home
# [ 0] 21:38:47.4 Driver drives to Customer 79 at (5736, 1320)
# [ 0] 21:41:22.7 Driver arrived at Customer 79 at (5736, 1320)
# [ 0] 21:42:22.7 Customer 79 at (5736, 1320) not at home
# [ 0] 21:42:22.7 Driver drives to Customer 84 at (6012, 1320)
# [ 0] 21:43:29.0 Driver arrived at Customer 84 at (6012, 1320)
# [ 0] 21:44:29.0 Customer 84 at (6012, 1320) not at home
# [ 0] 21:44:29.0 Driver drives to Customer 86 at (6203, 1320)
# [ 0] 21:45:14.8 Driver arrived at Customer 86 at (6203, 1320)
# [ 0] 21:46:14.8 Customer 86 at (6203, 1320) not at home
# [ 0] 21:46:14.8 Driver returns to delivery centre
# [ 0] 22:03:17.4 Driver arrived at delivery centre
# [ 0] 22:03:17.4 Parcel 33 for cust 62 return from delivery
# [ 0] 22:03:47.4 Parcel 31 for cust 59 return from delivery
# [ 0] 22:04:17.4 Parcel 30 for cust 58 return from delivery
# [ 0] 22:04:47.4 Parcel 49 for cust 85 return from delivery
# [ 0] 22:05:17.4 Parcel 34 for cust 66 return from delivery
# [ 0] 22:05:47.4 Parcel 35 for cust 68 return from delivery
# [ 0] 22:06:17.4 Parcel 36 for cust 69 return from delivery
# [ 0] 22:06:47.4 Parcel 37 for cust 70 return from delivery
# [ 0] 22:07:17.4 Parcel 38 for cust 70 return from delivery
# [ 0] 22:07:47.4 Parcel 39 for cust 71 return from delivery
# [ 0] 22:08:17.4 Parcel 40 for cust 72 return from delivery
# [ 0] 22:08:47.4 Parcel 41 for cust 73 return from delivery
# [ 0] 22:09:17.4 Parcel 42 for cust 73 return from delivery
# [ 0] 22:09:47.4 Parcel 29 for cust 56 return from delivery
# [ 0] 22:10:17.4 Parcel 24 for cust 51 return from delivery
# [ 0] 22:10:47.4 Parcel 23 for cust 50 return from delivery
# [ 0] 22:11:17.4 Parcel 3 for cust 12 return from delivery
# [ 0] 22:11:47.4 Parcel 1 for cust 2 return from delivery
# [ 0] 22:12:17.4 Parcel 0 for cust 1 return from delivery
# [ 0] 22:12:47.4 Parcel 8 for cust 23 return from delivery
# [ 0] 22:13:17.4 Parcel 7 for cust 19 return from delivery
# [ 0] 22:13:47.4 Parcel 10 for cust 37 return from delivery
# [ 0] 22:14:17.4 Parcel 6 for cust 16 return from delivery
# [ 0] 22:14:47.4 Parcel 9 for cust 29 return from delivery
# [ 0] 22:15:17.4 Parcel 4 for cust 13 return from delivery
# [ 0] 22:15:47.4 Parcel 22 for cust 49 return from delivery
# [ 0] 22:16:17.4 Parcel 25 for cust 52 return from delivery
# [ 0] 22:16:47.4 Parcel 11 for cust 38 return from delivery
# [ 0] 22:17:17.4 Parcel 12 for cust 39 return from delivery
# [ 0] 22:17:47.4 Parcel 13 for cust 43 return from delivery
# [ 0] 22:18:17.4 Parcel 14 for cust 43 return from delivery
# [ 0] 22:18:47.4 Parcel 15 for cust 44 return from delivery
# [ 0] 22:19:17.4 Parcel 16 for cust 44 return from delivery
# [ 0] 22:19:47.4 Parcel 17 for cust 44 return from delivery
# [ 0] 22:20:17.4 Parcel 18 for cust 45 return from delivery
# [ 0] 22:20:47.4 Parcel 19 for cust 45 return from delivery
# [ 0] 22:21:17.4 Parcel 20 for cust 46 return from delivery
# [ 0] 22:21:47.4 Parcel 21 for cust 47 return from delivery
# [ 0] 22:22:17.4 Parcel 43 for cust 76 return from delivery
# [ 0] 22:22:47.4 Parcel 44 for cust 76 return from delivery
# [ 0] 22:23:17.4 Parcel 45 for cust 76 return from delivery
# [ 0] 22:23:47.4 Parcel 46 for cust 79 return from delivery
# [ 0] 22:24:17.4 Parcel 47 for cust 84 return from delivery
# [ 0] 22:24:47.4 Parcel 48 for cust 84 return from delivery
# [ 0] 22:25:17.4 Parcel 50 for cust 86 return from delivery
# [ 0] 22:25:47.4 Parcel 51 for cust 86 return from delivery
# [ 0] 22:26:17.4 Parcel 52 for cust 86 return from delivery
# [ 0] 22:26:47.4 56 parcels left for next day
# [ 0] 22:36:47.4 Driver goes home
# [ 1] 17:00:00.0 Parcel 62 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 63 for cust 2 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 64 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 65 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 66 for cust 4 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 67 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 68 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 69 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 70 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 71 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 72 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 73 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 74 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 75 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 76 for cust 22 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 77 for cust 24 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 78 for cust 28 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 79 for cust 32 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 80 for cust 36 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 81 for cust 39 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 82 for cust 40 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 83 for cust 41 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 84 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 85 for cust 45 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 86 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 87 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 88 for cust 46 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 89 for cust 47 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 90 for cust 50 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 91 for cust 51 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 92 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 93 for cust 54 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 94 for cust 55 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 95 for cust 56 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 96 for cust 57 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 97 for cust 58 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 98 for cust 60 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 99 for cust 62 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 100 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 101 for cust 64 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 102 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 103 for cust 67 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 104 for cust 73 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 105 for cust 75 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 106 for cust 80 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 107 for cust 81 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 108 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 109 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 110 for cust 82 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 111 for cust 85 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 112 for cust 88 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 113 for cust 90 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 114 for cust 93 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 115 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 116 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 117 for cust 94 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 118 for cust 96 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 99 for cust 62 out for delivery
# [ 1] 18:00:00.0 Parcel 98 for cust 60 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 97 for cust 58 out for delivery
# [ 1] 18:00:00.0 Parcel 96 for cust 57 out for delivery
# [ 1] 18:00:00.0 Parcel 43 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 44 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 45 for cust 76 out for delivery
# [ 1] 18:00:00.0 Parcel 46 for cust 79 out for delivery
# [ 1] 18:00:00.0 Parcel 107 for cust 81 out for delivery
# [ 1] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 48 for cust 84 out for delivery
# [ 1] 18:00:00.0 Parcel 50 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 51 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 52 for cust 86 out for delivery
# [ 1] 18:00:00.0 Parcel 112 for cust 88 out for delivery
# [ 1] 18:00:00.0 Parcel 56 for cust 95 out for delivery
# [ 1] 18:00:00.0 Parcel 57 for cust 95 out for delivery
# [ 1] 18:00:00.0 Parcel 58 for cust 95 out for delivery
# [ 1] 18:00:00.0 Parcel 118 for cust 96 out for delivery
# [ 1] 18:00:00.0 Parcel 59 for cust 97 out for delivery
# [ 1] 18:00:00.0 Parcel 60 for cust 98 out for delivery
# [ 1] 18:00:00.0 Parcel 61 for cust 99 out for delivery
# [ 1] 18:00:00.0 Parcel 100 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 101 for cust 64 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 66 out for delivery
# [ 1] 18:00:00.0 Parcel 102 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 103 for cust 67 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 68 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 69 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 56 out for delivery
# [ 1] 18:00:00.0 Parcel 95 for cust 56 out for delivery
# [ 1] 18:00:00.0 Parcel 92 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 93 for cust 54 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 1] 18:00:00.0 Parcel 91 for cust 51 out for delivery
# [ 1] 18:00:00.0 Parcel 23 for cust 50 out for delivery
# [ 1] 18:00:00.0 Parcel 90 for cust 50 out for delivery
# [ 1] 18:00:00.0 Parcel 79 for cust 32 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 1] 18:00:00.0 Parcel 69 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 38 for cust 70 out for delivery
# [ 1] 18:00:00.0 Parcel 39 for cust 71 out for delivery
# [ 1] 18:00:00.0 Parcel 40 for cust 72 out for delivery
# [ 1] 18:00:00.0 Parcel 41 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 42 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 104 for cust 73 out for delivery
# [ 1] 18:00:00.0 Parcel 105 for cust 75 out for delivery
# [ 1] 18:00:00.0 Parcel 108 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 109 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 110 for cust 82 out for delivery
# [ 1] 18:00:00.0 Parcel 53 for cust 87 out for delivery
# [ 1] 18:00:00.0 Parcel 106 for cust 80 out for delivery
# [ 1] 18:00:00.0 Parcel 49 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 111 for cust 85 out for delivery
# [ 1] 18:00:00.0 Parcel 54 for cust 90 out for delivery
# [ 1] 18:00:00.0 Parcel 113 for cust 90 out for delivery
# [ 1] 18:00:00.0 Parcel 55 for cust 91 out for delivery
# [ 1] 18:50:50.0 Driver leaves for delivery of 61 parcels to 39 customers
# [ 1] 18:50:50.0 Length of delivery tour: 39,836m
# [ 1] 18:50:50.0 Driver drives to Customer 62 at (4500, 4006)
# [ 1] 18:52:48.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 1] 18:53:48.6 Customer 62 at (4500, 4006) not at home
# [ 1] 18:53:48.6 Driver drives to Customer 60 at (4500, 3173)
# [ 1] 18:57:08.5 Driver arrived at Customer 60 at (4500, 3173)
# [ 1] 18:58:08.5 Customer 60 at (4500, 3173) not at home
# [ 1] 18:58:08.5 Driver drives to Customer 59 at (4500, 3088)
# [ 1] 18:58:28.9 Driver arrived at Customer 59 at (4500, 3088)
# [ 1] 18:59:28.9 Customer 59 at (4500, 3088) not at home
# [ 1] 18:59:28.9 Driver drives to Customer 58 at (4500, 2960)
# [ 1] 18:59:59.6 Driver arrived at Customer 58 at (4500, 2960)
# [ 1] 19:00:59.6 Customer 58 at (4500, 2960) not at home
# [ 1] 19:00:59.6 Driver drives to Customer 57 at (4500, 2596)
# [ 1] 19:02:27.0 Driver arrived at Customer 57 at (4500, 2596)
# [ 1] 19:03:27.0 Customer 57 at (4500, 2596) not at home
# [ 1] 19:03:27.0 Driver drives to Customer 76 at (5226, 1653)
# [ 1] 19:08:25.3 Driver arrived at Customer 76 at (5226, 1653)
# [ 1] 19:09:25.3 Customer 76 at (5226, 1653) not at home
# [ 1] 19:09:25.3 Driver drives to Customer 79 at (5736, 1320)
# [ 1] 19:12:00.6 Driver arrived at Customer 79 at (5736, 1320)
# [ 1] 19:13:00.6 Customer 79 at (5736, 1320) not at home
# [ 1] 19:13:00.6 Driver drives to Customer 81 at (5915, 1320)
# [ 1] 19:13:43.5 Driver arrived at Customer 81 at (5915, 1320)
# [ 1] 19:13:49.2 Customer 81 at (5915, 1320) answers door
# [ 1] 19:13:49.2 Customer 81 at (5915, 1320) accepts Parcel 107 for cust 81
# [ 1] 19:13:49.4 Customer 81 at (5915, 1320) signs off
# [ 1] 19:13:50.2 Driver drives to Customer 84 at (6012, 1320)
# [ 1] 19:14:13.5 Driver arrived at Customer 84 at (6012, 1320)
# [ 1] 19:15:13.5 Customer 84 at (6012, 1320) not at home
# [ 1] 19:15:13.5 Driver drives to Customer 86 at (6203, 1320)
# [ 1] 19:15:59.3 Driver arrived at Customer 86 at (6203, 1320)
# [ 1] 19:16:02.4 Customer 86 at (6203, 1320) answers door
# [ 1] 19:16:02.4 Customer 86 at (6203, 1320) accepts Parcel 50 for cust 86
# [ 1] 19:16:07.8 Customer 86 at (6203, 1320) accepts Parcel 51 for cust 86
# [ 1] 19:16:15.8 Customer 86 at (6203, 1320) accepts Parcel 52 for cust 86
# [ 1] 19:16:29.3 Customer 86 at (6203, 1320) signs off
# [ 1] 19:16:30.9 Driver drives to Customer 88 at (6370, 1320)
# [ 1] 19:17:10.9 Driver arrived at Customer 88 at (6370, 1320)
# [ 1] 19:18:10.9 Customer 88 at (6370, 1320) not at home
# [ 1] 19:18:10.9 Driver drives to Customer 95 at (7141, 2380)
# [ 1] 19:25:30.4 Driver arrived at Customer 95 at (7141, 2380)
# [ 1] 19:26:30.4 Customer 95 at (7141, 2380) not at home
# [ 1] 19:26:30.4 Driver drives to Customer 96 at (8035, 2380)
# [ 1] 19:30:04.9 Driver arrived at Customer 96 at (8035, 2380)
# [ 1] 19:31:04.9 Customer 96 at (8035, 2380) not at home
# [ 1] 19:31:04.9 Driver drives to Customer 97 at (8360, 2380)
# [ 1] 19:32:22.9 Driver arrived at Customer 97 at (8360, 2380)
# [ 1] 19:33:22.9 Customer 97 at (8360, 2380) not at home
# [ 1] 19:33:22.9 Driver drives to Customer 98 at (8520, 2380)
# [ 1] 19:34:01.3 Driver arrived at Customer 98 at (8520, 2380)
# [ 1] 19:35:01.3 Customer 98 at (8520, 2380) not at home
# [ 1] 19:35:01.3 Driver drives to Customer 99 at (8740, 3028)
# [ 1] 19:38:29.7 Driver arrived at Customer 99 at (8740, 3028)
# [ 1] 19:39:29.7 Customer 99 at (8740, 3028) not at home
# [ 1] 19:39:29.7 Driver drives to Customer 64 at (4500, 4955)
# [ 1] 20:15:20.3 Driver arrived at Customer 64 at (4500, 4955)
# [ 1] 20:16:20.3 Customer 64 at (4500, 4955) not at home
# [ 1] 20:16:20.3 Driver drives to Customer 66 at (4500, 6013)
# [ 1] 20:20:34.2 Driver arrived at Customer 66 at (4500, 6013)
# [ 1] 20:21:34.2 Customer 66 at (4500, 6013) not at home
# [ 1] 20:21:34.2 Driver drives to Customer 67 at (4500, 6129)
# [ 1] 20:22:02.1 Driver arrived at Customer 67 at (4500, 6129)
# [ 1] 20:23:02.1 Customer 67 at (4500, 6129) not at home
# [ 1] 20:23:02.1 Driver drives to Customer 68 at (4500, 6293)
# [ 1] 20:23:41.4 Driver arrived at Customer 68 at (4500, 6293)
# [ 1] 20:24:41.4 Customer 68 at (4500, 6293) not at home
# [ 1] 20:24:41.4 Driver drives to Customer 69 at (4500, 7022)
# [ 1] 20:27:36.4 Driver arrived at Customer 69 at (4500, 7022)
# [ 1] 20:28:36.4 Customer 69 at (4500, 7022) not at home
# [ 1] 20:28:36.4 Driver drives to Customer 56 at (4173, 7680)
# [ 1] 20:32:32.8 Driver arrived at Customer 56 at (4173, 7680)
# [ 1] 20:32:54.7 Customer 56 at (4173, 7680) answers door
# [ 1] 20:32:54.7 Customer 56 at (4173, 7680) accepts Parcel 29 for cust 56
# [ 1] 20:33:04.9 Customer 56 at (4173, 7680) accepts Parcel 95 for cust 56
# [ 1] 20:33:05.7 Customer 56 at (4173, 7680) signs off
# [ 1] 20:33:11.6 Driver drives to Customer 54 at (3974, 7680)
# [ 1] 20:33:59.4 Driver arrived at Customer 54 at (3974, 7680)
# [ 1] 20:34:59.4 Customer 54 at (3974, 7680) not at home
# [ 1] 20:34:59.4 Driver drives to Customer 51 at (3758, 7680)
# [ 1] 20:35:51.2 Driver arrived at Customer 51 at (3758, 7680)
# [ 1] 20:36:51.2 Customer 51 at (3758, 7680) not at home
# [ 1] 20:36:51.2 Driver drives to Customer 50 at (3623, 7680)
# [ 1] 20:37:23.6 Driver arrived at Customer 50 at (3623, 7680)
# [ 1] 20:38:23.6 Customer 50 at (3623, 7680) not at home
# [ 1] 20:38:23.6 Driver drives to Customer 32 at (2925, 8194)
# [ 1] 20:42:02.0 Driver arrived at Customer 32 at (2925, 8194)
# [ 1] 20:43:02.0 Customer 32 at (2925, 8194) not at home
# [ 1] 20:43:02.0 Driver drives to Customer 12 at (2294, 8654)
# [ 1] 20:46:36.1 Driver arrived at Customer 12 at (2294, 8654)
# [ 1] 20:47:36.1 Customer 12 at (2294, 8654) not at home
# [ 1] 20:47:36.1 Driver drives to Customer 11 at (2223, 8583)
# [ 1] 20:48:00.1 Driver arrived at Customer 11 at (2223, 8583)
# [ 1] 20:49:00.1 Customer 11 at (2223, 8583) not at home
# [ 1] 20:49:00.1 Driver drives to Customer 70 at (4500, 7788)
# [ 1] 21:00:33.0 Driver arrived at Customer 70 at (4500, 7788)
# [ 1] 21:01:33.0 Customer 70 at (4500, 7788) not at home
# [ 1] 21:01:33.0 Driver drives to Customer 71 at (4500, 8018)
# [ 1] 21:02:28.2 Driver arrived at Customer 71 at (4500, 8018)
# [ 1] 21:03:28.2 Customer 71 at (4500, 8018) not at home
# [ 1] 21:03:28.2 Driver drives to Customer 72 at (4630, 8740)
# [ 1] 21:06:52.7 Driver arrived at Customer 72 at (4630, 8740)
# [ 1] 21:07:52.7 Customer 72 at (4630, 8740) not at home
# [ 1] 21:07:52.7 Driver drives to Customer 73 at (4853, 8740)
# [ 1] 21:08:46.2 Driver arrived at Customer 73 at (4853, 8740)
# [ 1] 21:09:46.2 Customer 73 at (4853, 8740) not at home
# [ 1] 21:09:46.2 Driver drives to Customer 75 at (5211, 8740)
# [ 1] 21:11:12.1 Driver arrived at Customer 75 at (5211, 8740)
# [ 1] 21:11:30.5 Customer 75 at (5211, 8740) answers door
# [ 1] 21:11:30.5 Customer 75 at (5211, 8740) accepts Parcel 105 for cust 75
# [ 1] 21:12:00.3 Customer 75 at (5211, 8740) signs off
# [ 1] 21:12:00.9 Driver drives to Customer 82 at (5931, 8740)
# [ 1] 21:14:53.7 Driver arrived at Customer 82 at (5931, 8740)
# [ 1] 21:15:14.7 Customer 82 at (5931, 8740) answers door
# [ 1] 21:15:14.7 Customer 82 at (5931, 8740) accepts Parcel 108 for cust 82
# [ 1] 21:15:20.1 Customer 82 at (5931, 8740) accepts Parcel 109 for cust 82
# [ 1] 21:15:33.1 Customer 82 at (5931, 8740) accepts Parcel 110 for cust 82
# [ 1] 21:15:37.0 Customer 82 at (5931, 8740) signs off
# [ 1] 21:15:39.3 Driver drives to Customer 87 at (6285, 8740)
# [ 1] 21:17:04.2 Driver arrived at Customer 87 at (6285, 8740)
# [ 1] 21:18:04.2 Customer 87 at (6285, 8740) not at home
# [ 1] 21:18:04.2 Driver drives to Customer 80 at (5832, 5560)
# [ 1] 21:43:15.5 Driver arrived at Customer 80 at (5832, 5560)
# [ 1] 21:44:15.5 Customer 80 at (5832, 5560) not at home
# [ 1] 21:44:15.5 Driver drives to Customer 85 at (6117, 5560)
# [ 1] 21:45:23.9 Driver arrived at Customer 85 at (6117, 5560)
# [ 1] 21:46:23.9 Customer 85 at (6117, 5560) not at home
# [ 1] 21:46:23.9 Driver drives to Customer 90 at (6620, 5883)
# [ 1] 21:49:42.1 Driver arrived at Customer 90 at (6620, 5883)
# [ 1] 21:50:42.1 Customer 90 at (6620, 5883) not at home
# [ 1] 21:50:42.1 Driver drives to Customer 91 at (6620, 6048)
# [ 1] 21:51:21.7 Driver arrived at Customer 91 at (6620, 6048)
# [ 1] 21:51:35.6 Customer 91 at (6620, 6048) answers door
# [ 1] 21:51:35.6 Customer 91 at (6620, 6048) accepts Parcel 55 for cust 91
# [ 1] 21:51:42.0 Customer 91 at (6620, 6048) signs off
# [ 1] 21:52:12.0 Driver returns to delivery centre
# [ 1] 22:06:52.3 Driver arrived at delivery centre
# [ 1] 22:06:52.3 Parcel 33 for cust 62 return from delivery
# [ 1] 22:07:22.3 Parcel 99 for cust 62 return from delivery
# [ 1] 22:07:52.3 Parcel 98 for cust 60 return from delivery
# [ 1] 22:08:22.3 Parcel 31 for cust 59 return from delivery
# [ 1] 22:08:52.3 Parcel 30 for cust 58 return from delivery
# [ 1] 22:09:22.3 Parcel 97 for cust 58 return from delivery
# [ 1] 22:09:52.3 Parcel 96 for cust 57 return from delivery
# [ 1] 22:10:22.3 Parcel 43 for cust 76 return from delivery
# [ 1] 22:10:52.3 Parcel 44 for cust 76 return from delivery
# [ 1] 22:11:22.3 Parcel 45 for cust 76 return from delivery
# [ 1] 22:11:52.3 Parcel 46 for cust 79 return from delivery
# [ 1] 22:12:22.3 Parcel 47 for cust 84 return from delivery
# [ 1] 22:12:52.3 Parcel 48 for cust 84 return from delivery
# [ 1] 22:13:22.3 Parcel 112 for cust 88 return from delivery
# [ 1] 22:13:52.3 Parcel 56 for cust 95 return from delivery
# [ 1] 22:14:22.3 Parcel 57 for cust 95 return from delivery
# [ 1] 22:14:52.3 Parcel 58 for cust 95 return from delivery
# [ 1] 22:15:22.3 Parcel 118 for cust 96 return from delivery
# [ 1] 22:15:52.3 Parcel 59 for cust 97 return from delivery
# [ 1] 22:16:22.3 Parcel 60 for cust 98 return from delivery
# [ 1] 22:16:52.3 Parcel 61 for cust 99 return from delivery
# [ 1] 22:17:22.3 Parcel 100 for cust 64 return from delivery
# [ 1] 22:17:52.3 Parcel 101 for cust 64 return from delivery
# [ 1] 22:18:22.3 Parcel 34 for cust 66 return from delivery
# [ 1] 22:18:52.3 Parcel 102 for cust 67 return from delivery
# [ 1] 22:19:22.3 Parcel 103 for cust 67 return from delivery
# [ 1] 22:19:52.3 Parcel 35 for cust 68 return from delivery
# [ 1] 22:20:22.3 Parcel 36 for cust 69 return from delivery
# [ 1] 22:20:52.3 Parcel 92 for cust 54 return from delivery
# [ 1] 22:21:22.3 Parcel 93 for cust 54 return from delivery
# [ 1] 22:21:52.3 Parcel 24 for cust 51 return from delivery
# [ 1] 22:22:22.3 Parcel 91 for cust 51 return from delivery
# [ 1] 22:22:52.3 Parcel 23 for cust 50 return from delivery
# [ 1] 22:23:22.3 Parcel 90 for cust 50 return from delivery
# [ 1] 22:23:52.3 Parcel 79 for cust 32 return from delivery
# [ 1] 22:24:22.3 Parcel 3 for cust 12 return from delivery
# [ 1] 22:24:52.3 Parcel 69 for cust 11 return from delivery
# [ 1] 22:25:22.3 Parcel 37 for cust 70 return from delivery
# [ 1] 22:25:52.3 Parcel 38 for cust 70 return from delivery
# [ 1] 22:26:22.3 Parcel 39 for cust 71 return from delivery
# [ 1] 22:26:52.3 Parcel 40 for cust 72 return from delivery
# [ 1] 22:27:22.3 Parcel 41 for cust 73 return from delivery
# [ 1] 22:27:52.3 Parcel 42 for cust 73 return from delivery
# [ 1] 22:28:22.3 Parcel 104 for cust 73 return from delivery
# [ 1] 22:28:52.3 Parcel 53 for cust 87 return from delivery
# [ 1] 22:29:22.3 Parcel 106 for cust 80 return from delivery
# [ 1] 22:29:52.3 Parcel 49 for cust 85 return from delivery
# [ 1] 22:30:22.3 Parcel 111 for cust 85 return from delivery
# [ 1] 22:30:52.3 Parcel 54 for cust 90 return from delivery
# [ 1] 22:31:22.3 Parcel 113 for cust 90 return from delivery
# [ 1] 22:31:52.3 102 parcels left for next day
# [ 1] 22:41:52.3 Driver goes home
# [ 2] 17:00:00.0 Parcel 119 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 120 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 121 for cust 6 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 122 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 123 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 124 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 125 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 126 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 127 for cust 16 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 128 for cust 17 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 129 for cust 20 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 130 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 131 for cust 23 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 132 for cust 24 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 133 for cust 28 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 134 for cust 32 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 135 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 136 for cust 35 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 137 for cust 36 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 138 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 139 for cust 37 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 140 for cust 41 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 141 for cust 45 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 142 for cust 49 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 143 for cust 51 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 144 for cust 52 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 145 for cust 56 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 146 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 147 for cust 59 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 148 for cust 60 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 149 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 150 for cust 61 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 151 for cust 62 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 152 for cust 63 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 153 for cust 64 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 154 for cust 68 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 155 for cust 69 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 156 for cust 70 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 157 for cust 75 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 158 for cust 76 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 159 for cust 79 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 160 for cust 81 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 161 for cust 82 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 162 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 163 for cust 83 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 164 for cust 85 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 165 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 166 for cust 86 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 167 for cust 91 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 168 for cust 93 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 169 for cust 95 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 99 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 151 for cust 62 out for delivery
# [ 2] 18:00:00.0 Parcel 149 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 150 for cust 61 out for delivery
# [ 2] 18:00:00.0 Parcel 98 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 148 for cust 60 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 146 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 147 for cust 59 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 2] 18:00:00.0 Parcel 97 for cust 58 out for delivery
# [ 2] 18:00:00.0 Parcel 96 for cust 57 out for delivery
# [ 2] 18:00:00.0 Parcel 152 for cust 63 out for delivery
# [ 2] 18:00:00.0 Parcel 100 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 101 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 153 for cust 64 out for delivery
# [ 2] 18:00:00.0 Parcel 106 for cust 80 out for delivery
# [ 2] 18:00:00.0 Parcel 162 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 163 for cust 83 out for delivery
# [ 2] 18:00:00.0 Parcel 49 for cust 85 out for delivery
# [ 2] 18:00:00.0 Parcel 111 for cust 85 out for delivery
# [ 2] 18:00:00.0 Parcel 164 for cust 85 out for delivery
# [ 2] 18:00:00.0 Parcel 54 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 113 for cust 90 out for delivery
# [ 2] 18:00:00.0 Parcel 167 for cust 91 out for delivery
# [ 2] 18:00:00.0 Parcel 114 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 168 for cust 93 out for delivery
# [ 2] 18:00:00.0 Parcel 115 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 116 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 117 for cust 94 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 66 out for delivery
# [ 2] 18:00:00.0 Parcel 102 for cust 67 out for delivery
# [ 2] 18:00:00.0 Parcel 103 for cust 67 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 154 for cust 68 out for delivery
# [ 2] 18:00:00.0 Parcel 36 for cust 69 out for delivery
# [ 2] 18:00:00.0 Parcel 155 for cust 69 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 156 for cust 70 out for delivery
# [ 2] 18:00:00.0 Parcel 39 for cust 71 out for delivery
# [ 2] 18:00:00.0 Parcel 145 for cust 56 out for delivery
# [ 2] 18:00:00.0 Parcel 92 for cust 54 out for delivery
# [ 2] 18:00:00.0 Parcel 93 for cust 54 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 51 out for delivery
# [ 2] 18:00:00.0 Parcel 91 for cust 51 out for delivery
# [ 2] 18:00:00.0 Parcel 143 for cust 51 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 90 for cust 50 out for delivery
# [ 2] 18:00:00.0 Parcel 79 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 134 for cust 32 out for delivery
# [ 2] 18:00:00.0 Parcel 3 for cust 12 out for delivery
# [ 2] 18:00:00.0 Parcel 69 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 68 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 122 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 66 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 120 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 64 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 65 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 63 for cust 2 out for delivery
# [ 2] 18:00:00.0 Parcel 0 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 62 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 119 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 77 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 132 for cust 24 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 130 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 131 for cust 23 out for delivery
# [ 2] 18:00:00.0 Parcel 76 for cust 22 out for delivery
# [ 2] 18:00:00.0 Parcel 67 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 123 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 129 for cust 20 out for delivery
# [ 2] 18:00:00.0 Parcel 7 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 75 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 74 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 138 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 139 for cust 37 out for delivery
# [ 2] 18:00:00.0 Parcel 128 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 73 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 127 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 72 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 29 out for delivery
# [ 2] 18:00:00.0 Parcel 70 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 71 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 126 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 124 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 125 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 78 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 133 for cust 28 out for delivery
# [ 2] 18:00:00.0 Parcel 135 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 136 for cust 35 out for delivery
# [ 2] 18:00:00.0 Parcel 80 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 137 for cust 36 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 49 out for delivery
# [ 2] 18:00:00.0 Parcel 142 for cust 49 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 52 out for delivery
# [ 2] 18:00:00.0 Parcel 144 for cust 52 out for delivery
# [ 2] 18:00:00.0 Parcel 94 for cust 55 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 38 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 39 out for delivery
# [ 2] 18:00:00.0 Parcel 81 for cust 39 out for delivery
# [ 2] 18:00:00.0 Parcel 82 for cust 40 out for delivery
# [ 2] 18:00:00.0 Parcel 83 for cust 41 out for delivery
# [ 2] 18:00:00.0 Parcel 140 for cust 41 out for delivery
# [ 2] 18:00:00.0 Parcel 13 for cust 43 out for delivery
# [ 2] 18:00:00.0 Parcel 14 for cust 43 out for delivery
# [ 2] 18:00:00.0 Parcel 15 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 44 out for delivery
# [ 2] 18:00:00.0 Parcel 18 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 84 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 85 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 141 for cust 45 out for delivery
# [ 2] 18:00:00.0 Parcel 20 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 86 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 87 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 88 for cust 46 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 89 for cust 47 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 76 out for delivery
# [ 2] 18:00:00.0 Parcel 158 for cust 76 out for delivery
# [ 2] 19:47:30.0 Driver leaves for delivery of 129 parcels to 64 customers
# [ 2] 19:47:30.0 Length of delivery tour: 39,983m
# [ 2] 19:47:30.0 Driver drives to Customer 62 at (4500, 4006)
# [ 2] 19:49:28.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 2] 19:50:28.6 Customer 62 at (4500, 4006) not at home
# [ 2] 19:50:28.6 Driver drives to Customer 61 at (4500, 3324)
# [ 2] 19:53:12.2 Driver arrived at Customer 61 at (4500, 3324)
# [ 2] 19:54:12.2 Customer 61 at (4500, 3324) not at home
# [ 2] 19:54:12.2 Driver drives to Customer 60 at (4500, 3173)
# [ 2] 19:54:48.5 Driver arrived at Customer 60 at (4500, 3173)
# [ 2] 19:55:48.5 Customer 60 at (4500, 3173) not at home
# [ 2] 19:55:48.5 Driver drives to Customer 59 at (4500, 3088)
# [ 2] 19:56:08.9 Driver arrived at Customer 59 at (4500, 3088)
# [ 2] 19:57:08.9 Customer 59 at (4500, 3088) not at home
# [ 2] 19:57:08.9 Driver drives to Customer 58 at (4500, 2960)
# [ 2] 19:57:39.6 Driver arrived at Customer 58 at (4500, 2960)
# [ 2] 19:58:39.6 Customer 58 at (4500, 2960) not at home
# [ 2] 19:58:39.6 Driver drives to Customer 57 at (4500, 2596)
# [ 2] 20:00:07.0 Driver arrived at Customer 57 at (4500, 2596)
# [ 2] 20:01:07.0 Customer 57 at (4500, 2596) not at home
# [ 2] 20:01:07.0 Driver drives to Customer 63 at (4500, 4714)
# [ 2] 20:09:35.3 Driver arrived at Customer 63 at (4500, 4714)
# [ 2] 20:10:35.3 Customer 63 at (4500, 4714) not at home
# [ 2] 20:10:35.3 Driver drives to Customer 64 at (4500, 4955)
# [ 2] 20:11:33.1 Driver arrived at Customer 64 at (4500, 4955)
# ...
# [ 3] 18:00:00.0 Parcel 42 for cust 73 out for delivery
# [ 3] 18:00:00.0 Parcel 104 for cust 73 out for delivery
# [ 3] 18:00:00.0 Parcel 213 for cust 74 out for delivery
# [ 3] 18:00:00.0 Parcel 214 for cust 74 out for delivery
# [ 3] 18:00:00.0 Parcel 157 for cust 75 out for delivery
# [ 3] 18:00:00.0 Parcel 161 for cust 82 out for delivery
# [ 3] 18:00:00.0 Parcel 53 for cust 87 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 99 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 151 for cust 62 out for delivery
# [ 3] 18:00:00.0 Parcel 149 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 150 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 207 for cust 61 out for delivery
# [ 3] 18:00:00.0 Parcel 98 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 148 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 206 for cust 60 out for delivery
# [ 3] 18:00:00.0 Parcel 31 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 146 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 147 for cust 59 out for delivery
# [ 3] 18:00:00.0 Parcel 30 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 97 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 203 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 204 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 205 for cust 58 out for delivery
# [ 3] 18:00:00.0 Parcel 96 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 202 for cust 57 out for delivery
# [ 3] 18:00:00.0 Parcel 187 for cust 37 out for delivery
# [ 3] 18:00:00.0 Parcel 177 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 129 for cust 20 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 123 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 173 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 121 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 215 for cust 76 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 79 out for delivery
# [ 3] 18:00:00.0 Parcel 159 for cust 79 out for delivery
# [ 3] 18:00:00.0 Parcel 160 for cust 81 out for delivery
# [ 3] 18:00:00.0 Parcel 217 for cust 81 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 84 out for delivery
# [ 3] 18:00:00.0 Parcel 48 for cust 84 out for delivery
# [ 3] 18:00:00.0 Parcel 165 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 166 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 219 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 220 for cust 86 out for delivery
# [ 3] 18:00:00.0 Parcel 112 for cust 88 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 95 out for delivery
# [ 3] 18:00:00.0 Parcel 57 for cust 95 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 95 out for delivery
# [ 3] 18:00:00.0 Parcel 169 for cust 95 out for delivery
# [ 3] 18:00:00.0 Parcel 222 for cust 95 out for delivery
# [ 3] 18:00:00.0 Parcel 118 for cust 96 out for delivery
# [ 3] 18:00:00.0 Parcel 223 for cust 96 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 97 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 98 out for delivery
# [ 3] 18:00:00.0 Parcel 224 for cust 98 out for delivery
# [ 3] 18:00:00.0 Parcel 225 for cust 98 out for delivery
# [ 3] 18:00:00.0 Parcel 61 for cust 99 out for delivery
# [ 3] 18:00:00.0 Parcel 226 for cust 99 out for delivery
# [ 3] 19:10:00.0 Driver leaves for delivery of 84 parcels to 39 customers
# [ 3] 19:10:00.0 Length of delivery tour: 39,990m
# [ 3] 19:10:00.0 Driver drives to Customer 63 at (4500, 4714)
# [ 3] 19:10:51.4 Driver arrived at Customer 63 at (4500, 4714)
# [ 3] 19:11:51.4 Customer 63 at (4500, 4714) not at home
# [ 3] 19:11:51.4 Driver drives to Customer 64 at (4500, 4955)
# [ 3] 19:12:49.2 Driver arrived at Customer 64 at (4500, 4955)
# [ 3] 19:13:49.2 Customer 64 at (4500, 4955) not at home
# [ 3] 19:13:49.2 Driver drives to Customer 80 at (5832, 5560)
# [ 3] 19:21:34.1 Driver arrived at Customer 80 at (5832, 5560)
# [ 3] 19:22:34.1 Customer 80 at (5832, 5560) not at home
# [ 3] 19:22:34.1 Driver drives to Customer 83 at (5946, 5560)
# [ 3] 19:23:01.4 Driver arrived at Customer 83 at (5946, 5560)
# [ 3] 19:24:01.4 Customer 83 at (5946, 5560) not at home
# [ 3] 19:24:01.4 Driver drives to Customer 65 at (4500, 5794)
# [ 3] 19:30:44.6 Driver arrived at Customer 65 at (4500, 5794)
# [ 3] 19:31:44.6 Customer 65 at (4500, 5794) not at home
# [ 3] 19:31:44.6 Driver drives to Customer 66 at (4500, 6013)
# [ 3] 19:32:37.2 Driver arrived at Customer 66 at (4500, 6013)
# [ 3] 19:33:37.2 Customer 66 at (4500, 6013) not at home
# [ 3] 19:33:37.2 Driver drives to Customer 67 at (4500, 6129)
# [ 3] 19:34:05.0 Driver arrived at Customer 67 at (4500, 6129)
# [ 3] 19:35:05.0 Customer 67 at (4500, 6129) not at home
# [ 3] 19:35:05.0 Driver drives to Customer 68 at (4500, 6293)
# [ 3] 19:35:44.4 Driver arrived at Customer 68 at (4500, 6293)
# [ 3] 19:36:44.4 Customer 68 at (4500, 6293) not at home
# [ 3] 19:36:44.4 Driver drives to Customer 69 at (4500, 7022)
# [ 3] 19:39:39.4 Driver arrived at Customer 69 at (4500, 7022)
# [ 3] 19:40:39.4 Customer 69 at (4500, 7022) not at home
# [ 3] 19:40:39.4 Driver drives to Customer 70 at (4500, 7788)
# [ 3] 19:43:43.2 Driver arrived at Customer 70 at (4500, 7788)
# [ 3] 19:44:43.2 Customer 70 at (4500, 7788) not at home
# [ 3] 19:44:43.2 Driver drives to Customer 71 at (4500, 8018)
# [ 3] 19:45:38.4 Driver arrived at Customer 71 at (4500, 8018)
# [ 3] 19:46:38.4 Customer 71 at (4500, 8018) not at home
# [ 3] 19:46:38.4 Driver drives to Customer 72 at (4630, 8740)
# [ 3] 19:50:02.9 Driver arrived at Customer 72 at (4630, 8740)
# [ 3] 19:51:02.9 Customer 72 at (4630, 8740) not at home
# [ 3] 19:51:02.9 Driver drives to Customer 73 at (4853, 8740)
# [ 3] 19:51:56.4 Driver arrived at Customer 73 at (4853, 8740)
# [ 3] 19:52:56.4 Customer 73 at (4853, 8740) not at home
# [ 3] 19:52:56.4 Driver drives to Customer 74 at (5079, 8740)
# [ 3] 19:53:50.6 Driver arrived at Customer 74 at (5079, 8740)
# [ 3] 19:54:50.6 Customer 74 at (5079, 8740) not at home
# [ 3] 19:54:50.6 Driver drives to Customer 75 at (5211, 8740)
# [ 3] 19:55:22.3 Driver arrived at Customer 75 at (5211, 8740)
# [ 3] 19:56:22.3 Customer 75 at (5211, 8740) not at home
# [ 3] 19:56:22.3 Driver drives to Customer 82 at (5931, 8740)
# [ 3] 19:59:15.1 Driver arrived at Customer 82 at (5931, 8740)
# [ 3] 20:00:15.1 Customer 82 at (5931, 8740) not at home
# [ 3] 20:00:15.1 Driver drives to Customer 87 at (6285, 8740)
# [ 3] 20:01:40.1 Driver arrived at Customer 87 at (6285, 8740)
# [ 3] 20:02:40.1 Customer 87 at (6285, 8740) not at home
# [ 3] 20:02:40.1 Driver drives to Customer 62 at (4500, 4006)
# [ 3] 20:28:44.6 Driver arrived at Customer 62 at (4500, 4006)
# [ 3] 20:29:44.6 Customer 62 at (4500, 4006) not at home
# [ 3] 20:29:44.6 Driver drives to Customer 61 at (4500, 3324)
# [ 3] 20:32:28.3 Driver arrived at Customer 61 at (4500, 3324)
# [ 3] 20:32:40.3 Customer 61 at (4500, 3324) answers door
# [ 3] 20:32:40.3 Customer 61 at (4500, 3324) accepts Parcel 149 for cust 61
# [ 3] 20:32:49.6 Customer 61 at (4500, 3324) accepts Parcel 150 for cust 61
# [ 3] 20:33:01.7 Customer 61 at (4500, 3324) accepts Parcel 207 for cust 61
# [ 3] 20:33:19.0 Customer 61 at (4500, 3324) signs off
# [ 3] 20:33:34.4 Driver drives to Customer 60 at (4500, 3173)
# [ 3] 20:34:10.6 Driver arrived at Customer 60 at (4500, 3173)
# [ 3] 20:35:10.6 Customer 60 at (4500, 3173) not at home
# [ 3] 20:35:10.6 Driver drives to Customer 59 at (4500, 3088)
# [ 3] 20:35:31.0 Driver arrived at Customer 59 at (4500, 3088)
# [ 3] 20:35:50.4 Customer 59 at (4500, 3088) answers door
# [ 3] 20:35:50.4 Customer 59 at (4500, 3088) accepts Parcel 31 for cust 59
# [ 3] 20:35:51.0 Customer 59 at (4500, 3088) accepts Parcel 146 for cust 59
# [ 3] 20:35:51.4 Customer 59 at (4500, 3088) accepts Parcel 147 for cust 59
# [ 3] 20:36:04.4 Customer 59 at (4500, 3088) signs off
# [ 3] 20:36:37.0 Driver drives to Customer 58 at (4500, 2960)
# [ 3] 20:37:07.7 Driver arrived at Customer 58 at (4500, 2960)
# [ 3] 20:38:07.7 Customer 58 at (4500, 2960) not at home
# [ 3] 20:38:07.7 Driver drives to Customer 57 at (4500, 2596)
# [ 3] 20:39:35.1 Driver arrived at Customer 57 at (4500, 2596)
# [ 3] 20:40:35.1 Customer 57 at (4500, 2596) not at home
# [ 3] 20:40:35.1 Driver drives to Customer 37 at (3305, 2380)
# [ 3] 20:46:13.7 Driver arrived at Customer 37 at (3305, 2380)
# [ 3] 20:47:13.7 Customer 37 at (3305, 2380) not at home
# [ 3] 20:47:13.7 Driver drives to Customer 19 at (2380, 2717)
# [ 3] 20:52:16.6 Driver arrived at Customer 19 at (2380, 2717)
# [ 3] 20:53:16.6 Customer 19 at (2380, 2717) not at home
# [ 3] 20:53:16.6 Driver drives to Customer 20 at (2380, 3216)
# [ 3] 20:55:16.3 Driver arrived at Customer 20 at (2380, 3216)
# [ 3] 20:56:16.3 Customer 20 at (2380, 3216) not at home
# [ 3] 20:56:16.3 Driver drives to Customer 8 at (1695, 3440)
# [ 3] 20:59:54.5 Driver arrived at Customer 8 at (1695, 3440)
# [ 3] 21:00:54.5 Customer 8 at (1695, 3440) not at home
# [ 3] 21:00:54.5 Driver drives to Customer 6 at (1542, 3440)
# [ 3] 21:01:31.2 Driver arrived at Customer 6 at (1542, 3440)
# [ 3] 21:02:31.2 Customer 6 at (1542, 3440) not at home
# [ 3] 21:02:31.2 Driver drives to Customer 76 at (5226, 1653)
# [ 3] 21:22:42.0 Driver arrived at Customer 76 at (5226, 1653)
# [ 3] 21:23:42.0 Customer 76 at (5226, 1653) not at home
# [ 3] 21:23:42.0 Driver drives to Customer 79 at (5736, 1320)
# [ 3] 21:26:17.3 Driver arrived at Customer 79 at (5736, 1320)
# [ 3] 21:26:34.1 Customer 79 at (5736, 1320) answers door
# [ 3] 21:26:34.1 Customer 79 at (5736, 1320) accepts Parcel 46 for cust 79
# [ 3] 21:26:39.9 Customer 79 at (5736, 1320) accepts Parcel 159 for cust 79
# [ 3] 21:26:52.9 Customer 79 at (5736, 1320) signs off
# [ 3] 21:27:03.6 Driver drives to Customer 81 at (5915, 1320)
# [ 3] 21:27:46.6 Driver arrived at Customer 81 at (5915, 1320)
# [ 3] 21:28:46.6 Customer 81 at (5915, 1320) not at home
# [ 3] 21:28:46.6 Driver drives to Customer 84 at (6012, 1320)
# [ 3] 21:29:09.8 Driver arrived at Customer 84 at (6012, 1320)
# [ 3] 21:30:09.8 Customer 84 at (6012, 1320) not at home
# [ 3] 21:30:09.8 Driver drives to Customer 86 at (6203, 1320)
# [ 3] 21:30:55.7 Driver arrived at Customer 86 at (6203, 1320)
# [ 3] 21:31:55.7 Customer 86 at (6203, 1320) not at home
# [ 3] 21:31:55.7 Driver drives to Customer 88 at (6370, 1320)
# [ 3] 21:32:35.8 Driver arrived at Customer 88 at (6370, 1320)
# [ 3] 21:33:35.8 Customer 88 at (6370, 1320) not at home
# [ 3] 21:33:35.8 Driver drives to Customer 95 at (7141, 2380)
# [ 3] 21:40:55.2 Driver arrived at Customer 95 at (7141, 2380)
# [ 3] 21:41:07.3 Customer 95 at (7141, 2380) answers door
# [ 3] 21:41:07.3 Customer 95 at (7141, 2380) accepts Parcel 56 for cust 95
# [ 3] 21:41:18.4 Customer 95 at (7141, 2380) accepts Parcel 57 for cust 95
# [ 3] 21:41:22.0 Customer 95 at (7141, 2380) accepts Parcel 58 for cust 95
# [ 3] 21:41:26.4 Customer 95 at (7141, 2380) accepts Parcel 169 for cust 95
# [ 3] 21:41:34.2 Customer 95 at (7141, 2380) accepts Parcel 222 for cust 95
# [ 3] 21:41:47.4 Customer 95 at (7141, 2380) signs off
# [ 3] 21:41:49.0 Driver drives to Customer 96 at (8035, 2380)
# [ 3] 21:45:23.6 Driver arrived at Customer 96 at (8035, 2380)
# [ 3] 21:46:23.6 Customer 96 at (8035, 2380) not at home
# [ 3] 21:46:23.6 Driver drives to Customer 97 at (8360, 2380)
# [ 3] 21:47:41.6 Driver arrived at Customer 97 at (8360, 2380)
# [ 3] 21:48:41.6 Customer 97 at (8360, 2380) not at home
# [ 3] 21:48:41.6 Driver drives to Customer 98 at (8520, 2380)
# [ 3] 21:49:20.0 Driver arrived at Customer 98 at (8520, 2380)
# [ 3] 21:50:20.0 Customer 98 at (8520, 2380) not at home
# [ 3] 21:50:20.0 Driver drives to Customer 99 at (8740, 3028)
# [ 3] 21:53:48.3 Driver arrived at Customer 99 at (8740, 3028)
# [ 3] 21:54:48.3 Customer 99 at (8740, 3028) not at home
# [ 3] 21:54:48.3 Driver returns to delivery centre
# [ 3] 22:28:49.7 Driver arrived at delivery centre
# [ 3] 22:28:49.7 Parcel 152 for cust 63 return from delivery
# [ 3] 22:29:19.7 Parcel 100 for cust 64 return from delivery
# [ 3] 22:29:49.7 Parcel 101 for cust 64 return from delivery
# [ 3] 22:30:19.7 Parcel 153 for cust 64 return from delivery
# [ 3] 22:30:49.7 Parcel 106 for cust 80 return from delivery
# [ 3] 22:31:19.7 Parcel 216 for cust 80 return from delivery
# [ 3] 22:31:49.7 Parcel 162 for cust 83 return from delivery
# [ 3] 22:32:19.7 Parcel 163 for cust 83 return from delivery
# [ 3] 22:32:49.7 Parcel 208 for cust 65 return from delivery
# [ 3] 22:33:19.7 Parcel 34 for cust 66 return from delivery
# [ 3] 22:33:49.7 Parcel 102 for cust 67 return from delivery
# [ 3] 22:34:19.7 Parcel 103 for cust 67 return from delivery
# [ 3] 22:34:49.7 Parcel 209 for cust 67 return from delivery
# [ 3] 22:35:19.7 Parcel 35 for cust 68 return from delivery
# [ 3] 22:35:49.7 Parcel 154 for cust 68 return from delivery
# [ 3] 22:36:19.7 Parcel 210 for cust 68 return from delivery
# [ 3] 22:36:49.7 Parcel 211 for cust 68 return from delivery
# [ 3] 22:37:19.7 Parcel 36 for cust 69 return from delivery
# [ 3] 22:37:49.7 Parcel 155 for cust 69 return from delivery
# [ 3] 22:38:19.7 Parcel 37 for cust 70 return from delivery
# [ 3] 22:38:49.7 Parcel 38 for cust 70 return from delivery
# [ 3] 22:39:19.7 Parcel 156 for cust 70 return from delivery
# [ 3] 22:39:49.7 Parcel 39 for cust 71 return from delivery
# [ 3] 22:40:19.7 Parcel 40 for cust 72 return from delivery
# [ 3] 22:40:49.7 Parcel 212 for cust 72 return from delivery
# [ 3] 22:41:19.7 Parcel 41 for cust 73 return from delivery
# [ 3] 22:41:49.7 Parcel 42 for cust 73 return from delivery
# [ 3] 22:42:19.7 Parcel 104 for cust 73 return from delivery
# [ 3] 22:42:49.7 Parcel 213 for cust 74 return from delivery
# [ 3] 22:43:19.7 Parcel 214 for cust 74 return from delivery
# [ 3] 22:43:49.7 Parcel 157 for cust 75 return from delivery
# [ 3] 22:44:19.7 Parcel 161 for cust 82 return from delivery
# [ 3] 22:44:49.7 Parcel 53 for cust 87 return from delivery
# [ 3] 22:45:19.7 Parcel 33 for cust 62 return from delivery
# [ 3] 22:45:49.7 Parcel 99 for cust 62 return from delivery
# [ 3] 22:46:19.7 Parcel 151 for cust 62 return from delivery
# [ 3] 22:46:49.7 Parcel 98 for cust 60 return from delivery
# [ 3] 22:47:19.7 Parcel 148 for cust 60 return from delivery
# [ 3] 22:47:49.7 Parcel 206 for cust 60 return from delivery
# [ 3] 22:48:19.7 Parcel 30 for cust 58 return from delivery
# [ 3] 22:48:49.7 Parcel 97 for cust 58 return from delivery
# [ 3] 22:49:19.7 Parcel 203 for cust 58 return from delivery
# [ 3] 22:49:49.7 Parcel 204 for cust 58 return from delivery
# [ 3] 22:50:19.7 Parcel 205 for cust 58 return from delivery
# [ 3] 22:50:49.7 Parcel 96 for cust 57 return from delivery
# [ 3] 22:51:19.7 Parcel 202 for cust 57 return from delivery
# [ 3] 22:51:49.7 Parcel 187 for cust 37 return from delivery
# [ 3] 22:52:19.7 Parcel 177 for cust 19 return from delivery
# [ 3] 22:52:49.7 Parcel 129 for cust 20 return from delivery
# [ 3] 22:53:19.7 Parcel 67 for cust 8 return from delivery
# [ 3] 22:53:49.7 Parcel 123 for cust 8 return from delivery
# [ 3] 22:54:19.7 Parcel 173 for cust 8 return from delivery
# [ 3] 22:54:49.7 Parcel 121 for cust 6 return from delivery
# [ 3] 22:55:19.7 Parcel 215 for cust 76 return from delivery
# [ 3] 22:55:49.7 Parcel 160 for cust 81 return from delivery
# [ 3] 22:56:19.7 Parcel 217 for cust 81 return from delivery
# [ 3] 22:56:49.7 Parcel 47 for cust 84 return from delivery
# [ 3] 22:57:19.7 Parcel 48 for cust 84 return from delivery
# [ 3] 22:57:49.7 Parcel 165 for cust 86 return from delivery
# [ 3] 22:58:19.7 Parcel 166 for cust 86 return from delivery
# [ 3] 22:58:49.7 Parcel 219 for cust 86 return from delivery
# [ 3] 22:59:19.7 Parcel 220 for cust 86 return from delivery
# [ 3] 22:59:49.7 Parcel 112 for cust 88 return from delivery
# [ 3] 23:00:19.7 Parcel 118 for cust 96 return from delivery
# [ 3] 23:00:49.7 Parcel 223 for cust 96 return from delivery
# [ 3] 23:01:19.7 Parcel 59 for cust 97 return from delivery
# [ 3] 23:01:49.7 Parcel 60 for cust 98 return from delivery
# [ 3] 23:02:19.7 Parcel 224 for cust 98 return from delivery
# [ 3] 23:02:49.7 Parcel 225 for cust 98 return from delivery
# [ 3] 23:03:19.7 Parcel 61 for cust 99 return from delivery
# [ 3] 23:03:49.7 Parcel 226 for cust 99 return from delivery
# [ 3] 23:04:19.7 153 parcels left for next day
# [ 3] 23:14:19.7 Driver goes home
# Delivery Centre Inventory: 153 parcels

# %%
import pickle
with open('testData.pickled', 'rb') as f:
    MX, CX = pickle.load(f)

# %%
WX = generateWarehouseLocation(MX)

# %%
rec4 = simulation(MX, WX, CX, p=0.15, days=7, log=True)
# Out:
# Simulating delivery of 14 parcels over 7 days to 20 customers
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Nothing to do today
# [ 0] 18:10:00.0 Driver goes home
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Nothing to do today
# [ 1] 18:10:00.0 Driver goes home
# [ 2] 17:00:00.0 Parcel 0 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 1 for cust 12 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 2 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 2] 18:02:30.0 Driver leaves for delivery of 3 parcels to 3 customers
# [ 2] 18:02:30.0 Length of delivery tour: 12,451m
# [ 2] 18:02:30.0 Driver drives to Customer 4 at (3350, 5351)
# [ 2] 18:10:30.2 Driver arrived at Customer 4 at (3350, 5351)
# [ 2] 18:11:30.2 Customer 4 at (3350, 5351) not at home
# [ 2] 18:11:30.2 Driver drives to Customer 12 at (5650, 6077)
# [ 2] 18:23:36.5 Driver arrived at Customer 12 at (5650, 6077)
# [ 2] 18:24:36.5 Customer 12 at (5650, 6077) not at home
# [ 2] 18:24:36.5 Driver drives to Customer 19 at (7794, 5805)
# [ 2] 18:37:43.4 Driver arrived at Customer 19 at (7794, 5805)
# [ 2] 18:38:43.4 Customer 19 at (7794, 5805) not at home
# [ 2] 18:38:43.4 Driver returns to delivery centre
# [ 2] 18:55:18.2 Driver arrived at delivery centre
# [ 2] 18:55:18.2 Parcel 0 for cust 4 return from delivery
# [ 2] 18:55:48.2 Parcel 1 for cust 12 return from delivery
# [ 2] 18:56:18.2 Parcel 2 for cust 19 return from delivery
# [ 2] 18:56:48.2 3 parcels left for next day
# [ 2] 19:06:48.2 Driver goes home
# [ 3] 17:00:00.0 Parcel 3 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 4 for cust 3 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 3] 18:04:10.0 Driver leaves for delivery of 5 parcels to 5 customers
# [ 3] 18:04:10.0 Length of delivery tour: 19,431m
# [ 3] 18:04:10.0 Driver drives to Customer 2 at (2705, 1694)
# [ 3] 18:22:43.6 Driver arrived at Customer 2 at (2705, 1694)
# [ 3] 18:23:43.6 Customer 2 at (2705, 1694) to slow to answer the door
# [ 3] 18:23:43.6 Driver drives to Customer 3 at (3350, 5059)
# [ 3] 18:39:55.4 Driver arrived at Customer 3 at (3350, 5059)
# [ 3] 18:40:55.4 Customer 3 at (3350, 5059) not at home
# [ 3] 18:40:55.4 Driver drives to Customer 4 at (3350, 5351)
# [ 3] 18:42:05.4 Driver arrived at Customer 4 at (3350, 5351)
# [ 3] 18:43:05.4 Customer 4 at (3350, 5351) not at home
# [ 3] 18:43:05.4 Driver drives to Customer 12 at (5650, 6077)
# [ 3] 18:55:11.7 Driver arrived at Customer 12 at (5650, 6077)
# [ 3] 18:56:11.7 Customer 12 at (5650, 6077) not at home
# [ 3] 18:56:11.7 Driver drives to Customer 19 at (7794, 5805)
# [ 3] 19:09:18.6 Driver arrived at Customer 19 at (7794, 5805)
# [ 3] 19:10:18.6 Customer 19 at (7794, 5805) not at home
# [ 3] 19:10:18.6 Driver returns to delivery centre
# [ 3] 19:26:53.4 Driver arrived at delivery centre
# [ 3] 19:26:53.4 Parcel 3 for cust 2 return from delivery
# [ 3] 19:27:23.4 Parcel 4 for cust 3 return from delivery
# [ 3] 19:27:53.4 Parcel 0 for cust 4 return from delivery
# [ 3] 19:28:23.4 Parcel 1 for cust 12 return from delivery
# [ 3] 19:28:53.4 Parcel 2 for cust 19 return from delivery
# [ 3] 19:29:23.4 5 parcels left for next day
# [ 3] 19:39:23.4 Driver goes home
# [ 4] 17:00:00.0 Parcel 5 for cust 6 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 6 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 7 for cust 15 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 8 for cust 18 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 5 for cust 6 out for delivery
# [ 4] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 0 for cust 4 out for delivery
# [ 4] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 6 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 7 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 4] 18:07:30.0 Driver leaves for delivery of 9 parcels to 8 customers
# [ 4] 18:07:30.0 Length of delivery tour: 22,004m
# [ 4] 18:07:30.0 Driver drives to Customer 6 at (4500, 1421)
# [ 4] 18:19:49.0 Driver arrived at Customer 6 at (4500, 1421)
# [ 4] 18:20:49.0 Customer 6 at (4500, 1421) not at home
# [ 4] 18:20:49.0 Driver drives to Customer 2 at (2705, 1694)
# [ 4] 18:30:32.6 Driver arrived at Customer 2 at (2705, 1694)
# [ 4] 18:31:32.6 Customer 2 at (2705, 1694) not at home
# [ 4] 18:31:32.6 Driver drives to Customer 3 at (3350, 5059)
# [ 4] 18:47:44.4 Driver arrived at Customer 3 at (3350, 5059)
# [ 4] 18:48:44.4 Customer 3 at (3350, 5059) not at home
# [ 4] 18:48:44.4 Driver drives to Customer 4 at (3350, 5351)
# [ 4] 18:49:54.5 Driver arrived at Customer 4 at (3350, 5351)
# [ 4] 18:50:06.5 Customer 4 at (3350, 5351) answers door
# [ 4] 18:50:06.5 Customer 4 at (3350, 5351) accepts Parcel 0 for cust 4
# [ 4] 18:50:09.0 Customer 4 at (3350, 5351) signs off
# [ 4] 18:50:19.4 Driver drives to Customer 19 at (7794, 5805)
# [ 4] 19:14:54.5 Driver arrived at Customer 19 at (7794, 5805)
# [ 4] 19:15:54.5 Customer 19 at (7794, 5805) not at home
# [ 4] 19:15:54.5 Driver drives to Customer 18 at (7586, 6013)
# [ 4] 19:17:05.0 Driver arrived at Customer 18 at (7586, 6013)
# [ 4] 19:18:05.0 Customer 18 at (7586, 6013) not at home
# [ 4] 19:18:05.0 Driver drives to Customer 15 at (6396, 6800)
# [ 4] 19:24:08.9 Driver arrived at Customer 15 at (6396, 6800)
# [ 4] 19:25:08.9 Customer 15 at (6396, 6800) not at home
# [ 4] 19:25:08.9 Driver drives to Customer 12 at (5650, 6077)
# [ 4] 19:31:01.4 Driver arrived at Customer 12 at (5650, 6077)
# [ 4] 19:32:01.4 Customer 12 at (5650, 6077) not at home
# [ 4] 19:32:01.4 Driver returns to delivery centre
# [ 4] 19:42:55.9 Driver arrived at delivery centre
# [ 4] 19:42:55.9 Parcel 5 for cust 6 return from delivery
# [ 4] 19:43:25.9 Parcel 3 for cust 2 return from delivery
# [ 4] 19:43:55.9 Parcel 4 for cust 3 return from delivery
# [ 4] 19:44:25.9 Parcel 2 for cust 19 return from delivery
# [ 4] 19:44:55.9 Parcel 8 for cust 18 return from delivery
# [ 4] 19:45:25.9 Parcel 6 for cust 15 return from delivery
# [ 4] 19:45:55.9 Parcel 7 for cust 15 return from delivery
# [ 4] 19:46:25.9 Parcel 1 for cust 12 return from delivery
# [ 4] 19:46:55.9 8 parcels left for next day
# [ 4] 19:56:55.9 Driver goes home
# [ 5] 17:00:00.0 Parcel 9 for cust 2 arr at delivery centre
# [ 5] 18:00:00.0 Driver arrives for work
# [ 5] 18:00:00.0 Parcel 5 for cust 6 out for delivery
# [ 5] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 5] 18:00:00.0 Parcel 9 for cust 2 out for delivery
# [ 5] 18:00:00.0 Parcel 4 for cust 3 out for delivery
# [ 5] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 5] 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 5] 18:00:00.0 Parcel 6 for cust 15 out for delivery
# [ 5] 18:00:00.0 Parcel 7 for cust 15 out for delivery
# [ 5] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 5] 18:07:30.0 Driver leaves for delivery of 9 parcels to 7 customers
# [ 5] 18:07:30.0 Length of delivery tour: 21,420m
# [ 5] 18:07:30.0 Driver drives to Customer 6 at (4500, 1421)
# [ 5] 18:19:49.0 Driver arrived at Customer 6 at (4500, 1421)
# [ 5] 18:20:49.0 Customer 6 at (4500, 1421) not at home
# [ 5] 18:20:49.0 Driver drives to Customer 2 at (2705, 1694)
# [ 5] 18:30:32.6 Driver arrived at Customer 2 at (2705, 1694)
# [ 5] 18:31:32.6 Customer 2 at (2705, 1694) not at home
# [ 5] 18:31:32.6 Driver drives to Customer 3 at (3350, 5059)
# [ 5] 18:47:44.4 Driver arrived at Customer 3 at (3350, 5059)
# [ 5] 18:48:07.8 Customer 3 at (3350, 5059) answers door
# [ 5] 18:48:07.8 Customer 3 at (3350, 5059) accepts Parcel 4 for cust 3
# [ 5] 18:48:09.7 Customer 3 at (3350, 5059) signs off
# [ 5] 18:48:16.1 Driver drives to Customer 19 at (7794, 5805)
# [ 5] 19:11:41.0 Driver arrived at Customer 19 at (7794, 5805)
# [ 5] 19:12:41.0 Customer 19 at (7794, 5805) not at home
# [ 5] 19:12:41.0 Driver drives to Customer 18 at (7586, 6013)
# [ 5] 19:13:51.6 Driver arrived at Customer 18 at (7586, 6013)
# [ 5] 19:14:51.6 Customer 18 at (7586, 6013) not at home
# [ 5] 19:14:51.6 Driver drives to Customer 15 at (6396, 6800)
# [ 5] 19:20:55.4 Driver arrived at Customer 15 at (6396, 6800)
# [ 5] 19:21:55.4 Customer 15 at (6396, 6800) not at home
# [ 5] 19:21:55.4 Driver drives to Customer 12 at (5650, 6077)
# [ 5] 19:27:48.0 Driver arrived at Customer 12 at (5650, 6077)
# [ 5] 19:28:48.0 Customer 12 at (5650, 6077) not at home
# [ 5] 19:28:48.0 Driver returns to delivery centre
# [ 5] 19:39:42.5 Driver arrived at delivery centre
# [ 5] 19:39:42.5 Parcel 5 for cust 6 return from delivery
# [ 5] 19:40:12.5 Parcel 3 for cust 2 return from delivery
# [ 5] 19:40:42.5 Parcel 9 for cust 2 return from delivery
# [ 5] 19:41:12.5 Parcel 2 for cust 19 return from delivery
# [ 5] 19:41:42.5 Parcel 8 for cust 18 return from delivery
# [ 5] 19:42:12.5 Parcel 6 for cust 15 return from delivery
# [ 5] 19:42:42.5 Parcel 7 for cust 15 return from delivery
# [ 5] 19:43:12.5 Parcel 1 for cust 12 return from delivery
# [ 5] 19:43:42.5 8 parcels left for next day
# [ 5] 19:53:42.5 Driver goes home
# [ 6] 17:00:00.0 Parcel 10 for cust 4 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 11 for cust 6 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 12 for cust 7 arr at delivery centre
# [ 6] 17:00:00.0 Parcel 13 for cust 16 arr at delivery centre
# [ 6] 18:00:00.0 Driver arrives for work
# [ 6] 18:00:00.0 Parcel 12 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 5 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 11 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 3 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 9 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 10 for cust 4 out for delivery
# [ 6] 18:00:00.0 Parcel 2 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 8 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 13 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 6 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 7 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 1 for cust 12 out for delivery
# [ 6] 18:10:00.0 Driver leaves for delivery of 12 parcels to 9 customers
# [ 6] 18:10:00.0 Length of delivery tour: 22,004m
# [ 6] 18:10:00.0 Driver drives to Customer 7 at (4500, 1958)
# [ 6] 18:20:10.1 Driver arrived at Customer 7 at (4500, 1958)
# [ 6] 18:21:10.1 Customer 7 at (4500, 1958) not at home
# [ 6] 18:21:10.1 Driver drives to Customer 6 at (4500, 1421)
# [ 6] 18:23:19.0 Driver arrived at Customer 6 at (4500, 1421)
# [ 6] 18:24:19.0 Customer 6 at (4500, 1421) not at home
# [ 6] 18:24:19.0 Driver drives to Customer 2 at (2705, 1694)
# [ 6] 18:34:02.6 Driver arrived at Customer 2 at (2705, 1694)
# [ 6] 18:35:02.6 Customer 2 at (2705, 1694) not at home
# [ 6] 18:35:02.6 Driver drives to Customer 4 at (3350, 5351)
# [ 6] 18:52:24.5 Driver arrived at Customer 4 at (3350, 5351)
# [ 6] 18:53:24.5 Customer 4 at (3350, 5351) not at home
# [ 6] 18:53:24.5 Driver drives to Customer 19 at (7794, 5805)
# [ 6] 19:17:59.5 Driver arrived at Customer 19 at (7794, 5805)
# [ 6] 19:18:59.5 Customer 19 at (7794, 5805) not at home
# [ 6] 19:18:59.5 Driver drives to Customer 18 at (7586, 6013)
# [ 6] 19:20:10.1 Driver arrived at Customer 18 at (7586, 6013)
# [ 6] 19:20:48.9 Customer 18 at (7586, 6013) answers door
# [ 6] 19:20:48.9 Customer 18 at (7586, 6013) accepts Parcel 8 for cust 18
# [ 6] 19:21:01.5 Customer 18 at (7586, 6013) signs off
# [ 6] 19:21:06.4 Driver drives to Customer 16 at (6575, 6800)
# [ 6] 19:26:27.3 Driver arrived at Customer 16 at (6575, 6800)
# [ 6] 19:27:27.3 Customer 16 at (6575, 6800) not at home
# [ 6] 19:27:27.3 Driver drives to Customer 15 at (6396, 6800)
# [ 6] 19:28:10.2 Driver arrived at Customer 15 at (6396, 6800)
# [ 6] 19:29:10.2 Customer 15 at (6396, 6800) not at home
# [ 6] 19:29:10.2 Driver drives to Customer 12 at (5650, 6077)
# [ 6] 19:35:02.8 Driver arrived at Customer 12 at (5650, 6077)
# [ 6] 19:36:02.8 Customer 12 at (5650, 6077) not at home
# [ 6] 19:36:02.8 Driver returns to delivery centre
# [ 6] 19:46:57.3 Driver arrived at delivery centre
# [ 6] 19:46:57.3 Parcel 12 for cust 7 return from delivery
# [ 6] 19:47:27.3 Parcel 5 for cust 6 return from delivery
# [ 6] 19:47:57.3 Parcel 11 for cust 6 return from delivery
# [ 6] 19:48:27.3 Parcel 3 for cust 2 return from delivery
# [ 6] 19:48:57.3 Parcel 9 for cust 2 return from delivery
# [ 6] 19:49:27.3 Parcel 10 for cust 4 return from delivery
# [ 6] 19:49:57.3 Parcel 2 for cust 19 return from delivery
# [ 6] 19:50:27.3 Parcel 13 for cust 16 return from delivery
# [ 6] 19:50:57.3 Parcel 6 for cust 15 return from delivery
# [ 6] 19:51:27.3 Parcel 7 for cust 15 return from delivery
# [ 6] 19:51:57.3 Parcel 1 for cust 12 return from delivery
# [ 6] 19:52:27.3 11 parcels left for next day
# [ 6] 20:02:27.3 Driver goes home
# Delivery Centre Inventory: 11 parcels

# %%
rec5 = simulation(MX, WX, CX, p=1.2, days=7, log=True)
# Out:
# Simulating delivery of 151 parcels over 7 days to 20 customers
# [ 0] 17:00:00.0 Parcel 0 for cust 5 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 1 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 2 for cust 6 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 3 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 4 for cust 7 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 5 for cust 8 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 6 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 7 for cust 13 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 8 for cust 15 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 9 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 10 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 11 for cust 16 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 12 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 13 for cust 17 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 14 for cust 18 arr at delivery centre
# [ 0] 17:00:00.0 Parcel 15 for cust 19 arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 0] 18:00:00.0 Parcel 5 for cust 8 out for delivery
# [ 0] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 0] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 0] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 0] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 0] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 0] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 0] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 0] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 0] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 0] 18:13:20.0 Driver leaves for delivery of 16 parcels to 10 customers
# [ 0] 18:13:20.0 Length of delivery tour: 24,691m
# [ 0] 18:13:20.0 Driver drives to Customer 5 at (3350, 6210)
# [ 0] 18:24:46.4 Driver arrived at Customer 5 at (3350, 6210)
# [ 0] 18:25:46.4 Customer 5 at (3350, 6210) not at home
# [ 0] 18:25:46.4 Driver drives to Customer 8 at (4500, 3885)
# [ 0] 18:39:40.4 Driver arrived at Customer 8 at (4500, 3885)
# [ 0] 18:39:59.4 Customer 8 at (4500, 3885) answers door
# [ 0] 18:39:59.4 Customer 8 at (4500, 3885) accepts Parcel 5 for cust 8
# [ 0] 18:40:20.3 Customer 8 at (4500, 3885) signs off
# [ 0] 18:40:28.7 Driver drives to Customer 15 at (6396, 6800)
# [ 0] 18:59:43.3 Driver arrived at Customer 15 at (6396, 6800)
# [ 0] 19:00:43.3 Customer 15 at (6396, 6800) not at home
# [ 0] 19:00:43.3 Driver drives to Customer 16 at (6575, 6800)
# [ 0] 19:01:26.3 Driver arrived at Customer 16 at (6575, 6800)
# [ 0] 19:02:26.3 Customer 16 at (6575, 6800) not at home
# [ 0] 19:02:26.3 Driver drives to Customer 18 at (7586, 6013)
# [ 0] 19:07:47.1 Driver arrived at Customer 18 at (7586, 6013)
# [ 0] 19:08:47.1 Customer 18 at (7586, 6013) not at home
# [ 0] 19:08:47.1 Driver drives to Customer 19 at (7794, 5805)
# [ 0] 19:09:57.7 Driver arrived at Customer 19 at (7794, 5805)
# [ 0] 19:10:57.7 Customer 19 at (7794, 5805) not at home
# [ 0] 19:10:57.7 Driver drives to Customer 17 at (7516, 3350)
# [ 0] 19:25:48.3 Driver arrived at Customer 17 at (7516, 3350)
# [ 0] 19:26:48.3 Customer 17 at (7516, 3350) not at home
# [ 0] 19:26:48.3 Driver drives to Customer 13 at (6000, 3350)
# [ 0] 19:32:52.2 Driver arrived at Customer 13 at (6000, 3350)
# [ 0] 19:33:52.2 Customer 13 at (6000, 3350) not at home
# [ 0] 19:33:52.2 Driver drives to Customer 7 at (4500, 1958)
# [ 0] 19:45:26.3 Driver arrived at Customer 7 at (4500, 1958)
# [ 0] 19:46:26.3 Customer 7 at (4500, 1958) not at home
# [ 0] 19:46:26.3 Driver drives to Customer 6 at (4500, 1421)
# [ 0] 19:48:35.1 Driver arrived at Customer 6 at (4500, 1421)
# [ 0] 19:49:35.1 Customer 6 at (4500, 1421) not at home
# [ 0] 19:49:35.1 Driver returns to delivery centre
# [ 0] 20:01:54.1 Driver arrived at delivery centre
# [ 0] 20:01:54.1 Parcel 0 for cust 5 return from delivery
# [ 0] 20:02:24.1 Parcel 8 for cust 15 return from delivery
# [ 0] 20:02:54.1 Parcel 9 for cust 16 return from delivery
# [ 0] 20:03:24.1 Parcel 10 for cust 16 return from delivery
# [ 0] 20:03:54.1 Parcel 11 for cust 16 return from delivery
# [ 0] 20:04:24.1 Parcel 14 for cust 18 return from delivery
# [ 0] 20:04:54.1 Parcel 15 for cust 19 return from delivery
# [ 0] 20:05:24.1 Parcel 12 for cust 17 return from delivery
# [ 0] 20:05:54.1 Parcel 13 for cust 17 return from delivery
# [ 0] 20:06:24.1 Parcel 6 for cust 13 return from delivery
# [ 0] 20:06:54.1 Parcel 7 for cust 13 return from delivery
# [ 0] 20:07:24.1 Parcel 3 for cust 7 return from delivery
# [ 0] 20:07:54.1 Parcel 4 for cust 7 return from delivery
# [ 0] 20:08:24.1 Parcel 1 for cust 6 return from delivery
# [ 0] 20:08:54.1 Parcel 2 for cust 6 return from delivery
# [ 0] 20:09:24.1 15 parcels left for next day
# [ 0] 20:19:24.1 Driver goes home
# [ 1] 17:00:00.0 Parcel 16 for cust 0 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 17 for cust 1 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 18 for cust 3 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 19 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 20 for cust 5 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 21 for cust 6 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 22 for cust 7 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 23 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 24 for cust 8 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 25 for cust 9 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 26 for cust 11 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 27 for cust 13 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 28 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 29 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 30 for cust 14 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 31 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 32 for cust 15 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 33 for cust 16 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 34 for cust 18 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 35 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 36 for cust 19 arr at delivery centre
# [ 1] 17:00:00.0 Parcel 37 for cust 19 arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 1] 18:00:00.0 Parcel 18 for cust 3 out for delivery
# [ 1] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 1] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 1] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 1] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 1] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 1] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 1] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 1] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 1] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 35 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 36 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 37 for cust 19 out for delivery
# [ 1] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 1] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 1] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 1] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 1] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 1] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 1] 18:30:50.0 Driver leaves for delivery of 37 parcels to 16 customers
# [ 1] 18:30:50.0 Length of delivery tour: 30,585m
# [ 1] 18:30:50.0 Driver drives to Customer 8 at (4500, 3885)
# [ 1] 18:33:17.6 Driver arrived at Customer 8 at (4500, 3885)
# [ 1] 18:34:17.6 Customer 8 at (4500, 3885) not at home
# [ 1] 18:34:17.6 Driver drives to Customer 3 at (3350, 5059)
# [ 1] 18:43:35.4 Driver arrived at Customer 3 at (3350, 5059)
# [ 1] 18:44:35.4 Customer 3 at (3350, 5059) not at home
# [ 1] 18:44:35.4 Driver drives to Customer 5 at (3350, 6210)
# [ 1] 18:49:11.6 Driver arrived at Customer 5 at (3350, 6210)
# [ 1] 18:50:11.6 Customer 5 at (3350, 6210) not at home
# [ 1] 18:50:11.6 Driver drives to Customer 1 at (2200, 6343)
# [ 1] 18:58:58.9 Driver arrived at Customer 1 at (2200, 6343)
# [ 1] 18:59:58.9 Customer 1 at (2200, 6343) not at home
# [ 1] 18:59:58.9 Driver drives to Customer 0 at (2200, 4901)
# [ 1] 19:05:45.0 Driver arrived at Customer 0 at (2200, 4901)
# [ 1] 19:06:45.0 Customer 0 at (2200, 4901) not at home
# [ 1] 19:06:45.0 Driver drives to Customer 7 at (4500, 1958)
# [ 1] 19:27:43.3 Driver arrived at Customer 7 at (4500, 1958)
# [ 1] 19:28:43.3 Customer 7 at (4500, 1958) not at home
# [ 1] 19:28:43.3 Driver drives to Customer 6 at (4500, 1421)
# [ 1] 19:30:52.2 Driver arrived at Customer 6 at (4500, 1421)
# [ 1] 19:31:52.2 Customer 6 at (4500, 1421) not at home
# [ 1] 19:31:52.2 Driver drives to Customer 14 at (6278, 2200)
# [ 1] 19:42:05.8 Driver arrived at Customer 14 at (6278, 2200)
# [ 1] 19:43:05.8 Customer 14 at (6278, 2200) not at home
# [ 1] 19:43:05.8 Driver drives to Customer 13 at (6000, 3350)
# [ 1] 19:51:36.6 Driver arrived at Customer 13 at (6000, 3350)
# [ 1] 19:52:36.6 Customer 13 at (6000, 3350) not at home
# [ 1] 19:52:36.6 Driver drives to Customer 17 at (7516, 3350)
# [ 1] 19:58:40.4 Driver arrived at Customer 17 at (7516, 3350)
# [ 1] 19:59:40.4 Customer 17 at (7516, 3350) not at home
# [ 1] 19:59:40.4 Driver drives to Customer 19 at (7794, 5805)
# [ 1] 20:14:31.0 Driver arrived at Customer 19 at (7794, 5805)
# [ 1] 20:15:31.0 Customer 19 at (7794, 5805) not at home
# [ 1] 20:15:31.0 Driver drives to Customer 18 at (7586, 6013)
# [ 1] 20:16:41.6 Driver arrived at Customer 18 at (7586, 6013)
# [ 1] 20:17:41.6 Customer 18 at (7586, 6013) not at home
# [ 1] 20:17:41.6 Driver drives to Customer 16 at (6575, 6800)
# [ 1] 20:23:02.5 Driver arrived at Customer 16 at (6575, 6800)
# [ 1] 20:24:02.5 Customer 16 at (6575, 6800) not at home
# [ 1] 20:24:02.5 Driver drives to Customer 15 at (6396, 6800)
# [ 1] 20:24:45.4 Driver arrived at Customer 15 at (6396, 6800)
# [ 1] 20:25:45.4 Customer 15 at (6396, 6800) not at home
# [ 1] 20:25:45.4 Driver drives to Customer 11 at (5650, 5065)
# [ 1] 20:35:40.9 Driver arrived at Customer 11 at (5650, 5065)
# [ 1] 20:36:40.9 Customer 11 at (5650, 5065) not at home
# [ 1] 20:36:40.9 Driver drives to Customer 9 at (4500, 5079)
# [ 1] 20:45:51.4 Driver arrived at Customer 9 at (4500, 5079)
# [ 1] 20:46:51.4 Customer 9 at (4500, 5079) not at home
# [ 1] 20:46:51.4 Driver returns to delivery centre
# [ 1] 20:49:10.4 Driver arrived at delivery centre
# [ 1] 20:49:10.4 Parcel 23 for cust 8 return from delivery
# [ 1] 20:49:40.4 Parcel 24 for cust 8 return from delivery
# [ 1] 20:50:10.4 Parcel 18 for cust 3 return from delivery
# [ 1] 20:50:40.4 Parcel 0 for cust 5 return from delivery
# [ 1] 20:51:10.4 Parcel 19 for cust 5 return from delivery
# [ 1] 20:51:40.4 Parcel 20 for cust 5 return from delivery
# [ 1] 20:52:10.4 Parcel 17 for cust 1 return from delivery
# [ 1] 20:52:40.4 Parcel 16 for cust 0 return from delivery
# [ 1] 20:53:10.4 Parcel 3 for cust 7 return from delivery
# [ 1] 20:53:40.4 Parcel 4 for cust 7 return from delivery
# [ 1] 20:54:10.4 Parcel 22 for cust 7 return from delivery
# [ 1] 20:54:40.4 Parcel 1 for cust 6 return from delivery
# [ 1] 20:55:10.4 Parcel 2 for cust 6 return from delivery
# [ 1] 20:55:40.4 Parcel 21 for cust 6 return from delivery
# [ 1] 20:56:10.4 Parcel 28 for cust 14 return from delivery
# [ 1] 20:56:40.4 Parcel 29 for cust 14 return from delivery
# [ 1] 20:57:10.4 Parcel 30 for cust 14 return from delivery
# [ 1] 20:57:40.4 Parcel 6 for cust 13 return from delivery
# [ 1] 20:58:10.4 Parcel 7 for cust 13 return from delivery
# [ 1] 20:58:40.4 Parcel 27 for cust 13 return from delivery
# [ 1] 20:59:10.4 Parcel 12 for cust 17 return from delivery
# [ 1] 20:59:40.4 Parcel 13 for cust 17 return from delivery
# [ 1] 21:00:10.4 Parcel 15 for cust 19 return from delivery
# [ 1] 21:00:40.4 Parcel 35 for cust 19 return from delivery
# [ 1] 21:01:10.4 Parcel 36 for cust 19 return from delivery
# [ 1] 21:01:40.4 Parcel 37 for cust 19 return from delivery
# [ 1] 21:02:10.4 Parcel 14 for cust 18 return from delivery
# [ 1] 21:02:40.4 Parcel 34 for cust 18 return from delivery
# [ 1] 21:03:10.4 Parcel 9 for cust 16 return from delivery
# [ 1] 21:03:40.4 Parcel 10 for cust 16 return from delivery
# [ 1] 21:04:10.4 Parcel 11 for cust 16 return from delivery
# [ 1] 21:04:40.4 Parcel 33 for cust 16 return from delivery
# [ 1] 21:05:10.4 Parcel 8 for cust 15 return from delivery
# [ 1] 21:05:40.4 Parcel 31 for cust 15 return from delivery
# [ 1] 21:06:10.4 Parcel 32 for cust 15 return from delivery
# [ 1] 21:06:40.4 Parcel 26 for cust 11 return from delivery
# [ 1] 21:07:10.4 Parcel 25 for cust 9 return from delivery
# [ 1] 21:07:40.4 37 parcels left for next day
# [ 1] 21:17:40.4 Driver goes home
# [ 2] 17:00:00.0 Parcel 38 for cust 0 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 39 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 40 for cust 1 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 41 for cust 3 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 42 for cust 4 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 43 for cust 5 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 44 for cust 7 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 45 for cust 8 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 46 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 47 for cust 10 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 48 for cust 11 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 49 for cust 13 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 50 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 51 for cust 14 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 52 for cust 15 arr at delivery centre
# [ 2] 17:00:00.0 Parcel 53 for cust 19 arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel 15 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 35 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 36 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 37 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 53 for cust 19 out for delivery
# [ 2] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 2] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 2] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 2] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 2] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 2] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 2] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 2] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 2] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 2] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 2] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 2] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 2] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 2] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 2] 18:00:00.0 Parcel 18 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 41 for cust 3 out for delivery
# [ 2] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 2] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 2] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 2] 18:44:10.0 Driver leaves for delivery of 53 parcels to 18 customers
# [ 2] 18:44:10.0 Length of delivery tour: 31,371m
# [ 2] 18:44:10.0 Driver drives to Customer 19 at (7794, 5805)
# [ 2] 19:00:44.8 Driver arrived at Customer 19 at (7794, 5805)
# [ 2] 19:00:49.0 Customer 19 at (7794, 5805) answers door
# [ 2] 19:00:49.0 Customer 19 at (7794, 5805) accepts Parcel 15 for cust 19
# [ 2] 19:01:08.3 Customer 19 at (7794, 5805) accepts Parcel 35 for cust 19
# [ 2] 19:01:13.3 Customer 19 at (7794, 5805) accepts Parcel 36 for cust 19
# [ 2] 19:01:14.2 Customer 19 at (7794, 5805) accepts Parcel 37 for cust 19
# [ 2] 19:01:17.4 Customer 19 at (7794, 5805) accepts Parcel 53 for cust 19
# [ 2] 19:01:23.4 Customer 19 at (7794, 5805) signs off
# [ 2] 19:01:39.1 Driver drives to Customer 18 at (7586, 6013)
# [ 2] 19:02:49.7 Driver arrived at Customer 18 at (7586, 6013)
# [ 2] 19:03:49.7 Customer 18 at (7586, 6013) not at home
# [ 2] 19:03:49.7 Driver drives to Customer 16 at (6575, 6800)
# [ 2] 19:09:10.6 Driver arrived at Customer 16 at (6575, 6800)
# [ 2] 19:10:10.6 Customer 16 at (6575, 6800) not at home
# [ 2] 19:10:10.6 Driver drives to Customer 15 at (6396, 6800)
# [ 2] 19:10:53.5 Driver arrived at Customer 15 at (6396, 6800)
# [ 2] 19:11:53.5 Customer 15 at (6396, 6800) not at home
# [ 2] 19:11:53.5 Driver drives to Customer 11 at (5650, 5065)
# [ 2] 19:21:49.0 Driver arrived at Customer 11 at (5650, 5065)
# [ 2] 19:22:49.0 Customer 11 at (5650, 5065) not at home
# [ 2] 19:22:49.0 Driver drives to Customer 13 at (6000, 3350)
# [ 2] 19:31:04.6 Driver arrived at Customer 13 at (6000, 3350)
# [ 2] 19:32:04.6 Customer 13 at (6000, 3350) not at home
# [ 2] 19:32:04.6 Driver drives to Customer 17 at (7516, 3350)
# [ 2] 19:38:08.4 Driver arrived at Customer 17 at (7516, 3350)
# [ 2] 19:39:08.4 Customer 17 at (7516, 3350) not at home
# [ 2] 19:39:08.4 Driver drives to Customer 14 at (6278, 2200)
# [ 2] 19:48:41.5 Driver arrived at Customer 14 at (6278, 2200)
# [ 2] 19:49:41.5 Customer 14 at (6278, 2200) not at home
# [ 2] 19:49:41.5 Driver drives to Customer 10 at (5132, 1050)
# [ 2] 19:58:52.6 Driver arrived at Customer 10 at (5132, 1050)
# [ 2] 19:59:52.6 Customer 10 at (5132, 1050) not at home
# [ 2] 19:59:52.6 Driver drives to Customer 6 at (4500, 1421)
# [ 2] 20:03:53.3 Driver arrived at Customer 6 at (4500, 1421)
# [ 2] 20:04:53.3 Customer 6 at (4500, 1421) not at home
# [ 2] 20:04:53.3 Driver drives to Customer 7 at (4500, 1958)
# [ 2] 20:07:02.2 Driver arrived at Customer 7 at (4500, 1958)
# [ 2] 20:08:02.2 Customer 7 at (4500, 1958) not at home
# [ 2] 20:08:02.2 Driver drives to Customer 8 at (4500, 3885)
# [ 2] 20:15:44.6 Driver arrived at Customer 8 at (4500, 3885)
# [ 2] 20:16:44.6 Customer 8 at (4500, 3885) to slow to answer the door
# [ 2] 20:16:44.6 Driver drives to Customer 9 at (4500, 5079)
# [ 2] 20:21:31.2 Driver arrived at Customer 9 at (4500, 5079)
# [ 2] 20:22:31.2 Customer 9 at (4500, 5079) not at home
# [ 2] 20:22:31.2 Driver drives to Customer 5 at (3350, 6210)
# [ 2] 20:31:38.6 Driver arrived at Customer 5 at (3350, 6210)
# [ 2] 20:32:38.6 Customer 5 at (3350, 6210) not at home
# [ 2] 20:32:38.6 Driver drives to Customer 4 at (3350, 5351)
# [ 2] 20:36:04.8 Driver arrived at Customer 4 at (3350, 5351)
# [ 2] 20:37:04.8 Customer 4 at (3350, 5351) not at home
# [ 2] 20:37:04.8 Driver drives to Customer 3 at (3350, 5059)
# [ 2] 20:38:14.9 Driver arrived at Customer 3 at (3350, 5059)
# [ 2] 20:38:20.6 Customer 3 at (3350, 5059) answers door
# [ 2] 20:38:20.6 Customer 3 at (3350, 5059) accepts Parcel 18 for cust 3
# [ 2] 20:38:28.0 Customer 3 at (3350, 5059) accepts Parcel 41 for cust 3
# [ 2] 20:38:38.5 Customer 3 at (3350, 5059) signs off
# [ 2] 20:38:42.8 Driver drives to Customer 1 at (2200, 6343)
# [ 2] 20:48:26.9 Driver arrived at Customer 1 at (2200, 6343)
# [ 2] 20:49:26.9 Customer 1 at (2200, 6343) not at home
# [ 2] 20:49:26.9 Driver drives to Customer 0 at (2200, 4901)
# [ 2] 20:55:13.0 Driver arrived at Customer 0 at (2200, 4901)
# [ 2] 20:56:13.0 Customer 0 at (2200, 4901) not at home
# [ 2] 20:56:13.0 Driver returns to delivery centre
# [ 2] 21:07:01.2 Driver arrived at delivery centre
# [ 2] 21:07:01.2 Parcel 14 for cust 18 return from delivery
# [ 2] 21:07:31.2 Parcel 34 for cust 18 return from delivery
# [ 2] 21:08:01.2 Parcel 9 for cust 16 return from delivery
# [ 2] 21:08:31.2 Parcel 10 for cust 16 return from delivery
# [ 2] 21:09:01.2 Parcel 11 for cust 16 return from delivery
# [ 2] 21:09:31.2 Parcel 33 for cust 16 return from delivery
# [ 2] 21:10:01.2 Parcel 8 for cust 15 return from delivery
# [ 2] 21:10:31.2 Parcel 31 for cust 15 return from delivery
# [ 2] 21:11:01.2 Parcel 32 for cust 15 return from delivery
# [ 2] 21:11:31.2 Parcel 52 for cust 15 return from delivery
# [ 2] 21:12:01.2 Parcel 26 for cust 11 return from delivery
# [ 2] 21:12:31.2 Parcel 48 for cust 11 return from delivery
# [ 2] 21:13:01.2 Parcel 6 for cust 13 return from delivery
# [ 2] 21:13:31.2 Parcel 7 for cust 13 return from delivery
# [ 2] 21:14:01.2 Parcel 27 for cust 13 return from delivery
# [ 2] 21:14:31.2 Parcel 49 for cust 13 return from delivery
# [ 2] 21:15:01.2 Parcel 12 for cust 17 return from delivery
# [ 2] 21:15:31.2 Parcel 13 for cust 17 return from delivery
# [ 2] 21:16:01.2 Parcel 28 for cust 14 return from delivery
# [ 2] 21:16:31.2 Parcel 29 for cust 14 return from delivery
# [ 2] 21:17:01.2 Parcel 30 for cust 14 return from delivery
# [ 2] 21:17:31.2 Parcel 50 for cust 14 return from delivery
# [ 2] 21:18:01.2 Parcel 51 for cust 14 return from delivery
# [ 2] 21:18:31.2 Parcel 46 for cust 10 return from delivery
# [ 2] 21:19:01.2 Parcel 47 for cust 10 return from delivery
# [ 2] 21:19:31.2 Parcel 1 for cust 6 return from delivery
# [ 2] 21:20:01.2 Parcel 2 for cust 6 return from delivery
# [ 2] 21:20:31.2 Parcel 21 for cust 6 return from delivery
# [ 2] 21:21:01.2 Parcel 3 for cust 7 return from delivery
# [ 2] 21:21:31.2 Parcel 4 for cust 7 return from delivery
# [ 2] 21:22:01.2 Parcel 22 for cust 7 return from delivery
# [ 2] 21:22:31.2 Parcel 44 for cust 7 return from delivery
# [ 2] 21:23:01.2 Parcel 23 for cust 8 return from delivery
# [ 2] 21:23:31.2 Parcel 24 for cust 8 return from delivery
# [ 2] 21:24:01.2 Parcel 45 for cust 8 return from delivery
# [ 2] 21:24:31.2 Parcel 25 for cust 9 return from delivery
# [ 2] 21:25:01.2 Parcel 0 for cust 5 return from delivery
# [ 2] 21:25:31.2 Parcel 19 for cust 5 return from delivery
# [ 2] 21:26:01.2 Parcel 20 for cust 5 return from delivery
# [ 2] 21:26:31.2 Parcel 43 for cust 5 return from delivery
# [ 2] 21:27:01.2 Parcel 42 for cust 4 return from delivery
# [ 2] 21:27:31.2 Parcel 17 for cust 1 return from delivery
# [ 2] 21:28:01.2 Parcel 39 for cust 1 return from delivery
# [ 2] 21:28:31.2 Parcel 40 for cust 1 return from delivery
# [ 2] 21:29:01.2 Parcel 16 for cust 0 return from delivery
# [ 2] 21:29:31.2 Parcel 38 for cust 0 return from delivery
# [ 2] 21:30:01.2 46 parcels left for next day
# [ 2] 21:40:01.2 Driver goes home
# [ 3] 17:00:00.0 Parcel 54 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 55 for cust 0 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 56 for cust 2 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 57 for cust 3 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 58 for cust 4 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 59 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 60 for cust 5 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 61 for cust 6 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 62 for cust 7 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 63 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 64 for cust 8 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 65 for cust 9 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 66 for cust 10 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 67 for cust 13 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 68 for cust 14 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 69 for cust 17 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 70 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 71 for cust 18 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 72 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 73 for cust 19 arr at delivery centre
# [ 3] 17:00:00.0 Parcel 74 for cust 19 arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 54 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 55 for cust 0 out for delivery
# [ 3] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 3] 18:00:00.0 Parcel 0 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 19 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 20 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 43 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 59 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 60 for cust 5 out for delivery
# [ 3] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 58 for cust 4 out for delivery
# [ 3] 18:00:00.0 Parcel 57 for cust 3 out for delivery
# [ 3] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 3] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 3] 18:00:00.0 Parcel 56 for cust 2 out for delivery
# [ 3] 18:00:00.0 Parcel 1 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 2 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 21 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 61 for cust 6 out for delivery
# [ 3] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 3] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 3] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 3] 18:00:00.0 Parcel 6 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 7 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 27 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 49 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 67 for cust 13 out for delivery
# [ 3] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 3] 18:00:00.0 Parcel 72 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 73 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 74 for cust 19 out for delivery
# [ 3] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 3] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 3] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 3] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 3] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 3] 18:55:50.0 Driver leaves for delivery of 67 parcels to 19 customers
# [ 3] 18:55:50.0 Length of delivery tour: 36,394m
# [ 3] 18:55:50.0 Driver drives to Customer 0 at (2200, 4901)
# [ 3] 19:06:38.2 Driver arrived at Customer 0 at (2200, 4901)
# [ 3] 19:07:38.2 Customer 0 at (2200, 4901) not at home
# [ 3] 19:07:38.2 Driver drives to Customer 1 at (2200, 6343)
# [ 3] 19:13:24.3 Driver arrived at Customer 1 at (2200, 6343)
# [ 3] 19:14:24.3 Customer 1 at (2200, 6343) not at home
# [ 3] 19:14:24.3 Driver drives to Customer 5 at (3350, 6210)
# [ 3] 19:23:11.6 Driver arrived at Customer 5 at (3350, 6210)
# [ 3] 19:23:12.0 Customer 5 at (3350, 6210) answers door
# [ 3] 19:23:12.0 Customer 5 at (3350, 6210) accepts Parcel 0 for cust 5
# [ 3] 19:23:13.6 Customer 5 at (3350, 6210) accepts Parcel 19 for cust 5
# [ 3] 19:23:17.7 Customer 5 at (3350, 6210) accepts Parcel 20 for cust 5
# [ 3] 19:23:33.2 Customer 5 at (3350, 6210) accepts Parcel 43 for cust 5
# [ 3] 19:23:45.9 Customer 5 at (3350, 6210) accepts Parcel 59 for cust 5
# [ 3] 19:23:50.0 Customer 5 at (3350, 6210) accepts Parcel 60 for cust 5
# [ 3] 19:23:59.7 Customer 5 at (3350, 6210) signs off
# [ 3] 19:24:00.2 Driver drives to Customer 4 at (3350, 5351)
# [ 3] 19:27:26.3 Driver arrived at Customer 4 at (3350, 5351)
# [ 3] 19:28:26.3 Customer 4 at (3350, 5351) not at home
# [ 3] 19:28:26.3 Driver drives to Customer 3 at (3350, 5059)
# [ 3] 19:29:36.4 Driver arrived at Customer 3 at (3350, 5059)
# [ 3] 19:30:36.4 Customer 3 at (3350, 5059) not at home
# [ 3] 19:30:36.4 Driver drives to Customer 8 at (4500, 3885)
# [ 3] 19:39:54.2 Driver arrived at Customer 8 at (4500, 3885)
# [ 3] 19:40:54.2 Customer 8 at (4500, 3885) not at home
# [ 3] 19:40:54.2 Driver drives to Customer 9 at (4500, 5079)
# [ 3] 19:45:40.7 Driver arrived at Customer 9 at (4500, 5079)
# [ 3] 19:46:40.7 Customer 9 at (4500, 5079) not at home
# [ 3] 19:46:40.7 Driver drives to Customer 2 at (2705, 1694)
# [ 3] 20:07:33.3 Driver arrived at Customer 2 at (2705, 1694)
# [ 3] 20:07:40.4 Customer 2 at (2705, 1694) answers door
# [ 3] 20:07:40.4 Customer 2 at (2705, 1694) accepts Parcel 56 for cust 2
# [ 3] 20:08:20.6 Customer 2 at (2705, 1694) signs off
# [ 3] 20:08:24.0 Driver drives to Customer 6 at (4500, 1421)
# [ 3] 20:18:07.7 Driver arrived at Customer 6 at (4500, 1421)
# [ 3] 20:18:27.7 Customer 6 at (4500, 1421) answers door
# [ 3] 20:18:27.7 Customer 6 at (4500, 1421) accepts Parcel 1 for cust 6
# [ 3] 20:18:35.7 Customer 6 at (4500, 1421) accepts Parcel 2 for cust 6
# [ 3] 20:18:39.2 Customer 6 at (4500, 1421) accepts Parcel 21 for cust 6
# [ 3] 20:18:45.7 Customer 6 at (4500, 1421) accepts Parcel 61 for cust 6
# [ 3] 20:18:48.4 Customer 6 at (4500, 1421) signs off
# [ 3] 20:18:48.9 Driver drives to Customer 7 at (4500, 1958)
# [ 3] 20:20:57.8 Driver arrived at Customer 7 at (4500, 1958)
# [ 3] 20:21:57.8 Customer 7 at (4500, 1958) not at home
# [ 3] 20:21:57.8 Driver drives to Customer 10 at (5132, 1050)
# [ 3] 20:28:07.4 Driver arrived at Customer 10 at (5132, 1050)
# [ 3] 20:29:07.4 Customer 10 at (5132, 1050) not at home
# [ 3] 20:29:07.4 Driver drives to Customer 14 at (6278, 2200)
# [ 3] 20:38:18.4 Driver arrived at Customer 14 at (6278, 2200)
# [ 3] 20:39:18.4 Customer 14 at (6278, 2200) not at home
# [ 3] 20:39:18.4 Driver drives to Customer 13 at (6000, 3350)
# [ 3] 20:47:49.1 Driver arrived at Customer 13 at (6000, 3350)
# [ 3] 20:47:57.1 Customer 13 at (6000, 3350) answers door
# [ 3] 20:47:57.1 Customer 13 at (6000, 3350) accepts Parcel 6 for cust 13
# [ 3] 20:48:04.5 Customer 13 at (6000, 3350) accepts Parcel 7 for cust 13
# [ 3] 20:48:05.2 Customer 13 at (6000, 3350) accepts Parcel 27 for cust 13
# [ 3] 20:48:10.4 Customer 13 at (6000, 3350) accepts Parcel 49 for cust 13
# [ 3] 20:48:14.3 Customer 13 at (6000, 3350) accepts Parcel 67 for cust 13
# [ 3] 20:48:19.7 Customer 13 at (6000, 3350) signs off
# [ 3] 20:48:20.8 Driver drives to Customer 17 at (7516, 3350)
# [ 3] 20:54:24.6 Driver arrived at Customer 17 at (7516, 3350)
# [ 3] 20:55:24.6 Customer 17 at (7516, 3350) not at home
# [ 3] 20:55:24.6 Driver drives to Customer 19 at (7794, 5805)
# [ 3] 21:10:15.2 Driver arrived at Customer 19 at (7794, 5805)
# [ 3] 21:11:15.2 Customer 19 at (7794, 5805) not at home
# [ 3] 21:11:15.2 Driver drives to Customer 18 at (7586, 6013)
# [ 3] 21:12:25.8 Driver arrived at Customer 18 at (7586, 6013)
# [ 3] 21:13:25.8 Customer 18 at (7586, 6013) not at home
# [ 3] 21:13:25.8 Driver drives to Customer 16 at (6575, 6800)
# [ 3] 21:18:46.7 Driver arrived at Customer 16 at (6575, 6800)
# [ 3] 21:19:46.7 Customer 16 at (6575, 6800) not at home
# [ 3] 21:19:46.7 Driver drives to Customer 15 at (6396, 6800)
# [ 3] 21:20:29.6 Driver arrived at Customer 15 at (6396, 6800)
# [ 3] 21:21:29.6 Customer 15 at (6396, 6800) not at home
# [ 3] 21:21:29.6 Driver drives to Customer 11 at (5650, 5065)
# [ 3] 21:31:25.1 Driver arrived at Customer 11 at (5650, 5065)
# [ 3] 21:32:25.1 Customer 11 at (5650, 5065) not at home
# [ 3] 21:32:25.1 Driver returns to delivery centre
# [ 3] 21:39:16.7 Driver arrived at delivery centre
# [ 3] 21:39:16.7 Parcel 16 for cust 0 return from delivery
# [ 3] 21:39:46.7 Parcel 38 for cust 0 return from delivery
# [ 3] 21:40:16.7 Parcel 54 for cust 0 return from delivery
# [ 3] 21:40:46.7 Parcel 55 for cust 0 return from delivery
# [ 3] 21:41:16.7 Parcel 17 for cust 1 return from delivery
# [ 3] 21:41:46.7 Parcel 39 for cust 1 return from delivery
# [ 3] 21:42:16.7 Parcel 40 for cust 1 return from delivery
# [ 3] 21:42:46.7 Parcel 42 for cust 4 return from delivery
# [ 3] 21:43:16.7 Parcel 58 for cust 4 return from delivery
# [ 3] 21:43:46.7 Parcel 57 for cust 3 return from delivery
# [ 3] 21:44:16.7 Parcel 23 for cust 8 return from delivery
# [ 3] 21:44:46.7 Parcel 24 for cust 8 return from delivery
# [ 3] 21:45:16.7 Parcel 45 for cust 8 return from delivery
# [ 3] 21:45:46.7 Parcel 63 for cust 8 return from delivery
# [ 3] 21:46:16.7 Parcel 64 for cust 8 return from delivery
# [ 3] 21:46:46.7 Parcel 25 for cust 9 return from delivery
# [ 3] 21:47:16.7 Parcel 65 for cust 9 return from delivery
# [ 3] 21:47:46.7 Parcel 3 for cust 7 return from delivery
# [ 3] 21:48:16.7 Parcel 4 for cust 7 return from delivery
# [ 3] 21:48:46.7 Parcel 22 for cust 7 return from delivery
# [ 3] 21:49:16.7 Parcel 44 for cust 7 return from delivery
# [ 3] 21:49:46.7 Parcel 62 for cust 7 return from delivery
# [ 3] 21:50:16.7 Parcel 46 for cust 10 return from delivery
# [ 3] 21:50:46.7 Parcel 47 for cust 10 return from delivery
# [ 3] 21:51:16.7 Parcel 66 for cust 10 return from delivery
# [ 3] 21:51:46.7 Parcel 28 for cust 14 return from delivery
# [ 3] 21:52:16.7 Parcel 29 for cust 14 return from delivery
# [ 3] 21:52:46.7 Parcel 30 for cust 14 return from delivery
# [ 3] 21:53:16.7 Parcel 50 for cust 14 return from delivery
# [ 3] 21:53:46.7 Parcel 51 for cust 14 return from delivery
# [ 3] 21:54:16.7 Parcel 68 for cust 14 return from delivery
# [ 3] 21:54:46.7 Parcel 12 for cust 17 return from delivery
# [ 3] 21:55:16.7 Parcel 13 for cust 17 return from delivery
# [ 3] 21:55:46.7 Parcel 69 for cust 17 return from delivery
# [ 3] 21:56:16.7 Parcel 72 for cust 19 return from delivery
# [ 3] 21:56:46.7 Parcel 73 for cust 19 return from delivery
# [ 3] 21:57:16.7 Parcel 74 for cust 19 return from delivery
# [ 3] 21:57:46.7 Parcel 14 for cust 18 return from delivery
# [ 3] 21:58:16.7 Parcel 34 for cust 18 return from delivery
# [ 3] 21:58:46.7 Parcel 70 for cust 18 return from delivery
# [ 3] 21:59:16.7 Parcel 71 for cust 18 return from delivery
# [ 3] 21:59:46.7 Parcel 9 for cust 16 return from delivery
# [ 3] 22:00:16.7 Parcel 10 for cust 16 return from delivery
# [ 3] 22:00:46.7 Parcel 11 for cust 16 return from delivery
# [ 3] 22:01:16.7 Parcel 33 for cust 16 return from delivery
# [ 3] 22:01:46.7 Parcel 8 for cust 15 return from delivery
# [ 3] 22:02:16.7 Parcel 31 for cust 15 return from delivery
# [ 3] 22:02:46.7 Parcel 32 for cust 15 return from delivery
# [ 3] 22:03:16.7 Parcel 52 for cust 15 return from delivery
# [ 3] 22:03:46.7 Parcel 26 for cust 11 return from delivery
# [ 3] 22:04:16.7 Parcel 48 for cust 11 return from delivery
# [ 3] 22:04:46.7 51 parcels left for next day
# [ 3] 22:14:46.7 Driver goes home
# [ 4] 17:00:00.0 Parcel 75 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 76 for cust 0 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 77 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 78 for cust 1 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 79 for cust 2 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 80 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 81 for cust 3 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 82 for cust 5 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 83 for cust 7 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 84 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 85 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 86 for cust 8 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 87 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 88 for cust 10 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 89 for cust 12 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 90 for cust 13 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 91 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 92 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 93 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 94 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 95 for cust 16 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 96 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 97 for cust 17 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 98 for cust 18 arr at delivery centre
# [ 4] 17:00:00.0 Parcel 99 for cust 19 arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel 72 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 73 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 74 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 99 for cust 19 out for delivery
# [ 4] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 98 for cust 18 out for delivery
# [ 4] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 91 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 92 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 93 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 94 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 95 for cust 16 out for delivery
# [ 4] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 4] 18:00:00.0 Parcel 89 for cust 12 out for delivery
# [ 4] 18:00:00.0 Parcel 26 for cust 11 out for delivery
# [ 4] 18:00:00.0 Parcel 48 for cust 11 out for delivery
# [ 4] 18:00:00.0 Parcel 90 for cust 13 out for delivery
# [ 4] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 96 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 97 for cust 17 out for delivery
# [ 4] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 4] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 87 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 88 for cust 10 out for delivery
# [ 4] 18:00:00.0 Parcel 79 for cust 2 out for delivery
# [ 4] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 83 for cust 7 out for delivery
# [ 4] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 84 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 85 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 86 for cust 8 out for delivery
# [ 4] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 4] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 4] 18:00:00.0 Parcel 16 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 38 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 54 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 55 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 75 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 76 for cust 0 out for delivery
# [ 4] 18:00:00.0 Parcel 17 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 39 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 40 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 77 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 78 for cust 1 out for delivery
# [ 4] 18:00:00.0 Parcel 82 for cust 5 out for delivery
# [ 4] 18:00:00.0 Parcel 42 for cust 4 out for delivery
# [ 4] 18:00:00.0 Parcel 58 for cust 4 out for delivery
# [ 4] 18:00:00.0 Parcel 57 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 80 for cust 3 out for delivery
# [ 4] 18:00:00.0 Parcel 81 for cust 3 out for delivery
# [ 4] 19:03:20.0 Driver leaves for delivery of 76 parcels to 19 customers
# [ 4] 19:03:20.0 Length of delivery tour: 35,263m
# [ 4] 19:03:20.0 Driver drives to Customer 19 at (7794, 5805)
# [ 4] 19:19:54.8 Driver arrived at Customer 19 at (7794, 5805)
# [ 4] 19:20:54.8 Customer 19 at (7794, 5805) not at home
# [ 4] 19:20:54.8 Driver drives to Customer 18 at (7586, 6013)
# [ 4] 19:22:05.4 Driver arrived at Customer 18 at (7586, 6013)
# [ 4] 19:23:05.4 Customer 18 at (7586, 6013) not at home
# [ 4] 19:23:05.4 Driver drives to Customer 16 at (6575, 6800)
# [ 4] 19:28:26.2 Driver arrived at Customer 16 at (6575, 6800)
# [ 4] 19:29:26.2 Customer 16 at (6575, 6800) not at home
# [ 4] 19:29:26.2 Driver drives to Customer 15 at (6396, 6800)
# [ 4] 19:30:09.2 Driver arrived at Customer 15 at (6396, 6800)
# [ 4] 19:31:09.2 Customer 15 at (6396, 6800) not at home
# [ 4] 19:31:09.2 Driver drives to Customer 12 at (5650, 6077)
# [ 4] 19:37:01.8 Driver arrived at Customer 12 at (5650, 6077)
# [ 4] 19:37:02.1 Customer 12 at (5650, 6077) answers door
# [ 4] 19:37:02.1 Customer 12 at (5650, 6077) accepts Parcel 89 for cust 12
# [ 4] 19:37:07.1 Customer 12 at (5650, 6077) signs off
# [ 4] 19:37:14.4 Driver drives to Customer 11 at (5650, 5065)
# [ 4] 19:41:17.3 Driver arrived at Customer 11 at (5650, 5065)
# [ 4] 19:42:17.3 Customer 11 at (5650, 5065) not at home
# [ 4] 19:42:17.3 Driver drives to Customer 13 at (6000, 3350)
# [ 4] 19:50:32.9 Driver arrived at Customer 13 at (6000, 3350)
# [ 4] 19:50:56.7 Customer 13 at (6000, 3350) answers door
# [ 4] 19:50:56.7 Customer 13 at (6000, 3350) accepts Parcel 90 for cust 13
# [ 4] 19:51:03.4 Customer 13 at (6000, 3350) signs off
# [ 4] 19:51:12.2 Driver drives to Customer 17 at (7516, 3350)
# [ 4] 19:57:16.0 Driver arrived at Customer 17 at (7516, 3350)
# [ 4] 19:58:16.0 Customer 17 at (7516, 3350) not at home
# [ 4] 19:58:16.0 Driver drives to Customer 14 at (6278, 2200)
# [ 4] 20:07:49.1 Driver arrived at Customer 14 at (6278, 2200)
# [ 4] 20:08:49.1 Customer 14 at (6278, 2200) not at home
# [ 4] 20:08:49.1 Driver drives to Customer 10 at (5132, 1050)
# [ 4] 20:18:00.2 Driver arrived at Customer 10 at (5132, 1050)
# [ 4] 20:19:00.2 Customer 10 at (5132, 1050) not at home
# [ 4] 20:19:00.2 Driver drives to Customer 2 at (2705, 1694)
# [ 4] 20:29:46.5 Driver arrived at Customer 2 at (2705, 1694)
# [ 4] 20:30:32.0 Customer 2 at (2705, 1694) answers door
# [ 4] 20:30:32.0 Customer 2 at (2705, 1694) accepts Parcel 79 for cust 2
# [ 4] 20:30:37.5 Customer 2 at (2705, 1694) signs off
# [ 4] 20:30:42.1 Driver drives to Customer 7 at (4500, 1958)
# [ 4] 20:42:34.7 Driver arrived at Customer 7 at (4500, 1958)
# [ 4] 20:43:34.7 Customer 7 at (4500, 1958) not at home
# [ 4] 20:43:34.7 Driver drives to Customer 8 at (4500, 3885)
# [ 4] 20:51:17.1 Driver arrived at Customer 8 at (4500, 3885)
# [ 4] 20:52:17.1 Customer 8 at (4500, 3885) not at home
# [ 4] 20:52:17.1 Driver drives to Customer 9 at (4500, 5079)
# [ 4] 20:57:03.7 Driver arrived at Customer 9 at (4500, 5079)
# [ 4] 20:58:03.7 Customer 9 at (4500, 5079) to slow to answer the door
# [ 4] 20:58:03.7 Driver drives to Customer 0 at (2200, 4901)
# [ 4] 21:11:10.9 Driver arrived at Customer 0 at (2200, 4901)
# [ 4] 21:12:10.9 Customer 0 at (2200, 4901) not at home
# [ 4] 21:12:10.9 Driver drives to Customer 1 at (2200, 6343)
# [ 4] 21:17:57.0 Driver arrived at Customer 1 at (2200, 6343)
# [ 4] 21:18:57.0 Customer 1 at (2200, 6343) not at home
# [ 4] 21:18:57.0 Driver drives to Customer 5 at (3350, 6210)
# [ 4] 21:27:44.3 Driver arrived at Customer 5 at (3350, 6210)
# [ 4] 21:28:44.3 Customer 5 at (3350, 6210) not at home
# [ 4] 21:28:44.3 Driver drives to Customer 4 at (3350, 5351)
# [ 4] 21:32:10.4 Driver arrived at Customer 4 at (3350, 5351)
# [ 4] 21:33:10.4 Customer 4 at (3350, 5351) not at home
# [ 4] 21:33:10.4 Driver drives to Customer 3 at (3350, 5059)
# [ 4] 21:34:20.5 Driver arrived at Customer 3 at (3350, 5059)
# [ 4] 21:35:20.5 Customer 3 at (3350, 5059) not at home
# [ 4] 21:35:20.5 Driver returns to delivery centre
# [ 4] 21:42:10.7 Driver arrived at delivery centre
# [ 4] 21:42:10.7 Parcel 72 for cust 19 return from delivery
# [ 4] 21:42:40.7 Parcel 73 for cust 19 return from delivery
# [ 4] 21:43:10.7 Parcel 74 for cust 19 return from delivery
# [ 4] 21:43:40.7 Parcel 99 for cust 19 return from delivery
# [ 4] 21:44:10.7 Parcel 14 for cust 18 return from delivery
# [ 4] 21:44:40.7 Parcel 34 for cust 18 return from delivery
# [ 4] 21:45:10.7 Parcel 70 for cust 18 return from delivery
# [ 4] 21:45:40.7 Parcel 71 for cust 18 return from delivery
# [ 4] 21:46:10.7 Parcel 98 for cust 18 return from delivery
# [ 4] 21:46:40.7 Parcel 9 for cust 16 return from delivery
# [ 4] 21:47:10.7 Parcel 10 for cust 16 return from delivery
# [ 4] 21:47:40.7 Parcel 11 for cust 16 return from delivery
# [ 4] 21:48:10.7 Parcel 33 for cust 16 return from delivery
# [ 4] 21:48:40.7 Parcel 91 for cust 16 return from delivery
# [ 4] 21:49:10.7 Parcel 92 for cust 16 return from delivery
# ...
# [ 6] 18:00:00.0 Parcel 128 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 129 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 130 for cust 5 out for delivery
# [ 6] 18:00:00.0 Parcel 137 for cust 12 out for delivery
# [ 6] 18:00:00.0 Parcel 8 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 31 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 32 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 52 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 118 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 119 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 120 for cust 15 out for delivery
# [ 6] 18:00:00.0 Parcel 9 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 10 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 11 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 33 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 91 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 92 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 93 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 94 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 95 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 121 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 142 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 143 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 144 for cust 16 out for delivery
# [ 6] 18:00:00.0 Parcel 14 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 34 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 70 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 71 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 98 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 146 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 147 for cust 18 out for delivery
# [ 6] 18:00:00.0 Parcel 72 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 73 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 74 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 99 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 123 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 148 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 149 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 150 for cust 19 out for delivery
# [ 6] 18:00:00.0 Parcel 136 for cust 11 out for delivery
# [ 6] 18:00:00.0 Parcel 114 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 115 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 116 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 138 for cust 13 out for delivery
# [ 6] 18:00:00.0 Parcel 12 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 13 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 69 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 96 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 97 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 122 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 145 for cust 17 out for delivery
# [ 6] 18:00:00.0 Parcel 28 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 29 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 30 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 50 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 51 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 68 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 117 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 139 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 140 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 141 for cust 14 out for delivery
# [ 6] 18:00:00.0 Parcel 46 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 47 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 66 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 87 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 88 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 111 for cust 10 out for delivery
# [ 6] 18:00:00.0 Parcel 126 for cust 2 out for delivery
# [ 6] 18:00:00.0 Parcel 106 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 107 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 108 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 131 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 132 for cust 6 out for delivery
# [ 6] 18:00:00.0 Parcel 3 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 4 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 22 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 44 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 62 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 83 for cust 7 out for delivery
# [ 6] 18:00:00.0 Parcel 23 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 24 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 45 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 63 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 64 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 84 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 85 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 86 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 109 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 133 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 134 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 135 for cust 8 out for delivery
# [ 6] 18:00:00.0 Parcel 25 for cust 9 out for delivery
# [ 6] 18:00:00.0 Parcel 65 for cust 9 out for delivery
# [ 6] 18:00:00.0 Parcel 110 for cust 9 out for delivery
# [ 6] 19:35:50.0 Driver leaves for delivery of 115 parcels to 19 customers
# [ 6] 19:35:50.0 Length of delivery tour: 35,628m
# [ 6] 19:35:50.0 Driver drives to Customer 0 at (2200, 4901)
# [ 6] 19:46:38.2 Driver arrived at Customer 0 at (2200, 4901)
# [ 6] 19:47:38.2 Customer 0 at (2200, 4901) not at home
# [ 6] 19:47:38.2 Driver drives to Customer 1 at (2200, 6343)
# [ 6] 19:53:24.3 Driver arrived at Customer 1 at (2200, 6343)
# [ 6] 19:54:24.3 Customer 1 at (2200, 6343) not at home
# [ 6] 19:54:24.3 Driver drives to Customer 4 at (3350, 5351)
# [ 6] 20:02:58.4 Driver arrived at Customer 4 at (3350, 5351)
# [ 6] 20:03:58.4 Customer 4 at (3350, 5351) not at home
# [ 6] 20:03:58.4 Driver drives to Customer 5 at (3350, 6210)
# [ 6] 20:07:24.6 Driver arrived at Customer 5 at (3350, 6210)
# [ 6] 20:08:24.6 Customer 5 at (3350, 6210) not at home
# [ 6] 20:08:24.6 Driver drives to Customer 12 at (5650, 6077)
# [ 6] 20:21:33.4 Driver arrived at Customer 12 at (5650, 6077)
# [ 6] 20:22:33.4 Customer 12 at (5650, 6077) not at home
# [ 6] 20:22:33.4 Driver drives to Customer 15 at (6396, 6800)
# [ 6] 20:28:26.0 Driver arrived at Customer 15 at (6396, 6800)
# [ 6] 20:29:26.0 Customer 15 at (6396, 6800) not at home
# [ 6] 20:29:26.0 Driver drives to Customer 16 at (6575, 6800)
# [ 6] 20:30:09.0 Driver arrived at Customer 16 at (6575, 6800)
# [ 6] 20:31:09.0 Customer 16 at (6575, 6800) not at home
# [ 6] 20:31:09.0 Driver drives to Customer 18 at (7586, 6013)
# [ 6] 20:36:29.8 Driver arrived at Customer 18 at (7586, 6013)
# [ 6] 20:37:29.8 Customer 18 at (7586, 6013) not at home
# [ 6] 20:37:29.8 Driver drives to Customer 19 at (7794, 5805)
# [ 6] 20:38:40.4 Driver arrived at Customer 19 at (7794, 5805)
# [ 6] 20:39:40.4 Customer 19 at (7794, 5805) not at home
# [ 6] 20:39:40.4 Driver drives to Customer 11 at (5650, 5065)
# [ 6] 20:56:50.2 Driver arrived at Customer 11 at (5650, 5065)
# [ 6] 20:57:50.2 Customer 11 at (5650, 5065) not at home
# [ 6] 20:57:50.2 Driver drives to Customer 13 at (6000, 3350)
# [ 6] 21:06:05.8 Driver arrived at Customer 13 at (6000, 3350)
# [ 6] 21:07:05.8 Customer 13 at (6000, 3350) not at home
# [ 6] 21:07:05.8 Driver drives to Customer 17 at (7516, 3350)
# [ 6] 21:13:09.7 Driver arrived at Customer 17 at (7516, 3350)
# [ 6] 21:14:09.7 Customer 17 at (7516, 3350) not at home
# [ 6] 21:14:09.7 Driver drives to Customer 14 at (6278, 2200)
# [ 6] 21:23:42.8 Driver arrived at Customer 14 at (6278, 2200)
# [ 6] 21:24:42.8 Customer 14 at (6278, 2200) not at home
# [ 6] 21:24:42.8 Driver drives to Customer 10 at (5132, 1050)
# [ 6] 21:33:53.8 Driver arrived at Customer 10 at (5132, 1050)
# [ 6] 21:34:53.8 Customer 10 at (5132, 1050) not at home
# [ 6] 21:34:53.8 Driver drives to Customer 2 at (2705, 1694)
# [ 6] 21:45:40.2 Driver arrived at Customer 2 at (2705, 1694)
# [ 6] 21:46:40.2 Customer 2 at (2705, 1694) not at home
# [ 6] 21:46:40.2 Driver drives to Customer 6 at (4500, 1421)
# [ 6] 21:56:23.8 Driver arrived at Customer 6 at (4500, 1421)
# [ 6] 21:57:23.8 Customer 6 at (4500, 1421) not at home
# [ 6] 21:57:23.8 Driver drives to Customer 7 at (4500, 1958)
# [ 6] 21:59:32.7 Driver arrived at Customer 7 at (4500, 1958)
# [ 6] 22:00:32.7 Customer 7 at (4500, 1958) not at home
# [ 6] 22:00:32.7 Driver drives to Customer 8 at (4500, 3885)
# [ 6] 22:08:15.2 Driver arrived at Customer 8 at (4500, 3885)
# [ 6] 22:08:16.9 Customer 8 at (4500, 3885) answers door
# [ 6] 22:08:16.9 Customer 8 at (4500, 3885) accepts Parcel 23 for cust 8
# [ 6] 22:08:17.0 Customer 8 at (4500, 3885) accepts Parcel 24 for cust 8
# [ 6] 22:08:35.6 Customer 8 at (4500, 3885) accepts Parcel 45 for cust 8
# [ 6] 22:08:39.6 Customer 8 at (4500, 3885) accepts Parcel 63 for cust 8
# [ 6] 22:08:41.4 Customer 8 at (4500, 3885) accepts Parcel 64 for cust 8
# [ 6] 22:08:43.0 Customer 8 at (4500, 3885) accepts Parcel 84 for cust 8
# [ 6] 22:08:53.6 Customer 8 at (4500, 3885) accepts Parcel 85 for cust 8
# [ 6] 22:09:28.2 Customer 8 at (4500, 3885) accepts Parcel 86 for cust 8
# [ 6] 22:09:35.3 Customer 8 at (4500, 3885) accepts Parcel 109 for cust 8
# [ 6] 22:09:58.4 Customer 8 at (4500, 3885) accepts Parcel 133 for cust 8
# [ 6] 22:10:05.4 Customer 8 at (4500, 3885) accepts Parcel 134 for cust 8
# [ 6] 22:10:13.9 Customer 8 at (4500, 3885) accepts Parcel 135 for cust 8
# [ 6] 22:10:25.3 Customer 8 at (4500, 3885) signs off
# [ 6] 22:10:41.6 Driver drives to Customer 9 at (4500, 5079)
# [ 6] 22:15:28.2 Driver arrived at Customer 9 at (4500, 5079)
# [ 6] 22:16:24.9 Customer 9 at (4500, 5079) answers door
# [ 6] 22:16:24.9 Customer 9 at (4500, 5079) accepts Parcel 25 for cust 9
# [ 6] 22:17:11.5 Customer 9 at (4500, 5079) accepts Parcel 65 for cust 9
# [ 6] 22:17:25.3 Customer 9 at (4500, 5079) accepts Parcel 110 for cust 9
# [ 6] 22:17:48.9 Customer 9 at (4500, 5079) signs off
# [ 6] 22:17:51.2 Driver returns to delivery centre
# [ 6] 22:20:10.1 Driver arrived at delivery centre
# [ 6] 22:20:10.1 Parcel 16 for cust 0 return from delivery
# [ 6] 22:20:40.1 Parcel 38 for cust 0 return from delivery
# [ 6] 22:21:10.1 Parcel 54 for cust 0 return from delivery
# [ 6] 22:21:40.1 Parcel 55 for cust 0 return from delivery
# [ 6] 22:22:10.1 Parcel 75 for cust 0 return from delivery
# [ 6] 22:22:40.1 Parcel 76 for cust 0 return from delivery
# [ 6] 22:23:10.1 Parcel 100 for cust 0 return from delivery
# [ 6] 22:23:40.1 Parcel 124 for cust 0 return from delivery
# [ 6] 22:24:10.1 Parcel 125 for cust 0 return from delivery
# [ 6] 22:24:40.1 Parcel 17 for cust 1 return from delivery
# [ 6] 22:25:10.1 Parcel 39 for cust 1 return from delivery
# [ 6] 22:25:40.1 Parcel 40 for cust 1 return from delivery
# [ 6] 22:26:10.1 Parcel 77 for cust 1 return from delivery
# [ 6] 22:26:40.1 Parcel 78 for cust 1 return from delivery
# [ 6] 22:27:10.1 Parcel 101 for cust 1 return from delivery
# [ 6] 22:27:40.1 Parcel 42 for cust 4 return from delivery
# [ 6] 22:28:10.1 Parcel 58 for cust 4 return from delivery
# [ 6] 22:28:40.1 Parcel 104 for cust 4 return from delivery
# [ 6] 22:29:10.1 Parcel 105 for cust 4 return from delivery
# [ 6] 22:29:40.1 Parcel 127 for cust 4 return from delivery
# [ 6] 22:30:10.1 Parcel 82 for cust 5 return from delivery
# [ 6] 22:30:40.1 Parcel 128 for cust 5 return from delivery
# [ 6] 22:31:10.1 Parcel 129 for cust 5 return from delivery
# [ 6] 22:31:40.1 Parcel 130 for cust 5 return from delivery
# [ 6] 22:32:10.1 Parcel 137 for cust 12 return from delivery
# [ 6] 22:32:40.1 Parcel 8 for cust 15 return from delivery
# [ 6] 22:33:10.1 Parcel 31 for cust 15 return from delivery
# [ 6] 22:33:40.1 Parcel 32 for cust 15 return from delivery
# [ 6] 22:34:10.1 Parcel 52 for cust 15 return from delivery
# [ 6] 22:34:40.1 Parcel 118 for cust 15 return from delivery
# [ 6] 22:35:10.1 Parcel 119 for cust 15 return from delivery
# [ 6] 22:35:40.1 Parcel 120 for cust 15 return from delivery
# [ 6] 22:36:10.1 Parcel 9 for cust 16 return from delivery
# [ 6] 22:36:40.1 Parcel 10 for cust 16 return from delivery
# [ 6] 22:37:10.1 Parcel 11 for cust 16 return from delivery
# [ 6] 22:37:40.1 Parcel 33 for cust 16 return from delivery
# [ 6] 22:38:10.1 Parcel 91 for cust 16 return from delivery
# [ 6] 22:38:40.1 Parcel 92 for cust 16 return from delivery
# [ 6] 22:39:10.1 Parcel 93 for cust 16 return from delivery
# [ 6] 22:39:40.1 Parcel 94 for cust 16 return from delivery
# [ 6] 22:40:10.1 Parcel 95 for cust 16 return from delivery
# [ 6] 22:40:40.1 Parcel 121 for cust 16 return from delivery
# [ 6] 22:41:10.1 Parcel 142 for cust 16 return from delivery
# [ 6] 22:41:40.1 Parcel 143 for cust 16 return from delivery
# [ 6] 22:42:10.1 Parcel 144 for cust 16 return from delivery
# [ 6] 22:42:40.1 Parcel 14 for cust 18 return from delivery
# [ 6] 22:43:10.1 Parcel 34 for cust 18 return from delivery
# [ 6] 22:43:40.1 Parcel 70 for cust 18 return from delivery
# [ 6] 22:44:10.1 Parcel 71 for cust 18 return from delivery
# [ 6] 22:44:40.1 Parcel 98 for cust 18 return from delivery
# [ 6] 22:45:10.1 Parcel 146 for cust 18 return from delivery
# [ 6] 22:45:40.1 Parcel 147 for cust 18 return from delivery
# [ 6] 22:46:10.1 Parcel 72 for cust 19 return from delivery
# [ 6] 22:46:40.1 Parcel 73 for cust 19 return from delivery
# [ 6] 22:47:10.1 Parcel 74 for cust 19 return from delivery
# [ 6] 22:47:40.1 Parcel 99 for cust 19 return from delivery
# [ 6] 22:48:10.1 Parcel 123 for cust 19 return from delivery
# [ 6] 22:48:40.1 Parcel 148 for cust 19 return from delivery
# [ 6] 22:49:10.1 Parcel 149 for cust 19 return from delivery
# [ 6] 22:49:40.1 Parcel 150 for cust 19 return from delivery
# [ 6] 22:50:10.1 Parcel 136 for cust 11 return from delivery
# [ 6] 22:50:40.1 Parcel 114 for cust 13 return from delivery
# [ 6] 22:51:10.1 Parcel 115 for cust 13 return from delivery
# [ 6] 22:51:40.1 Parcel 116 for cust 13 return from delivery
# [ 6] 22:52:10.1 Parcel 138 for cust 13 return from delivery
# [ 6] 22:52:40.1 Parcel 12 for cust 17 return from delivery
# [ 6] 22:53:10.1 Parcel 13 for cust 17 return from delivery
# [ 6] 22:53:40.1 Parcel 69 for cust 17 return from delivery
# [ 6] 22:54:10.1 Parcel 96 for cust 17 return from delivery
# [ 6] 22:54:40.1 Parcel 97 for cust 17 return from delivery
# [ 6] 22:55:10.1 Parcel 122 for cust 17 return from delivery
# [ 6] 22:55:40.1 Parcel 145 for cust 17 return from delivery
# [ 6] 22:56:10.1 Parcel 28 for cust 14 return from delivery
# [ 6] 22:56:40.1 Parcel 29 for cust 14 return from delivery
# [ 6] 22:57:10.1 Parcel 30 for cust 14 return from delivery
# [ 6] 22:57:40.1 Parcel 50 for cust 14 return from delivery
# [ 6] 22:58:10.1 Parcel 51 for cust 14 return from delivery
# [ 6] 22:58:40.1 Parcel 68 for cust 14 return from delivery
# [ 6] 22:59:10.1 Parcel 117 for cust 14 return from delivery
# [ 6] 22:59:40.1 Parcel 139 for cust 14 return from delivery
# [ 6] 23:00:10.1 Parcel 140 for cust 14 return from delivery
# [ 6] 23:00:40.1 Parcel 141 for cust 14 return from delivery
# [ 6] 23:01:10.1 Parcel 46 for cust 10 return from delivery
# [ 6] 23:01:40.1 Parcel 47 for cust 10 return from delivery
# [ 6] 23:02:10.1 Parcel 66 for cust 10 return from delivery
# [ 6] 23:02:40.1 Parcel 87 for cust 10 return from delivery
# [ 6] 23:03:10.1 Parcel 88 for cust 10 return from delivery
# [ 6] 23:03:40.1 Parcel 111 for cust 10 return from delivery
# [ 6] 23:04:10.1 Parcel 126 for cust 2 return from delivery
# [ 6] 23:04:40.1 Parcel 106 for cust 6 return from delivery
# [ 6] 23:05:10.1 Parcel 107 for cust 6 return from delivery
# [ 6] 23:05:40.1 Parcel 108 for cust 6 return from delivery
# [ 6] 23:06:10.1 Parcel 131 for cust 6 return from delivery
# [ 6] 23:06:40.1 Parcel 132 for cust 6 return from delivery
# [ 6] 23:07:10.1 Parcel 3 for cust 7 return from delivery
# [ 6] 23:07:40.1 Parcel 4 for cust 7 return from delivery
# [ 6] 23:08:10.1 Parcel 22 for cust 7 return from delivery
# [ 6] 23:08:40.1 Parcel 44 for cust 7 return from delivery
# [ 6] 23:09:10.1 Parcel 62 for cust 7 return from delivery
# [ 6] 23:09:40.1 Parcel 83 for cust 7 return from delivery
# [ 6] 23:10:10.1 100 parcels left for next day
# [ 6] 23:20:10.1 Driver goes home
# Delivery Centre Inventory: 100 parcels
